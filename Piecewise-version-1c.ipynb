# %% [markdown]
# ## Initial Package Import and Simple Module definition
#
# Modified from ZFTurbo

# %%
# %matplotlib inline


import shutil

import datetime
import pandas as pd
import numpy as np
import xgboost as xgb
from sklearn.metrics import roc_auc_score
from scipy.io import loadmat
from operator import itemgetter
import random
import os
import time
import glob
import re
from multiprocessing import Process
import copy

#Importing old and new Kfold
from sklearn.cross_validation import KFold
from sklearn.model_selection import KFold as NewKF
from sklearn.model_selection import StratifiedKFold as StratKF

#Importing GroupKfold, only available since version 0.18
from sklearn.model_selection import GroupKFold


#Importing function for scaling data before PCA
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import scale

#Importing PCA packages
from sklearn.decomposition import PCA, KernelPCA

#Importing FFT package
from scipy.fftpack import fft

#Importing crossvalidation metrics and Gridsearch
from sklearn import cross_validation, metrics
from sklearn.model_selection import GridSearchCV

#Importing wrapper to use XGB with Gridsearch

from xgboost.sklearn import XGBClassifier

#Importing plotting packages (optional)

import matplotlib.pylab as plt

from pandas.tools.plotting import scatter_matrix

from sklearn.model_selection import LeavePGroupsOut
from sklearn.model_selection import GroupShuffleSplit

#Oversampling

from imblearn.over_sampling import SMOTE

from collections import Counter

from imblearn.combine import SMOTETomek



#Defining general modules used in the classification

random.seed(2016)
np.random.seed(2016)


def natural_key(string_):
    return [int(s) if s.isdigit() else s for s in re.split(r'(\d+)', string_)]


def create_feature_map(features):
    outfile = open('xgb.fmap', 'w')
    for i, feat in enumerate(features):
        outfile.write('{0}\t{1}\tq\n'.format(i, feat))
    outfile.close()


def get_importance(gbm, features):
    create_feature_map(features)
    importance = gbm.get_fscore(fmap='xgb.fmap')
    importance = sorted(importance.items(), key=itemgetter(1), reverse=True)
    return importance


def intersect(a, b):
    return list(set(a) & set(b))


def print_features_importance(imp):
    for i in range(len(imp)):
        print("# " + str(imp[i][1]))
        print('output.remove(\'' + imp[i][0] + '\')')


def mat_to_pandas(path):
    mat = loadmat(path)
    names = mat['dataStruct'].dtype.names
    ndata = {n: mat['dataStruct'][n][0, 0] for n in names}
    samp_freq = ndata['iEEGsamplingRate'][0, 0]
    sequence = -1
    if 'sequence' in names:
        sequence = mat['dataStruct']['sequence']
    return pd.DataFrame(ndata['data'], columns=ndata['channelIndices'][0]), sequence, samp_freq

def create_submission(score, test, prediction, feature_model, short_size, new_test):
    # Make Submission
    now = datetime.datetime.now()
    sub_file = 'submission_' + str(score) + '_' + 'model_'+str(feature_model)+'_short_'+str(short_size)+'_new_test_'+str(new_test)+'_'+ str(now.strftime("%Y-%m-%d-%H-%M")) + '.csv'
    print('Writing submission: ', sub_file)
    f = open(sub_file, 'w')
    f.write('File,Class\n')
    total = 0
    for id in test['Id']:
        patient = id // 100000
        fid = id % 100000
        str1 = str(patient) + '_' + str(fid) + '.mat' + ',' + str(prediction[total])
        str1 += '\n'
        total += 1
        f.write(str1)
    f.close()


def get_features(train, test):
    trainval = list(train.columns.values)
    testval = list(test.columns.values)
    output = intersect(trainval, testval)
    output.remove('Id')
    # output.remove('file_size')
    return sorted(output)

# %% [markdown]
# ## Module for Creating Features and Saving to CSV Files
#
# #### One file per patient per test/training

# %%
#Modules to read train and test data.
#Short_dataset can be False or TRue. It decides whether to use the lon or short sample size.

def create_simple_csv_train(patient_id, feature_model, num_features, short_dataset=False, new_test=False):
    
    feature_file='_'+str(feature_model)+'_short_'+str(short_dataset)+'_new_test_'+ str(new_test)
    
    if short_dataset:
        
        source_dir="./data/train_"
    else:
        source_dir="./train_"
    
    new_label=''
    if new_test:
        
        new_label='_new'

    out = open("simple_train_" + str(patient_id) + feature_file + ".csv", "w")
    out.write("Id,sequence_id,patient_id,")
  
    columns=''
    for i in range(16):
        for j in range(num_features):
            columns+= 'ch_'+str(i)+'_'+"band_"+str(j)+","        

    out.write(columns+"file_size,result\n")

    # TRAIN (0)
    out_str = ''
    files = sorted(glob.glob(source_dir + str(patient_id) + "/*.mat"), key=natural_key)
    print ('train files'+ str(patient_id), len(files))    
    pos1=0
    neg1=0
    sequence_id_pre = int(patient_id)*1000
    sequence_id_inter = int(patient_id)*1000
    total_pre = 0
    total_inter=0
    seq1=0
    
    new_train = pd.read_csv('train_and_test_data_labels_safe'+'.csv')
    new_data = new_train['image']
    
    selection = new_train[new_train['safe'] == 1].drop('safe', axis=1)
    
    for fl in files:
        
        # print('Go for ' + fl)
               
        if os.path.basename(fl) not in selection['image'].values:
            continue
        
        id_str = os.path.basename(fl)[:-4]
        arr = id_str.split("_")
        patient = int(arr[0])
        id = int(arr[1])
        result = int(arr[2])
        
        if result == 1:
            
            total_pre += 1
            sequence_id=int(patient_id)*1000+int((total_pre-1) // 6) + int((total_inter-1) // 6) + 1

            
        elif result == 0:
            
            total_inter += 1            
            sequence_id=int(patient_id)*1000+int((total_pre) // 6) + int((total_inter-1) // 6)

        
        new_id = int(patient*100000 + id)
        try:
            tables, sequence_from_mat, samp_freq = mat_to_pandas(fl)
        except:
            print('Some error here {}...'.format(fl))
            continue
        print(sequence_id)
        out_str += str(new_id) + "," + str(sequence_id) + "," + str(patient)

        sizesignal=int(tables.shape[0])       
        
        for f in sorted(list(tables.columns.values)):
            
            out_str=feature_eng(tables[f], out_str,feature_model, sizesignal, samp_freq)
            
            
        out_str += "," + str(os.path.getsize(fl)) + "," + str(result) + "\n"
        #print(sequence_from_mat)
        #print(type(sequence_from_mat))
        seq1=int(sequence_from_mat[0][0][0][0])
        print('total preictal: ', total_pre,' total interictal: ', total_inter,' sequence local: ', seq1)
        if (total_pre % 6 == 0) and result == 1:
                pos1 += 1
                print('Positive ocurrence sequence finished', pos1)
                if (seq1==6):
                    sequence_id_pre += 1
                    print ('sequence preictal next',sequence_id_pre)
        
        if (total_inter % 6 == 0) and result == 0:                
                neg1 += 1
                print('Negative ocurrence sequence finished', neg1)
                if (seq1==6):
                    sequence_id_inter += 1
                    print ('sequence interictal next',sequence_id_inter)

    out.write(out_str)
    
    out.close()
    print('Train CSV for patient {} has been completed...'.format(patient_id))


def create_simple_csv_test(patient_id, feature_model, num_features, short_dataset=False, new_test=False):
    
    feature_file='_'+str(feature_model)+'_short_'+str(short_dataset)+'_new_test_'+str(new_test)
    
    if short_dataset:
        
        source_dir="./data/test_"
    else:
        source_dir="./test_"
    
    new_label=''
    
    if new_test:
        
        new_label="_new"

    # TEST
    out_str = ''
    files = sorted(glob.glob(source_dir + str(patient_id) + new_label + "/*.mat"), key=natural_key)
    print ('test files'+ str(patient_id), len(files))    
    out = open("simple_test_" + str(patient_id) + feature_file + ".csv", "w")
    out.write("Id,patient_id,")
    
    columns=''
    for i in range(16):
        for j in range(num_features):
            columns+= 'ch_'+str(i)+'_'+"band_"+str(j)+","        
    
    out.write(columns+"file_size\n")
    
        
    for fl in files:
        # print('Go for ' + fl)
        id_str = os.path.basename(fl)[4:-4]
        arr = id_str.split("_")
        patient = int(arr[0])
        id = int(arr[1])
        new_id = int(patient*100000 + id)
        try:
            tables, sequence_from_mat, samp_freq = mat_to_pandas(fl)
        except:
            print('Some error here {}...'.format(fl))
            continue
        out_str += str(new_id) + "," + str(patient)

        sizesignal=int(tables.shape[0])           
        
        
        
        
        for f in sorted(list(tables.columns.values)):
            
            out_str=feature_eng(tables[f], out_str,feature_model, sizesignal, samp_freq)
                        
        out_str += "," + str(os.path.getsize(fl)) + "\n"
        # break

    out.write(out_str)
    out.close()
    print('Test CSV for patient {} has been completed...'.format(patient_id))

# %% [markdown]
# ## Feature Engineering

# %%
#eng_number is the feature_value that has values 0,1,2,3... infinite, given by the list below.

def feature_eng(data_sensor, out_str, eng_number, sizesignal, fs):

                
    yf1 = fft(data_sensor)
    fftpeak=2/sizesignal * np.abs(yf1[0:sizesignal/2])
 
    numberofbands=4

    sizeband=20/numberofbands

    if eng_number==3:
        
    
        ###Band Frequency filtering###
        from scipy.signal import butter, lfilter

        ##Frequency parameters##
        #Start frequency#+
        fini = 4
        #End frequency#
        fend = 30
        #Frequency band range#
        frng = 4
        #Frequency overlap#
        fovr = 2
    
        #Frequency band generator#
        fbands = [[f, f + frng] for f in range(fini, fend - (frng - fovr), frng - fovr)]
    
        #Filter order#
        order = 5
        #Nyquist frequency#
        fnyq = fs / 2.0
        

        for fb in fbands:
        
            #Create butterworth bandpass filter#
            b, a = butter(order, fb  / fnyq, btype='band')
            
            #Apply filter#
            data_filter = lfilter(b, a, data_sensor)
            
            #Band pass 'power'#
            band_pwr = np.square(data_filter)
            
            avg_band_pwr = band_pwr.mean()
            
            out_str += "," + str(avg_band_pwr)
            

    elif eng_number==2:
        
        mean = data_sensor.mean()
        
        peak1=fftpeak[0:3].mean()            
        peak2=fftpeak[3:6].mean()          
        peak3=fftpeak[6:9].mean()
        peak4=fftpeak[9:12].mean()
        peak5=fftpeak[12:15].mean()            
        peak6=fftpeak[15:18].mean()          
        peak7=fftpeak[18:21].mean()
        peak8=fftpeak[21:24].mean()
        peak9=fftpeak[24:27].mean()            
        peak10=fftpeak[27:30].mean()          
        peak11=fftpeak[30:33].mean()
        peak12=fftpeak[33:36].mean()
            
        out_str += "," + str(mean)+ "," + str(peak1) + "," + str(peak2) + "," + str(peak3) +"," + str(peak4) \
                    +"," + str(peak5) + "," + str(peak6) + "," + str(peak7) +"," + str(peak8)+ "," + str(peak9) \
                    +"," + str(peak10) + "," + str(peak11) +"," + str(peak12)
    
    elif eng_number==1:
            
        mean = data_sensor.mean()   
        
        peak1=fftpeak[0:5].mean()            
        peak2=fftpeak[5:10].mean()          
        peak3=fftpeak[10:15].mean()
        peak4=fftpeak[15:20].mean()
        
        out_str += "," + str(mean)+ "," + str(peak1) + "," + str(peak2) + "," + str(peak3) +"," + str(peak4)
    
    elif eng_number==0:
            
        mean = data_sensor.mean()
    
        out_str += "," + str(mean)
    
    return out_str

# %% [markdown]
# ## Module for Reading Test and Train Feature Files and Concatenating

# %%
def read_test_train(feature_model, short_size=False, new_test=False):
    feature_file='_'+str(feature_model)
    print("Load train.csv...")
    train1 = pd.read_csv('simple_train_1'+feature_file+'_short_'+str(short_size)+'_new_test_'+str(new_test)+'.csv')
    train2 = pd.read_csv('simple_train_2'+feature_file+'_short_'+str(short_size)+'_new_test_'+str(new_test)+'.csv')
    train3 = pd.read_csv('simple_train_3'+feature_file+'_short_'+str(short_size)+'_new_test_'+str(new_test)+'.csv')
    train = pd.concat([train1, train2, train3])
    # Remove all zeroes files
    train = train[train['file_size'] > 55000].copy()
    # Shuffle rows since they are ordered
    train = train.iloc[np.random.permutation(len(train))]
    # Reset broken index
    train = train.reset_index()
    print("Load test.csv...")
    test1 = pd.read_csv('simple_test_1'+feature_file+'_short_'+str(short_size)+'_new_test_'+str(new_test)+'.csv')
    test2 = pd.read_csv('simple_test_2'+feature_file+'_short_'+str(short_size)+'_new_test_'+str(new_test)+'.csv')
    test3 = pd.read_csv('simple_test_3'+feature_file+'_short_'+str(short_size)+'_new_test_'+str(new_test)+'.csv')
    test = pd.concat([test1, test2, test3])
    print("Process tables...")
    features = get_features(train, test)
    return train, test, features

# %% [markdown]
# ## Running Creation of Feature Files (!!!)

# %%
feature_model=3
short_size=True
num_features=12
new_test=True


if __name__ == '__main__':
    print('XGBoost: {}'.format(xgb.__version__))
    if 1:
        # Do reading and processing of MAT files in parallel
        p = dict()
        p[1] = Process(target=create_simple_csv_train, args=(1,feature_model,num_features,short_size,new_test))
        p[1].start()
        p[2] = Process(target=create_simple_csv_train, args=(2,feature_model,num_features,short_size,new_test))
        p[2].start()
        p[3] = Process(target=create_simple_csv_train, args=(3,feature_model,num_features,short_size,new_test))
        p[3].start()
        p[4] = Process(target=create_simple_csv_test, args=(1,feature_model,num_features,short_size,new_test))
        p[4].start()
        p[5] = Process(target=create_simple_csv_test, args=(2,feature_model,num_features,short_size,new_test))
        p[5].start()
        p[6] = Process(target=create_simple_csv_test, args=(3,feature_model,num_features,short_size,new_test))
        p[6].start()
        p[1].join()
        p[2].join()
        p[3].join()
        p[4].join()
        p[5].join()
        p[6].join()
# Out:
# XGBoost: 0.6
# test files1 48
# train files3 168
# test files2 56
# train files2 168
# train files1 168
# test files3 54
# /home/rodolfoxps/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:7: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
# 1000
# /home/rodolfoxps/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:7: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
# /home/rodolfoxps/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:7: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
# 3000
# /home/rodolfoxps/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:7: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
# 2000
# /home/rodolfoxps/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:7: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
# /home/rodolfoxps/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:7: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
# total preictal:  0  total interictal:  1  sequence local:  1
# total preictal:  0  total interictal:  1  sequence local:  1
# total preictal:  0  total interictal:  1  sequence local:  1
# 3001
# 1001
# 2001
# total preictal:  1  total interictal:  1  sequence local:  1
# total preictal:  1  total interictal:  1  sequence local:  1
# 1000
# total preictal:  1  total interictal:  1  sequence local:  1
# 3000
# 2000
# total preictal:  1  total interictal:  2  sequence local:  2
# 3001
# total preictal:  1  total interictal:  2  sequence local:  2
# 2001
# total preictal:  1  total interictal:  2  sequence local:  2
# 1001
# total preictal:  2  total interictal:  2  sequence local:  2
# 2000
# total preictal:  2  total interictal:  2  sequence local:  2
# 3000
# total preictal:  2  total interictal:  2  sequence local:  2
# 1000
# total preictal:  2  total interictal:  3  sequence local:  3
# 2001
# total preictal:  2  total interictal:  3  sequence local:  3
# 3001
# total preictal:  2  total interictal:  3  sequence local:  3
# 1001
# total preictal:  3  total interictal:  3  sequence local:  3
# 2000
# total preictal:  3  total interictal:  3  sequence local:  3
# 3000
# total preictal:  3  total interictal:  3  sequence local:  3
# 1000
# total preictal:  3  total interictal:  4  sequence local:  4
# 2001
# total preictal:  3  total interictal:  4  sequence local:  4
# 3001
# total preictal:  3  total interictal:  4  sequence local:  4
# 1001
# total preictal:  4  total interictal:  4  sequence local:  4
# 2000
# total preictal:  4  total interictal:  4  sequence local:  4
# 3000
# total preictal:  4  total interictal:  4  sequence local:  4
# 1000
# total preictal:  4  total interictal:  5  sequence local:  5
# 2001
# total preictal:  4  total interictal:  5  sequence local:  5
# 3001
# total preictal:  4  total interictal:  5  sequence local:  5
# 1001
# total preictal:  5  total interictal:  5  sequence local:  5
# 2000
# total preictal:  5  total interictal:  5  sequence local:  5
# 3000
# total preictal:  5  total interictal:  5  sequence local:  5
# 1000
# total preictal:  5  total interictal:  6  sequence local:  6
# Negative ocurrence sequence finished 1
# sequence interictal next 3001
# 3001
# total preictal:  5  total interictal:  6  sequence local:  6
# Negative ocurrence sequence finished 1
# sequence interictal next 2001
# 2001
# total preictal:  5  total interictal:  6  sequence local:  6
# Negative ocurrence sequence finished 1
# sequence interictal next 1001
# 1001
# total preictal:  6  total interictal:  6  sequence local:  6
# Positive ocurrence sequence finished 1
# sequence preictal next 3001
# 3002
# total preictal:  6  total interictal:  6  sequence local:  6
# Positive ocurrence sequence finished 1
# sequence preictal next 2001
# 2002
# total preictal:  6  total interictal:  6  sequence local:  6
# Positive ocurrence sequence finished 1
# sequence preictal next 1001
# 1002
# total preictal:  6  total interictal:  7  sequence local:  1
# total preictal:  6  total interictal:  7  sequence local:  1
# 3003
# 2003
# total preictal:  6  total interictal:  7  sequence local:  1
# 1003
# total preictal:  7  total interictal:  7  sequence local:  1
# 3002
# total preictal:  7  total interictal:  7  sequence local:  1
# 2002
# total preictal:  7  total interictal:  7  sequence local:  1
# 1002
# total preictal:  7  total interictal:  8  sequence local:  2
# 3003
# total preictal:  7  total interictal:  8  sequence local:  2
# 2003
# total preictal:  7  total interictal:  8  sequence local:  2
# 1003
# total preictal:  8  total interictal:  8  sequence local:  2
# 2002
# total preictal:  8  total interictal:  8  sequence local:  2
# 3002
# total preictal:  8  total interictal:  8  sequence local:  2
# 1002
# total preictal:  8  total interictal:  9  sequence local:  3
# 2003
# total preictal:  8  total interictal:  9  sequence local:  3
# 3003
# total preictal:  8  total interictal:  9  sequence local:  3
# 1003
# total preictal:  9  total interictal:  9  sequence local:  3
# 3002
# total preictal:  9  total interictal:  9  sequence local:  3
# 2002
# total preictal:  9  total interictal:  9  sequence local:  3
# 1002
# total preictal:  9  total interictal:  10  sequence local:  4
# total preictal:  9  total interictal:  10  sequence local:  4
# 2003
# 3003
# total preictal:  9  total interictal:  10  sequence local:  4
# 1003
# total preictal:  10  total interictal:  10  sequence local:  4
# 2002
# total preictal:  10  total interictal:  10  sequence local:  4
# 3002
# total preictal:  10  total interictal:  10  sequence local:  4
# 1002
# total preictal:  10  total interictal:  11  sequence local:  5
# total preictal:  10  total interictal:  11  sequence local:  5
# 2003
# 3003
# total preictal:  10  total interictal:  11  sequence local:  5
# 1003
# total preictal:  11  total interictal:  11  sequence local:  5
# 2002
# total preictal:  11  total interictal:  11  sequence local:  5
# 3002
# total preictal:  11  total interictal:  11  sequence local:  5
# 1002
# total preictal:  11  total interictal:  12  sequence local:  6
# Negative ocurrence sequence finished 2
# sequence interictal next 2002
# 2003
# total preictal:  11  total interictal:  12  sequence local:  6
# Negative ocurrence sequence finished 2
# sequence interictal next 3002
# total preictal:  11  total interictal:  12  sequence local:  6
# Negative ocurrence sequence finished 2
# sequence interictal next 1002
# 3003
# 1003
# total preictal:  12  total interictal:  12  sequence local:  6
# Positive ocurrence sequence finished 2
# sequence preictal next 2002
# 2004
# total preictal:  12  total interictal:  12  sequence local:  6
# Positive ocurrence sequence finished 2
# sequence preictal next 3002
# total preictal:  12  total interictal:  12  sequence local:  6
# 3004
# Positive ocurrence sequence finished 2
# sequence preictal next 1002
# 1004
# total preictal:  12  total interictal:  13  sequence local:  1
# total preictal:  12  total interictal:  13  sequence local:  1
# 3005
# 2005
# total preictal:  12  total interictal:  13  sequence local:  1
# 1005
# total preictal:  13  total interictal:  13  sequence local:  1
# 2004
# total preictal:  13  total interictal:  13  sequence local:  1
# 3004
# total preictal:  13  total interictal:  13  sequence local:  1
# 1004
# total preictal:  13  total interictal:  14  sequence local:  2
# 3005
# total preictal:  13  total interictal:  14  sequence local:  2
# 1005
# total preictal:  14  total interictal:  14  sequence local:  2
# total preictal:  13  total interictal:  14  sequence local:  2
# 3004
# 2005
# total preictal:  14  total interictal:  14  sequence local:  2
# 1004
# total preictal:  14  total interictal:  15  sequence local:  3
# total preictal:  14  total interictal:  14  sequence local:  2
# 3005
# 2004
# total preictal:  14  total interictal:  15  sequence local:  3
# 1005
# total preictal:  15  total interictal:  15  sequence local:  3
# 3004
# total preictal:  14  total interictal:  15  sequence local:  3
# 2005
# total preictal:  15  total interictal:  16  sequence local:  4
# 3005
# total preictal:  15  total interictal:  15  sequence local:  3
# 2004
# total preictal:  16  total interictal:  16  sequence local:  4
# 3004
# total preictal:  15  total interictal:  16  sequence local:  4
# 2005
# total preictal:  15  total interictal:  15  sequence local:  3
# 1004
# total preictal:  16  total interictal:  17  sequence local:  5
# 3005
# total preictal:  16  total interictal:  16  sequence local:  4
# 2004
# total preictal:  15  total interictal:  16  sequence local:  4
# 1005
# total preictal:  17  total interictal:  17  sequence local:  5
# 3004
# total preictal:  16  total interictal:  16  sequence local:  4
# total preictal:  16  total interictal:  17  sequence local:  5
# 1004
# 2005
# total preictal:  17  total interictal:  18  sequence local:  6
# Negative ocurrence sequence finished 3
# sequence interictal next 3003
# 3005
# total preictal:  17  total interictal:  17  sequence local:  5
# total preictal:  16  total interictal:  17  sequence local:  5
# 1005
# 2004
# total preictal:  18  total interictal:  18  sequence local:  6
# sequence preictal next 3003
# Positive ocurrence sequence finished 3
# 3006
# total preictal:  17  total interictal:  17  sequence local:  5
# 1004
# total preictal:  17  total interictal:  18  sequence local:  6
# Negative ocurrence sequence finished 3
# sequence interictal next 2003
# 2005
# total preictal:  18  total interictal:  19  sequence local:  1
# 3007
# total preictal:  17  total interictal:  18  sequence local:  6
# Negative ocurrence sequence finished 3
# sequence interictal next 1003
# 1005
# total preictal:  18  total interictal:  18  sequence local:  6
# Positive ocurrence sequence finished 3
# sequence preictal next 2003
# 2006
# total preictal:  19  total interictal:  19  sequence local:  1
# 3006
# total preictal:  18  total interictal:  18  sequence local:  6
# Positive ocurrence sequence finished 3
# sequence preictal next 1003
# 1006
# total preictal:  18  total interictal:  19  sequence local:  1
# 2007
# total preictal:  19  total interictal:  20  sequence local:  2
# 3007
# total preictal:  18  total interictal:  19  sequence local:  1
# 1007
# total preictal:  19  total interictal:  19  sequence local:  1
# 2006
# total preictal:  20  total interictal:  20  sequence local:  2
# 3006
# total preictal:  19  total interictal:  19  sequence local:  1
# 1006
# total preictal:  19  total interictal:  20  sequence local:  2
# 2007
# total preictal:  20  total interictal:  21  sequence local:  3
# 3007
# total preictal:  19  total interictal:  20  sequence local:  2
# 1007
# total preictal:  20  total interictal:  20  sequence local:  2
# 2006
# total preictal:  21  total interictal:  21  sequence local:  3
# 3006
# total preictal:  20  total interictal:  20  sequence local:  2
# 1006
# total preictal:  20  total interictal:  21  sequence local:  3
# total preictal:  21  total interictal:  22  sequence local:  4
# 2007
# 3007
# total preictal:  20  total interictal:  21  sequence local:  3
# 1007
# total preictal:  22  total interictal:  22  sequence local:  4
# total preictal:  21  total interictal:  21  sequence local:  3
# 2006
# 3006
# total preictal:  21  total interictal:  21  sequence local:  3
# 1006
# total preictal:  22  total interictal:  23  sequence local:  5
# 3007
# total preictal:  21  total interictal:  22  sequence local:  4
# 2007
# total preictal:  21  total interictal:  22  sequence local:  4
# 1007
# total preictal:  23  total interictal:  23  sequence local:  5
# 3006
# total preictal:  22  total interictal:  22  sequence local:  4
# 2006
# total preictal:  22  total interictal:  22  sequence local:  4
# 1006
# total preictal:  22  total interictal:  23  sequence local:  5
# total preictal:  23  total interictal:  24  sequence local:  6
# Negative ocurrence sequence finished 4
# sequence interictal next 3004
# 2007
# 3007
# total preictal:  22  total interictal:  23  sequence local:  5
# 1007
# total preictal:  23  total interictal:  23  sequence local:  5
# 2006
# total preictal:  24  total interictal:  24  sequence local:  6
# Positive ocurrence sequence finished 4
# sequence preictal next 3004
# total preictal:  23  total interictal:  23  sequence local:  5
# 1006
# 3008
# total preictal:  23  total interictal:  24  sequence local:  6
# Negative ocurrence sequence finished 4
# sequence interictal next 2004
# 2007
# total preictal:  24  total interictal:  25  sequence local:  1
# 3009
# total preictal:  23  total interictal:  24  sequence local:  6
# Negative ocurrence sequence finished 4
# sequence interictal next 1004
# 1007
# total preictal:  24  total interictal:  24  sequence local:  6
# Positive ocurrence sequence finished 4
# sequence preictal next 2004
# 2008
# total preictal:  25  total interictal:  25  sequence local:  1
# 3008
# total preictal:  24  total interictal:  24  sequence local:  6
# Positive ocurrence sequence finished 4
# sequence preictal next 1004
# 1008
# total preictal:  24  total interictal:  25  sequence local:  1
# 2009
# total preictal:  25  total interictal:  26  sequence local:  2
# 3009
# total preictal:  24  total interictal:  25  sequence local:  1
# 1009
# total preictal:  25  total interictal:  25  sequence local:  1
# 2008
# total preictal:  26  total interictal:  26  sequence local:  2
# 3008
# total preictal:  25  total interictal:  25  sequence local:  1
# 1008
# total preictal:  25  total interictal:  26  sequence local:  2
# 2009
# total preictal:  26  total interictal:  27  sequence local:  3
# 3009
# total preictal:  25  total interictal:  26  sequence local:  2
# 1009
# total preictal:  26  total interictal:  26  sequence local:  2
# 2008
# total preictal:  27  total interictal:  27  sequence local:  3
# 3008
# total preictal:  26  total interictal:  26  sequence local:  2
# 1008
# total preictal:  26  total interictal:  27  sequence local:  3
# 2009
# total preictal:  27  total interictal:  28  sequence local:  4
# 3009
# total preictal:  26  total interictal:  27  sequence local:  3
# 1009
# total preictal:  27  total interictal:  27  sequence local:  3
# 2008
# total preictal:  28  total interictal:  28  sequence local:  4
# 3008
# total preictal:  27  total interictal:  28  sequence local:  4
# total preictal:  27  total interictal:  27  sequence local:  3
# 1008
# 2009
# total preictal:  28  total interictal:  29  sequence local:  5
# 3009
# total preictal:  28  total interictal:  28  sequence local:  4
# 2008
# total preictal:  27  total interictal:  28  sequence local:  4
# total preictal:  29  total interictal:  29  sequence local:  5
# Test CSV for patient 2 has been completed...
# 3008
# 1009
# total preictal:  28  total interictal:  29  sequence local:  5
# total preictal:  29  total interictal:  30  sequence local:  6
# Negative ocurrence sequence finished 5
# sequence interictal next 3005
# 2009
# 3009
# total preictal:  28  total interictal:  28  sequence local:  4
# 1008
# total preictal:  29  total interictal:  29  sequence local:  5
# total preictal:  30  total interictal:  30  sequence local:  6
# Positive ocurrence sequence finished 5
# sequence preictal next 3005
# 2008
# 3010
# total preictal:  28  total interictal:  29  sequence local:  5
# 1009
# total preictal:  30  total interictal:  31  sequence local:  1
# total preictal:  29  total interictal:  30  sequence local:  6
# Negative ocurrence sequence finished 5
# sequence interictal next 2005
# 3011
# 2009
# total preictal:  29  total interictal:  29  sequence local:  5
# 1008
# Test CSV for patient 3 has been completed...
# total preictal:  30  total interictal:  30  sequence local:  6
# Positive ocurrence sequence finished 5
# sequence preictal next 2005
# 2010
# total preictal:  31  total interictal:  31  sequence local:  1
# 3010
# total preictal:  29  total interictal:  30  sequence local:  6
# Negative ocurrence sequence finished 5
# sequence interictal next 1005
# 1009
# total preictal:  30  total interictal:  31  sequence local:  1
# 2011
# total preictal:  31  total interictal:  32  sequence local:  2
# 3011
# total preictal:  30  total interictal:  30  sequence local:  6
# Positive ocurrence sequence finished 5
# sequence preictal next 1005
# 1010
# Test CSV for patient 1 has been completed...
# total preictal:  31  total interictal:  31  sequence local:  1
# 2010
# total preictal:  32  total interictal:  32  sequence local:  2
# 3010
# total preictal:  30  total interictal:  31  sequence local:  1
# 1011
# total preictal:  31  total interictal:  32  sequence local:  2
# 2011
# total preictal:  32  total interictal:  33  sequence local:  3
# 3011
# total preictal:  31  total interictal:  31  sequence local:  1
# 1010
# total preictal:  32  total interictal:  32  sequence local:  2
# 2010
# total preictal:  33  total interictal:  33  sequence local:  3
# 3010
# total preictal:  31  total interictal:  32  sequence local:  2
# 1011
# total preictal:  32  total interictal:  33  sequence local:  3
# 2011
# total preictal:  33  total interictal:  34  sequence local:  4
# 3011
# total preictal:  32  total interictal:  32  sequence local:  2
# 1010
# total preictal:  33  total interictal:  33  sequence local:  3
# 2010
# total preictal:  34  total interictal:  34  sequence local:  4
# 3010
# total preictal:  32  total interictal:  33  sequence local:  3
# 1011
# total preictal:  33  total interictal:  34  sequence local:  4
# 2011
# total preictal:  34  total interictal:  35  sequence local:  5
# 3011
# total preictal:  33  total interictal:  33  sequence local:  3
# 1010
# total preictal:  34  total interictal:  34  sequence local:  4
# 2010
# total preictal:  35  total interictal:  35  sequence local:  5
# 3010
# total preictal:  33  total interictal:  34  sequence local:  4
# 1011
# total preictal:  34  total interictal:  35  sequence local:  5
# 2011
# total preictal:  35  total interictal:  36  sequence local:  6
# Negative ocurrence sequence finished 6
# sequence interictal next 3006
# 3011
# total preictal:  34  total interictal:  34  sequence local:  4
# 1010
# total preictal:  35  total interictal:  35  sequence local:  5
# 2010
# total preictal:  36  total interictal:  36  sequence local:  6
# Positive ocurrence sequence finished 6
# sequence preictal next 3006
# 3012
# total preictal:  34  total interictal:  35  sequence local:  5
# 1011
# total preictal:  35  total interictal:  36  sequence local:  6
# Negative ocurrence sequence finished 6
# sequence interictal next 2006
# 2011
# total preictal:  36  total interictal:  37  sequence local:  1
# 3013
# total preictal:  36  total interictal:  36  sequence local:  6
# Positive ocurrence sequence finished 6
# sequence preictal next 2006
# 2012
# total preictal:  37  total interictal:  37  sequence local:  1
# 3012
# total preictal:  36  total interictal:  37  sequence local:  1
# 2013
# total preictal:  37  total interictal:  38  sequence local:  2
# 3013
# total preictal:  37  total interictal:  37  sequence local:  1
# 2012
# total preictal:  38  total interictal:  38  sequence local:  2
# 3012
# total preictal:  37  total interictal:  38  sequence local:  2
# 2013
# total preictal:  38  total interictal:  39  sequence local:  3
# 3013
# total preictal:  38  total interictal:  38  sequence local:  2
# 2012
# total preictal:  39  total interictal:  39  sequence local:  3
# 3012
# total preictal:  38  total interictal:  39  sequence local:  3
# 2013
# total preictal:  35  total interictal:  35  sequence local:  5
# 1010
# total preictal:  39  total interictal:  40  sequence local:  4
# 3013
# total preictal:  39  total interictal:  39  sequence local:  3
# 2012
# total preictal:  35  total interictal:  36  sequence local:  6
# Negative ocurrence sequence finished 6
# sequence interictal next 1006
# 1011
# total preictal:  40  total interictal:  40  sequence local:  4
# 3012
# total preictal:  39  total interictal:  40  sequence local:  4
# 2013
# total preictal:  36  total interictal:  36  sequence local:  6
# Positive ocurrence sequence finished 6
# sequence preictal next 1006
# 1012
# total preictal:  40  total interictal:  41  sequence local:  5
# 3013
# total preictal:  40  total interictal:  40  sequence local:  4
# 2012
# total preictal:  37  total interictal:  36  sequence local:  1
# 1012
# total preictal:  41  total interictal:  41  sequence local:  5
# 3012
# total preictal:  40  total interictal:  41  sequence local:  5
# 2013
# total preictal:  38  total interictal:  36  sequence local:  2
# 1012
# total preictal:  41  total interictal:  42  sequence local:  6
# Negative ocurrence sequence finished 7
# sequence interictal next 3007
# 3013
# total preictal:  41  total interictal:  41  sequence local:  5
# 2012
# total preictal:  39  total interictal:  36  sequence local:  3
# 1012
# total preictal:  42  total interictal:  42  sequence local:  6
# Positive ocurrence sequence finished 7
# sequence preictal next 3007
# 3014
# total preictal:  41  total interictal:  42  sequence local:  6
# Negative ocurrence sequence finished 7
# sequence interictal next 2007
# 2013
# total preictal:  42  total interictal:  43  sequence local:  1
# 3015
# total preictal:  42  total interictal:  42  sequence local:  6
# Positive ocurrence sequence finished 7
# sequence preictal next 2007
# 2014
# total preictal:  43  total interictal:  43  sequence local:  1
# 3014
# total preictal:  42  total interictal:  43  sequence local:  1
# 2015
# total preictal:  43  total interictal:  44  sequence local:  2
# 3015
# total preictal:  43  total interictal:  43  sequence local:  1
# 2014
# total preictal:  44  total interictal:  44  sequence local:  2
# 3014
# total preictal:  43  total interictal:  44  sequence local:  2
# 2015
# total preictal:  44  total interictal:  45  sequence local:  3
# 3015
# total preictal:  44  total interictal:  44  sequence local:  2
# 2014
# total preictal:  40  total interictal:  36  sequence local:  4
# 1012
# total preictal:  45  total interictal:  45  sequence local:  3
# 3014
# total preictal:  44  total interictal:  45  sequence local:  3
# 2015
# total preictal:  41  total interictal:  36  sequence local:  5
# 1012
# total preictal:  45  total interictal:  46  sequence local:  4
# 3015
# total preictal:  45  total interictal:  45  sequence local:  3
# 2014
# total preictal:  42  total interictal:  36  sequence local:  6
# Positive ocurrence sequence finished 7
# sequence preictal next 1007
# 1013
# total preictal:  46  total interictal:  46  sequence local:  4
# 3014
# total preictal:  45  total interictal:  46  sequence local:  4
# 2015
# total preictal:  43  total interictal:  36  sequence local:  1
# 1013
# total preictal:  46  total interictal:  47  sequence local:  5
# 3015
# total preictal:  46  total interictal:  46  sequence local:  4
# 2014
# total preictal:  44  total interictal:  36  sequence local:  2
# 1013
# total preictal:  47  total interictal:  47  sequence local:  5
# 3014
# total preictal:  46  total interictal:  47  sequence local:  5
# 2015
# total preictal:  45  total interictal:  36  sequence local:  3
# 1013
# total preictal:  47  total interictal:  48  sequence local:  6
# Negative ocurrence sequence finished 8
# sequence interictal next 3008
# 3015
# total preictal:  47  total interictal:  47  sequence local:  5
# 2014
# total preictal:  46  total interictal:  36  sequence local:  4
# 1013
# total preictal:  48  total interictal:  48  sequence local:  6
# Positive ocurrence sequence finished 8
# sequence preictal next 3008
# 3016
# total preictal:  47  total interictal:  48  sequence local:  6
# Negative ocurrence sequence finished 8
# sequence interictal next 2008
# 2015
# total preictal:  47  total interictal:  36  sequence local:  5
# 1013
# total preictal:  48  total interictal:  49  sequence local:  1
# 3017
# total preictal:  48  total interictal:  48  sequence local:  6
# Positive ocurrence sequence finished 8
# sequence preictal next 2008
# 2016
# total preictal:  48  total interictal:  36  sequence local:  6
# Positive ocurrence sequence finished 8
# sequence preictal next 1008
# 1014
# total preictal:  48  total interictal:  49  sequence local:  1
# total preictal:  49  total interictal:  49  sequence local:  1
# 2017
# 3016
# total preictal:  49  total interictal:  36  sequence local:  1
# 1014
# total preictal:  49  total interictal:  49  sequence local:  1
# total preictal:  49  total interictal:  50  sequence local:  2
# 3017
# 2016
# total preictal:  50  total interictal:  36  sequence local:  2
# 1014
# total preictal:  50  total interictal:  50  sequence local:  2
# 3016
# total preictal:  49  total interictal:  50  sequence local:  2
# 2017
# total preictal:  51  total interictal:  36  sequence local:  3
# 1014
# total preictal:  50  total interictal:  51  sequence local:  3
# 3017
# total preictal:  50  total interictal:  50  sequence local:  2
# 2016
# total preictal:  52  total interictal:  36  sequence local:  4
# 1014
# total preictal:  51  total interictal:  51  sequence local:  3
# 3016
# total preictal:  50  total interictal:  51  sequence local:  3
# 2017
# total preictal:  53  total interictal:  36  sequence local:  5
# 1014
# total preictal:  51  total interictal:  52  sequence local:  4
# 3017
# total preictal:  51  total interictal:  51  sequence local:  3
# 2016
# total preictal:  54  total interictal:  36  sequence local:  6
# Positive ocurrence sequence finished 9
# sequence preictal next 1009
# 1015
# total preictal:  51  total interictal:  52  sequence local:  4
# 2017
# total preictal:  55  total interictal:  36  sequence local:  1
# 1015
# total preictal:  52  total interictal:  52  sequence local:  4
# 2016
# total preictal:  56  total interictal:  36  sequence local:  2
# 1015
# total preictal:  52  total interictal:  53  sequence local:  5
# 2017
# total preictal:  53  total interictal:  53  sequence local:  5
# 2016
# total preictal:  57  total interictal:  36  sequence local:  3
# 1015
# total preictal:  53  total interictal:  54  sequence local:  6
# Negative ocurrence sequence finished 9
# sequence interictal next 2009
# 2017
# total preictal:  58  total interictal:  36  sequence local:  4
# 1015
# total preictal:  54  total interictal:  54  sequence local:  6
# Positive ocurrence sequence finished 9
# sequence preictal next 2009
# 2018
# total preictal:  59  total interictal:  36  sequence local:  5
# 1015
# total preictal:  54  total interictal:  55  sequence local:  1
# 2019
# total preictal:  52  total interictal:  52  sequence local:  4
# 3016
# total preictal:  60  total interictal:  36  sequence local:  6
# Positive ocurrence sequence finished 10
# sequence preictal next 1010
# 1016
# total preictal:  55  total interictal:  55  sequence local:  1
# 2018
# total preictal:  52  total interictal:  53  sequence local:  5
# 3017
# total preictal:  60  total interictal:  37  sequence local:  1
# 1016
# total preictal:  55  total interictal:  56  sequence local:  2
# 2019
# total preictal:  53  total interictal:  53  sequence local:  5
# 3016
# total preictal:  60  total interictal:  38  sequence local:  2
# 1016
# total preictal:  56  total interictal:  56  sequence local:  2
# 2018
# total preictal:  53  total interictal:  54  sequence local:  6
# Negative ocurrence sequence finished 9
# sequence interictal next 3009
# 3017
# total preictal:  60  total interictal:  39  sequence local:  3
# 1016
# total preictal:  56  total interictal:  57  sequence local:  3
# 2019
# total preictal:  54  total interictal:  54  sequence local:  6
# Positive ocurrence sequence finished 9
# sequence preictal next 3009
# 3018
# total preictal:  60  total interictal:  40  sequence local:  4
# 1016
# total preictal:  57  total interictal:  57  sequence local:  3
# 2018
# total preictal:  54  total interictal:  55  sequence local:  1
# 3019
# total preictal:  60  total interictal:  41  sequence local:  5
# 1016
# total preictal:  55  total interictal:  55  sequence local:  1
# 3018
# total preictal:  60  total interictal:  42  sequence local:  6
# Negative ocurrence sequence finished 7
# sequence interictal next 1007
# 1017
# total preictal:  55  total interictal:  56  sequence local:  2
# 3019
# total preictal:  60  total interictal:  43  sequence local:  1
# 1017
# total preictal:  56  total interictal:  56  sequence local:  2
# 3018
# total preictal:  60  total interictal:  44  sequence local:  2
# 1017
# total preictal:  56  total interictal:  57  sequence local:  3
# 3019
# total preictal:  60  total interictal:  45  sequence local:  3
# 1017
# total preictal:  57  total interictal:  57  sequence local:  3
# total preictal:  60  total interictal:  46  sequence local:  4
# 3018
# 1017
# total preictal:  57  total interictal:  58  sequence local:  4
# 2019
# total preictal:  57  total interictal:  58  sequence local:  4
# 3019
# total preictal:  60  total interictal:  47  sequence local:  5
# 1017
# total preictal:  58  total interictal:  58  sequence local:  4
# 2018
# total preictal:  58  total interictal:  58  sequence local:  4
# total preictal:  60  total interictal:  48  sequence local:  6
# Negative ocurrence sequence finished 8
# sequence interictal next 1008
# Train CSV for patient 1 has been completed...
# 3018
# total preictal:  58  total interictal:  59  sequence local:  5
# 2019
# total preictal:  58  total interictal:  59  sequence local:  5
# 3019
# total preictal:  59  total interictal:  59  sequence local:  5
# 2018
# total preictal:  59  total interictal:  59  sequence local:  5
# 3018
# total preictal:  59  total interictal:  60  sequence local:  6
# Negative ocurrence sequence finished 10
# sequence interictal next 2010
# 2019
# total preictal:  59  total interictal:  60  sequence local:  6
# Negative ocurrence sequence finished 10
# sequence interictal next 3010
# 3019
# total preictal:  60  total interictal:  60  sequence local:  6
# Positive ocurrence sequence finished 10
# sequence preictal next 2010
# 2020
# total preictal:  60  total interictal:  60  sequence local:  6
# Positive ocurrence sequence finished 10
# sequence preictal next 3010
# 3020
# total preictal:  60  total interictal:  61  sequence local:  1
# 2020
# total preictal:  60  total interictal:  61  sequence local:  1
# 3020
# total preictal:  60  total interictal:  62  sequence local:  2
# 2020
# total preictal:  60  total interictal:  62  sequence local:  2
# 3020
# total preictal:  60  total interictal:  63  sequence local:  3
# 2020
# total preictal:  60  total interictal:  63  sequence local:  3
# 3020
# total preictal:  60  total interictal:  64  sequence local:  4
# 2020
# total preictal:  60  total interictal:  64  sequence local:  4
# 3020
# total preictal:  60  total interictal:  65  sequence local:  5
# 2020
# total preictal:  60  total interictal:  65  sequence local:  5
# 3020
# total preictal:  60  total interictal:  66  sequence local:  6
# Negative ocurrence sequence finished 11
# sequence interictal next 2011
# 2021
# total preictal:  60  total interictal:  66  sequence local:  6
# Negative ocurrence sequence finished 11
# sequence interictal next 3011
# 3021
# total preictal:  60  total interictal:  67  sequence local:  1
# 2021
# total preictal:  60  total interictal:  67  sequence local:  1
# 3021
# total preictal:  60  total interictal:  68  sequence local:  2
# 2021
# total preictal:  60  total interictal:  68  sequence local:  2
# 3021
# total preictal:  60  total interictal:  69  sequence local:  3
# 2021
# total preictal:  60  total interictal:  69  sequence local:  3
# 3021
# total preictal:  60  total interictal:  70  sequence local:  4
# 2021
# total preictal:  60  total interictal:  70  sequence local:  4
# 3021
# total preictal:  60  total interictal:  71  sequence local:  5
# 2021
# total preictal:  60  total interictal:  71  sequence local:  5
# 3021
# total preictal:  60  total interictal:  72  sequence local:  6
# Negative ocurrence sequence finished 12
# sequence interictal next 2012
# 2022
# total preictal:  60  total interictal:  72  sequence local:  6
# Negative ocurrence sequence finished 12
# sequence interictal next 3012
# 3022
# total preictal:  60  total interictal:  73  sequence local:  1
# 2022
# total preictal:  60  total interictal:  73  sequence local:  1
# 3022
# total preictal:  60  total interictal:  74  sequence local:  2
# 2022
# total preictal:  60  total interictal:  74  sequence local:  2
# 3022
# total preictal:  60  total interictal:  75  sequence local:  3
# 2022
# total preictal:  60  total interictal:  75  sequence local:  3
# 3022
# total preictal:  60  total interictal:  76  sequence local:  4
# 2022
# total preictal:  60  total interictal:  76  sequence local:  4
# 3022
# total preictal:  60  total interictal:  77  sequence local:  5
# 2022
# total preictal:  60  total interictal:  77  sequence local:  5
# 3022
# total preictal:  60  total interictal:  78  sequence local:  6
# Negative ocurrence sequence finished 13
# sequence interictal next 2013
# 2023
# total preictal:  60  total interictal:  78  sequence local:  6
# Negative ocurrence sequence finished 13
# sequence interictal next 3013
# 3023
# total preictal:  60  total interictal:  79  sequence local:  1
# 2023
# total preictal:  60  total interictal:  79  sequence local:  1
# 3023
# total preictal:  60  total interictal:  80  sequence local:  2
# 2023
# total preictal:  60  total interictal:  80  sequence local:  2
# 3023
# total preictal:  60  total interictal:  81  sequence local:  3
# 2023
# total preictal:  60  total interictal:  81  sequence local:  3
# 3023
# total preictal:  60  total interictal:  82  sequence local:  4
# 2023
# total preictal:  60  total interictal:  82  sequence local:  4
# 3023
# total preictal:  60  total interictal:  83  sequence local:  5
# 2023
# total preictal:  60  total interictal:  83  sequence local:  5
# 3023
# total preictal:  60  total interictal:  84  sequence local:  6
# Negative ocurrence sequence finished 14
# sequence interictal next 2014
# 2024
# total preictal:  60  total interictal:  84  sequence local:  6
# Negative ocurrence sequence finished 14
# sequence interictal next 3014
# 3024
# total preictal:  60  total interictal:  85  sequence local:  1
# 2024
# total preictal:  60  total interictal:  85  sequence local:  1
# 3024
# total preictal:  60  total interictal:  86  sequence local:  2
# 2024
# total preictal:  60  total interictal:  86  sequence local:  2
# 3024
# total preictal:  60  total interictal:  87  sequence local:  3
# 2024
# total preictal:  60  total interictal:  87  sequence local:  3
# 3024
# total preictal:  60  total interictal:  88  sequence local:  4
# 2024
# total preictal:  60  total interictal:  88  sequence local:  4
# 3024
# total preictal:  60  total interictal:  89  sequence local:  5
# 2024
# total preictal:  60  total interictal:  89  sequence local:  5
# 3024
# total preictal:  60  total interictal:  90  sequence local:  6
# Negative ocurrence sequence finished 15
# sequence interictal next 2015
# 2025
# total preictal:  60  total interictal:  90  sequence local:  6
# Negative ocurrence sequence finished 15
# sequence interictal next 3015
# 3025
# total preictal:  60  total interictal:  91  sequence local:  1
# 2025
# total preictal:  60  total interictal:  91  sequence local:  1
# 3025
# total preictal:  60  total interictal:  92  sequence local:  2
# 2025
# total preictal:  60  total interictal:  92  sequence local:  2
# 3025
# total preictal:  60  total interictal:  93  sequence local:  3
# 2025
# total preictal:  60  total interictal:  93  sequence local:  3
# 3025
# total preictal:  60  total interictal:  94  sequence local:  4
# 2025
# total preictal:  60  total interictal:  94  sequence local:  4
# 3025
# total preictal:  60  total interictal:  95  sequence local:  5
# 2025
# total preictal:  60  total interictal:  95  sequence local:  5
# 3025
# total preictal:  60  total interictal:  96  sequence local:  6
# Negative ocurrence sequence finished 16
# sequence interictal next 2016
# 2026
# total preictal:  60  total interictal:  96  sequence local:  6
# Negative ocurrence sequence finished 16
# sequence interictal next 3016
# 3026
# total preictal:  60  total interictal:  97  sequence local:  1
# 2026
# total preictal:  60  total interictal:  97  sequence local:  1
# 3026
# total preictal:  60  total interictal:  98  sequence local:  2
# 2026
# total preictal:  60  total interictal:  98  sequence local:  2
# 3026
# total preictal:  60  total interictal:  99  sequence local:  3
# 2026
# total preictal:  60  total interictal:  99  sequence local:  3
# 3026
# total preictal:  60  total interictal:  100  sequence local:  4
# 2026
# total preictal:  60  total interictal:  100  sequence local:  4
# 3026
# total preictal:  60  total interictal:  101  sequence local:  5
# 2026
# total preictal:  60  total interictal:  101  sequence local:  5
# 3026
# total preictal:  60  total interictal:  102  sequence local:  6
# Negative ocurrence sequence finished 17
# sequence interictal next 2017
# 2027
# total preictal:  60  total interictal:  102  sequence local:  6
# Negative ocurrence sequence finished 17
# sequence interictal next 3017
# Train CSV for patient 3 has been completed...
# total preictal:  60  total interictal:  103  sequence local:  1
# 2027
# total preictal:  60  total interictal:  104  sequence local:  2
# 2027
# total preictal:  60  total interictal:  105  sequence local:  3
# 2027
# total preictal:  60  total interictal:  106  sequence local:  4
# 2027
# total preictal:  60  total interictal:  107  sequence local:  5
# 2027
# total preictal:  60  total interictal:  108  sequence local:  6
# Negative ocurrence sequence finished 18
# sequence interictal next 2018
# Train CSV for patient 2 has been completed...

# %% [markdown]
# ## Reading Feature Files

# %%
feature_model=3
short_size=False
num_features=12
new_test=True

if __name__ == '__main__':
    print('XGBoost: {}'.format(xgb.__version__))
    
    train, test, features = read_test_train(feature_model, short_size, new_test)
    print('Length of train: ', len(train))
    print('Length of test: ', len(test))
    print('Features [{}]: {}'.format(len(features), sorted(features)))
    
#   print ('train',train['sequence_id'])
# Out:
# XGBoost: 0.6
# Load train.csv...
# Load test.csv...
# Process tables...
# Length of train:  4698
# Length of test:  1908
# Features [194]: ['ch_0_band_0', 'ch_0_band_1', 'ch_0_band_10', 'ch_0_band_11', 'ch_0_band_2', 'ch_0_band_3', 'ch_0_band_4', 'ch_0_band_5', 'ch_0_band_6', 'ch_0_band_7', 'ch_0_band_8', 'ch_0_band_9', 'ch_10_band_0', 'ch_10_band_1', 'ch_10_band_10', 'ch_10_band_11', 'ch_10_band_2', 'ch_10_band_3', 'ch_10_band_4', 'ch_10_band_5', 'ch_10_band_6', 'ch_10_band_7', 'ch_10_band_8', 'ch_10_band_9', 'ch_11_band_0', 'ch_11_band_1', 'ch_11_band_10', 'ch_11_band_11', 'ch_11_band_2', 'ch_11_band_3', 'ch_11_band_4', 'ch_11_band_5', 'ch_11_band_6', 'ch_11_band_7', 'ch_11_band_8', 'ch_11_band_9', 'ch_12_band_0', 'ch_12_band_1', 'ch_12_band_10', 'ch_12_band_11', 'ch_12_band_2', 'ch_12_band_3', 'ch_12_band_4', 'ch_12_band_5', 'ch_12_band_6', 'ch_12_band_7', 'ch_12_band_8', 'ch_12_band_9', 'ch_13_band_0', 'ch_13_band_1', 'ch_13_band_10', 'ch_13_band_11', 'ch_13_band_2', 'ch_13_band_3', 'ch_13_band_4', 'ch_13_band_5', 'ch_13_band_6', 'ch_13_band_7', 'ch_13_band_8', 'ch_13_band_9', 'ch_14_band_0', 'ch_14_band_1', 'ch_14_band_10', 'ch_14_band_11', 'ch_14_band_2', 'ch_14_band_3', 'ch_14_band_4', 'ch_14_band_5', 'ch_14_band_6', 'ch_14_band_7', 'ch_14_band_8', 'ch_14_band_9', 'ch_15_band_0', 'ch_15_band_1', 'ch_15_band_10', 'ch_15_band_11', 'ch_15_band_2', 'ch_15_band_3', 'ch_15_band_4', 'ch_15_band_5', 'ch_15_band_6', 'ch_15_band_7', 'ch_15_band_8', 'ch_15_band_9', 'ch_1_band_0', 'ch_1_band_1', 'ch_1_band_10', 'ch_1_band_11', 'ch_1_band_2', 'ch_1_band_3', 'ch_1_band_4', 'ch_1_band_5', 'ch_1_band_6', 'ch_1_band_7', 'ch_1_band_8', 'ch_1_band_9', 'ch_2_band_0', 'ch_2_band_1', 'ch_2_band_10', 'ch_2_band_11', 'ch_2_band_2', 'ch_2_band_3', 'ch_2_band_4', 'ch_2_band_5', 'ch_2_band_6', 'ch_2_band_7', 'ch_2_band_8', 'ch_2_band_9', 'ch_3_band_0', 'ch_3_band_1', 'ch_3_band_10', 'ch_3_band_11', 'ch_3_band_2', 'ch_3_band_3', 'ch_3_band_4', 'ch_3_band_5', 'ch_3_band_6', 'ch_3_band_7', 'ch_3_band_8', 'ch_3_band_9', 'ch_4_band_0', 'ch_4_band_1', 'ch_4_band_10', 'ch_4_band_11', 'ch_4_band_2', 'ch_4_band_3', 'ch_4_band_4', 'ch_4_band_5', 'ch_4_band_6', 'ch_4_band_7', 'ch_4_band_8', 'ch_4_band_9', 'ch_5_band_0', 'ch_5_band_1', 'ch_5_band_10', 'ch_5_band_11', 'ch_5_band_2', 'ch_5_band_3', 'ch_5_band_4', 'ch_5_band_5', 'ch_5_band_6', 'ch_5_band_7', 'ch_5_band_8', 'ch_5_band_9', 'ch_6_band_0', 'ch_6_band_1', 'ch_6_band_10', 'ch_6_band_11', 'ch_6_band_2', 'ch_6_band_3', 'ch_6_band_4', 'ch_6_band_5', 'ch_6_band_6', 'ch_6_band_7', 'ch_6_band_8', 'ch_6_band_9', 'ch_7_band_0', 'ch_7_band_1', 'ch_7_band_10', 'ch_7_band_11', 'ch_7_band_2', 'ch_7_band_3', 'ch_7_band_4', 'ch_7_band_5', 'ch_7_band_6', 'ch_7_band_7', 'ch_7_band_8', 'ch_7_band_9', 'ch_8_band_0', 'ch_8_band_1', 'ch_8_band_10', 'ch_8_band_11', 'ch_8_band_2', 'ch_8_band_3', 'ch_8_band_4', 'ch_8_band_5', 'ch_8_band_6', 'ch_8_band_7', 'ch_8_band_8', 'ch_8_band_9', 'ch_9_band_0', 'ch_9_band_1', 'ch_9_band_10', 'ch_9_band_11', 'ch_9_band_2', 'ch_9_band_3', 'ch_9_band_4', 'ch_9_band_5', 'ch_9_band_6', 'ch_9_band_7', 'ch_9_band_8', 'ch_9_band_9', 'file_size', 'patient_id']

# %% [markdown]
# ## Module for Training and Prediction

# %%
def run_train_predict(nfolds, train, test, features, target, random_state=2016, PCAkey=False, SEQoriginal=False,
                     Oversampling=False):

    num_boost_round = 1000
    early_stopping_rounds = 50
    
    train_index_group=[]
    test_index_group=[]
    
    
    unique_seq = train.drop_duplicates(subset=['sequence_id'])
    unique_seq_y = unique_seq['result'].values
    
    n_samples=len(unique_seq_y)
    print('length',n_samples)
    unique_seq_X = np.zeros(n_samples)
    
    
    
    
    print('train pre', train.shape) 

    yfull_train = dict()
    yfull_test = copy.deepcopy(test[['Id']].astype(object))

    unique_sequences = np.array(train['sequence_id'].unique())
    print('unique sequences pre', unique_sequences.shape)

    groups1=np.fix(unique_sequences/1000)
    
    groups2=groups1.astype(int)
#    print('groups', groups2)
    

    
    if SEQoriginal:
        sequences_full=np.mod(train['sequence_id'].values,1000)
        print('sequences full', sequences_full.shape)
        unique_sequences2=np.mod(unique_sequences,1000)
        unique_sequences_fold=pd.Series(sequences_full, index=train['sequence_id'].index)
#        print('unique_sequences_fold', unique_sequences_fold)
    
        unique_sequences = np.unique(unique_sequences2)
        print('unique sequences pre', unique_sequences.shape)

    else:
        unique_sequences_fold=pd.Series(train['sequence_id'], index=train['sequence_id'].index)

    gkf = GroupKFold(n_splits=3)
    test1=gkf.split(unique_sequences, groups=groups2)
    test2=gkf.split(unique_sequences, groups=groups2)
    
    #random_state=random_state
    print('unique sequences', unique_sequences.shape)
#    splitKF = KFold(len(unique_sequences), n_folds=nfolds, shuffle=True, random_state=random_state)
#    kf = NewKF(n_splits=nfolds, shuffle=True, random_state=random_state)
    kf = StratKF(n_splits=nfolds, shuffle=True, random_state=random_state)
    
    num_fold = 0
    num_fold1=0
    
    eta = 0.2
    max_depth = 3
    subsample = 0.9
    colsample_bytree = 0.9
    start_time = time.time()

    print('XGBoost params. ETA: {}, MAX_DEPTH: {}, SUBSAMPLE: {}, COLSAMPLE_BY_TREE: {}'.format(eta, max_depth, subsample, colsample_bytree))
    params = {
        "objective": "binary:logistic",
        "booster" : "gbtree",
        "eval_metric": "auc",
        "eta": eta,
        "tree_method": 'exact',
        "max_depth": max_depth,
        "subsample": subsample,
        "colsample_bytree": colsample_bytree,
        "silent": 1,
        "seed": random_state,
#        "gamma": 0,
        "min_child_weight": 1,
        "scale_pos_weight":1
    }

    
#   Using best parameters to train model    
    
    splitKF=kf.split(unique_seq_X, unique_seq_y)
    
    for train_seq_index, test_seq_index in splitKF:
        num_fold += 1
        print('Start fold {} from {}'.format(num_fold, nfolds))
        train_seq = unique_sequences[train_seq_index]
        valid_seq = unique_sequences[test_seq_index]
        print('Length of train people: {}'.format(len(train_seq)))
        print('Length of valid people: {}'.format(len(valid_seq)))
        
#        print('train_seq',train_seq)
#        print('valid_seq',valid_seq)

        X_train, X_valid = train[unique_sequences_fold.isin(train_seq)][features], train[unique_sequences_fold.isin(valid_seq)][features]
        y_train, y_valid = train[unique_sequences_fold.isin(train_seq)][target], train[unique_sequences_fold.isin(valid_seq)][target]
        X_test = test[features]
        
#        print('X_train',X_train)
#        print('y_train',y_train)

        print('Length train:', len(X_train))
        print('Length valid:', len(X_valid))
        
#       Scaling for PCA

        if PCAkey:
        
            scaler = MinMaxScaler()   
        
            Xtrain_scaled=pd.DataFrame(scaler.fit_transform(X_train), columns=X_train.columns, index=X_train.index)
            Xvalid_scaled=pd.DataFrame(scaler.fit_transform(X_valid), columns=X_valid.columns, index=X_valid.index )

            Xtest_scaled=pd.DataFrame(scaler.fit_transform(X_test), columns=X_test.columns, index=X_test.index)
        

        
#       PCA transformation 
            pcatest=PCA(n_components=40)
            X_train_f=pd.DataFrame(pcatest.fit_transform(Xtrain_scaled), index=Xtrain_scaled.index)
            X_valid_f=pd.DataFrame(pcatest.fit_transform(Xvalid_scaled), index=Xvalid_scaled.index)

            X_test_f=pd.DataFrame(pcatest.fit_transform(Xtest_scaled), index=Xtest_scaled.index)

        else:
            X_train_f=X_train
            X_valid_f=X_valid
            X_test_f=X_test
                
        
        y_train_f=y_train
        y_valid_f=y_valid
    
#       SMOTE oversampling
        
#        print('Original dataset shape {}'.format(Counter(y_train)))
#        print('Original dataset shape {}'.format(Counter(X_train_f)))
#        print(X_train_f)
#        print(y_train)

        if Oversampling:
        
            sm1 = SMOTETomek(random_state=42)
            X_res,y_res = sm1.fit_sample(X_train_f,y_train)
            X_train_f=pd.DataFrame(X_res, columns=X_train_f.columns)
            y_train=pd.Series(y_res)
        
#        print('Resampled dataset shape {}'.format(Counter(y_train)))
#        print(X_train_f)
#        print(y_train)
    
    
        
#       Preparation for XGB training

        dtrain = xgb.DMatrix(X_train_f, y_train)
        dvalid = xgb.DMatrix(X_valid_f, y_valid)

        watchlist = [(dtrain, 'train'), (dvalid, 'eval')]       
        
        gbm = xgb.train(params, dtrain, num_boost_round, evals=watchlist, early_stopping_rounds=early_stopping_rounds, verbose_eval=500)

        yhat = gbm.predict(xgb.DMatrix(X_valid_f), ntree_limit=gbm.best_iteration+1)

#       Each time store portion of precicted data in train predicted values

        for i in range(len(X_valid_f.index)):
            yfull_train[X_valid_f.index[i]] = yhat[i]
            
        print("Validating...")
        check = gbm.predict(xgb.DMatrix(X_valid_f), ntree_limit=gbm.best_iteration+1)
        score = roc_auc_score(y_valid.tolist(), check)
        print('Check error value: {:.6f}'.format(score))

        print("Predict test set...")
        test_prediction1 = gbm.predict(xgb.DMatrix(X_test_f), ntree_limit=gbm.best_iteration+1)
        yfull_test['kfold_' + str(num_fold)] = test_prediction1
        
              

    print('iteration finished')
    # Copy dict to list
    train_res = []
    
    for i in range(len(train.index)):
        train_res.append(yfull_train[i])

    score = roc_auc_score(train[target], np.array(train_res))
    print('Check error value: {:.6f}'.format(score))

    # Find mean for KFolds on test
    merge = []
    for i in range(1, nfolds+1):
        merge.append('kfold_' + str(i))
    yfull_test['mean'] = yfull_test[merge].mean(axis=1)
    
    print()

    print('Training time: {} minutes'.format(round((time.time() - start_time)/60, 2)))
    return yfull_test['mean'].values, score

# %% [markdown]
# ## Module for Grid Search

# %%
def run_param_search(nfolds, train, test, features, target, random_state=2016,  PCAkey=False, SEQoriginal=False):

    num_boost_round = 1000
    early_stopping_rounds = 50
    
    train_index_group=[]
    test_index_group=[]
    

    
    yfull_train = dict()
    yfull_test = copy.deepcopy(test[['Id']].astype(object))
    print('train sequences',train['sequence_id'])
    
    
    unique_sequences = np.array(train['sequence_id'].unique())
#    print('unique sequences', unique_sequences, len(unique_sequences))
    
    groups1=np.fix(unique_sequences/1000)
    
    groups2=groups1.astype(int)
#    print('groups', groups2)
    
    gkf = GroupKFold(n_splits=3)
    test1=gkf.split(unique_sequences, groups=groups2)
    test2=gkf.split(unique_sequences, groups=groups2)
    
    
    if SEQoriginal:
        sequences_full=np.mod(train['sequence_id'].values,1000)
        unique_sequences2=np.mod(unique_sequences,1000)
        unique_sequences_fold=pd.Series(sequences_full, index=train['sequence_id'].index)
#        print('unique_sequences_fold', unique_sequences_fold)
    
        unique_sequences = np.unique(unique_sequences2)

    else:
        unique_sequences_fold=pd.Series(train['sequence_id'], index=train['sequence_id'].index)

    
    kf = KFold(len(unique_sequences), n_folds=nfolds, shuffle=True, random_state=random_state)
    num_fold = 0
    num_fold1=0
    
    
    
    
#   param_test1 = {'max_depth': [3,5]}
#   param_test1 = {'max_depth': [1,3,5,7,9], 'min_child_weight':[1,3,5,7]}
#   param_test1 = {'gamma':[i/10.0 for i in range(0,7)]}
#   param_test1 = { 'subsample':[i/10.0 for i in range(6,10)],'colsample_bytree':[i/10.0 for i in range(6,10)]}  
#   param_test1 = {'max_depth': [1,3], 'min_child_weight':[6,7,8,9,10]}
    param_test1 = {'scale_pos_weight':[1,2,3,4,5], 'max_delta_step':[0,1,2,3,4,5]}

    for train_seq_index1, test_seq_index1 in kf:
        num_fold1 += 1
        print('this is creation of Kfold iterator')
        print('Start fold {} from {}'.format(num_fold1, nfolds))
    
        train_seq1 = unique_sequences[train_seq_index1]
        valid_seq1 = unique_sequences[test_seq_index1]
        
        print(train_seq1)
        print(valid_seq1)

        train_index = train[unique_sequences_fold.isin(train_seq1)].index.values
        test_index = train[unique_sequences_fold.isin(valid_seq1)].index.values

        print(train_index, type(train_index))
        print(test_index, type(test_index))
       
        train_index_group.append(train_index)
        test_index_group.append(test_index)
        
    
    print('train index group',train_index_group)

    custom_cv = [(train_index_group[i], test_index_group[i]) for i in range(0,3) ]
    
#    custom_cv=GroupShuffleSplit(n_splits=nfolds, test_size=0.5, random_state=0)

#    custom_cv = list(zip(train_index_group, test_index_group))

    print('custom cv', custom_cv)
                   

#    Scaling and PCA

    if PCAkey:

        scaler1 = MinMaxScaler() 
    
        train_features=train[features]
        train_target=train[target]
            
        train_scaled=pd.DataFrame(scaler1.fit_transform(train_features), columns=train_features.columns, index=train_features.index)


        pcatest=KernelPCA(kernel='poly')
        train_features_f=pd.DataFrame(pcatest.fit_transform(train_scaled), index=train_scaled.index)

        dmfeatures=train_features_f
        dmtarget=train_target        

    else:
    
        dmfeatures=train[features]
        dmtarget=train[target]
    
#   GridSearch
    
    classifier1=XGBClassifier( learning_rate =0.2, n_estimators=1000, max_depth=1,
        min_child_weight=3, gamma=0, subsample=0.6, colsample_bytree=0.8,
        objective= 'binary:logistic', nthread=4, scale_pos_weight=2, seed=27)

    gsearch1 = GridSearchCV(estimator = classifier1, param_grid = param_test1, scoring='roc_auc',n_jobs=-1,iid=False, cv=custom_cv)
  
    
#    gsearch1.fit(dmfeatures,dmtarget,groups=train['sequence_id'])
    gsearch1.fit(dmfeatures,dmtarget)

    print('best parameters, scores')    
    print(gsearch1.grid_scores_, gsearch1.best_params_, gsearch1.best_score_)
    
#    classifier2 = xgb.train(params, dtrain, num_boost_round, evals=watchlist, early_stopping_rounds=early_stopping_rounds, verbose_eval=500)

# %% [markdown]
# ## Running Grid Search

# %%
run_param_search(3, train, test, features, 'result', SEQoriginal=True, PCAkey=False)
# Out:
# train sequences 0       43.272316
# 1       30.618763
# 2       80.687466
# 3        5.525942
# 4       88.606139
# 5       26.489047
# 6       84.269872
# 7       66.672083
# 8       16.405674
# 9       71.819310
# 10      70.890514
# 11      80.025173
# 12       6.253357
# 13      47.250981
# 14      47.517605
# 15       5.285341
# 16      46.612877
# 17      11.425580
# 18      36.983796
# 19      38.606834
# 20      38.356721
# 21      19.700394
# 22      81.921776
# 23      63.742570
# 24      58.119774
# 25       4.515086
# 26      56.665411
# 27       6.878984
# 28      30.897093
# 29      50.361463
#           ...
# 456     44.286496
# 457     31.984977
# 458     66.695088
# 459     46.523501
# 460     94.073604
# 461     85.068425
# 462     14.981299
# 463     31.660847
# 464     42.181179
# 465      8.793187
# 466     63.067570
# 467     81.911738
# 468     93.726513
# 469     44.902306
# 470     53.043242
# 471      8.859100
# 472     30.272482
# 473     59.628107
# 474    114.034977
# 475     55.840244
# 476     45.347542
# 477     89.662273
# 478      2.673564
# 479     74.691054
# 480     13.502610
# 481      8.307366
# 482      5.306697
# 483     11.989683
# 484    103.977150
# 485     50.957168
# Name: sequence_id, dtype: float64
# this is creation of Kfold iterator
# Start fold 1 from 3
# [   0.14317687    0.5934909     2.6570786     4.51508624    4.97275672
#     5.01861517    5.03257936    5.13024079    5.2113137     5.25599737
#     5.27325854    5.46847074    5.47028274    5.52017387    5.52594205
#     5.61860663    5.83795032    5.91847004    5.96979298    6.1143548
 338, 339, 340,
#        341, 342, 343, 344, 345, 346, 348, 349, 350, 351, 352, 354, 355,
#        357, 358, 359, 360, 362, 365, 366, 367, 368, 369, 372, 373, 374,
#        375, 376, 377, 378, 379, 380, 382, 384, 385, 386, 387, 389, 390,
#        391, 392, 393, 394, 395, 396, 397, 398, 400, 401, 402, 404, 405,
#        406, 407, 408, 410, 413, 414, 415, 417, 418, 419, 421, 422, 423,
#        424, 425, 427, 429, 432, 433, 434, 435, 437, 439, 440, 441, 443,
#        444, 448, 449, 450, 451, 452, 454, 455, 461, 462, 463, 464, 466,
#        469, 470, 472, 473, 477, 478, 479, 480, 481, 482, 483, 484]), array([  1,   6,   9,  11,  14,  17,  19,  20,  21,  25,  30,  33,  35,
#         38,  39,  42,  43,  45,  46,  49,  52,  53,  54,  60,  61,  63,
#         75,  84,  87,  92,  94, 101, 102, 103, 106, 107, 112, 113, 114,
#        116, 117, 127, 129, 130, 140, 141, 144, 145, 147, 151, 152, 157,
#        161, 162, 164, 165, 167, 168, 169, 171, 174, 177, 178, 180, 185,
#        190, 192, 195, 197, 200, 204, 206, 208, 211, 213, 214, 215, 217,
#        219, 221, 223, 228, 232, 235, 239, 243, 245, 247, 249, 253, 258,
#        260, 261, 263, 264, 273, 275, 276, 282, 283, 284, 285, 289, 291,
#        294, 298, 299, 301, 304, 305, 306, 309, 316, 317, 320, 328, 331,
#        335, 336, 337, 347, 353, 356, 361, 363, 364, 370, 371, 381, 383,
#        388, 399, 403, 409, 411, 412, 416, 420, 426, 428, 430, 431, 436,
#        438, 442, 445, 446, 447, 453, 456, 457, 458, 459, 460, 465, 467,
#        468, 471, 474, 475, 476, 485]))]
# best parameters, scores
# [mean: 0.79178, std: 0.04198, params: {'max_delta_step': 0, 'scale_pos_weight': 1}, mean: 0.80802, std: 0.04762, params: {'max_delta_step': 0, 'scale_pos_weight': 2}, mean: 0.80678, std: 0.04407, params: {'max_delta_step': 0, 'scale_pos_weight': 3}, mean: 0.81294, std: 0.04166, params: {'max_delta_step': 0, 'scale_pos_weight': 4}, mean: 0.80769, std: 0.04110, params: {'max_delta_step': 0, 'scale_pos_weight': 5}, mean: 0.79542, std: 0.04748, params: {'max_delta_step': 1, 'scale_pos_weight': 1}, mean: 0.80900, std: 0.04895, params: {'max_delta_step': 1, 'scale_pos_weight': 2}, mean: 0.80965, std: 0.04483, params: {'max_delta_step': 1, 'scale_pos_weight': 3}, mean: 0.80749, std: 0.04031, params: {'max_delta_step': 1, 'scale_pos_weight': 4}, mean: 0.80927, std: 0.04572, params: {'max_delta_step': 1, 'scale_pos_weight': 5}, mean: 0.79178, std: 0.04198, params: {'max_delta_step': 2, 'scale_pos_weight': 1}, mean: 0.80802, std: 0.04762, params: {'max_delta_step': 2, 'scale_pos_weight': 2}, mean: 0.80678, std: 0.04407, params: {'max_delta_step': 2, 'scale_pos_weight': 3}, mean: 0.81294, std: 0.04166, params: {'max_delta_step': 2, 'scale_pos_weight': 4}, mean: 0.80769, std: 0.04110, params: {'max_delta_step': 2, 'scale_pos_weight': 5}, mean: 0.79178, std: 0.04198, params: {'max_delta_step': 3, 'scale_pos_weight': 1}, mean: 0.80802, std: 0.04762, params: {'max_delta_step': 3, 'scale_pos_weight': 2}, mean: 0.80678, std: 0.04407, params: {'max_delta_step': 3, 'scale_pos_weight': 3}, mean: 0.81294, std: 0.04166, params: {'max_delta_step': 3, 'scale_pos_weight': 4}, mean: 0.80769, std: 0.04110, params: {'max_delta_step': 3, 'scale_pos_weight': 5}, mean: 0.79178, std: 0.04198, params: {'max_delta_step': 4, 'scale_pos_weight': 1}, mean: 0.80802, std: 0.04762, params: {'max_delta_step': 4, 'scale_pos_weight': 2}, mean: 0.80678, std: 0.04407, params: {'max_delta_step': 4, 'scale_pos_weight': 3}, mean: 0.81294, std: 0.04166, params: {'max_delta_step': 4, 'scale_pos_weight': 4}, mean: 0.80769, std: 0.04110, params: {'max_delta_step': 4, 'scale_pos_weight': 5}, mean: 0.79178, std: 0.04198, params: {'max_delta_step': 5, 'scale_pos_weight': 1}, mean: 0.80802, std: 0.04762, params: {'max_delta_step': 5, 'scale_pos_weight': 2}, mean: 0.80678, std: 0.04407, params: {'max_delta_step': 5, 'scale_pos_weight': 3}, mean: 0.81294, std: 0.04166, params: {'max_delta_step': 5, 'scale_pos_weight': 4}, mean: 0.80769, std: 0.04110, params: {'max_delta_step': 5, 'scale_pos_weight': 5}] {'max_delta_step': 0, 'scale_pos_weight': 4} 0.812940616916
# /home/candres/Downloads/anaconda3/lib/python3.5/site-packages/sklearn/model_selection/_search.py:662: DeprecationWarning: The grid_scores_ attribute was deprecated in version 0.18 in favor of the more elaborate cv_results_ attribute. The grid_scores_ attribute will not be available from 0.20
#   DeprecationWarning)

# %% [markdown]
# ## Running Training, Prediction and Creating Submission

# %%
prediction, score = run_train_predict(4, train, test, features, 'result', SEQoriginal=False, PCAkey=False,
                                      Oversampling=False)

create_submission(score, test, prediction, feature_model, short_size, new_test)
# Out:
# length 728
# train pre (4698, 198)
# unique sequences pre (728,)
# unique sequences (728,)
# XGBoost params. ETA: 0.2, MAX_DEPTH: 3, SUBSAMPLE: 0.9, COLSAMPLE_BY_TREE: 0.9
# Start fold 1 from 4
# Length of train people: 546
# Length of valid people: 182
# Length train: 3505
# Length valid: 1193
# [0]	train-auc:0.763073	eval-auc:0.643037
# Multiple eval metrics have been passed: 'eval-auc' will be used for early stopping.
#
# Will train until eval-auc hasn't improved in 50 rounds.
# Stopping. Best iteration:
# [155]	train-auc:0.999983	eval-auc:0.740539
#
# Validating...
# Check error value: 0.740539
# Predict test set...
# Start fold 2 from 4
# Length of train people: 546
# Length of valid people: 182
# Length train: 3553
# Length valid: 1145
# [0]	train-auc:0.739019	eval-auc:0.583981
# Multiple eval metrics have been passed: 'eval-auc' will be used for early stopping.
#
# Will train until eval-auc hasn't improved in 50 rounds.
# Stopping. Best iteration:
# [287]	train-auc:1	eval-auc:0.7404
#
# Validating...
# Check error value: 0.740400
# Predict test set...
# Start fold 3 from 4
# Length of train people: 546
# Length of valid people: 182
# Length train: 3529
# Length valid: 1169
# [0]	train-auc:0.719549	eval-auc:0.65341
# Multiple eval metrics have been passed: 'eval-auc' will be used for early stopping.
#
# Will train until eval-auc hasn't improved in 50 rounds.
# Stopping. Best iteration:
# [58]	train-auc:0.979509	eval-auc:0.882728
#
# Validating...
# Check error value: 0.882728
# Predict test set...
# Start fold 4 from 4
# Length of train people: 546
# Length of valid people: 182
# Length train: 3507
# Length valid: 1191
# [0]	train-auc:0.703555	eval-auc:0.664748
# Multiple eval metrics have been passed: 'eval-auc' will be used for early stopping.
#
# Will train until eval-auc hasn't improved in 50 rounds.
# Stopping. Best iteration:
# [23]	train-auc:0.936284	eval-auc:0.806926
#
# Validating...
# Check error value: 0.806926
# Predict test set...
# iteration finished
# Check error value: 0.745332
#
# Training time: 0.15 minutes
# Writing submission:  submission_0.745331723744_model_3_short_False_new_test_True_2016-11-19-10-12.csv
