# %%
# %matplotlib inline
import datetime
import pandas as pd
import numpy as np
import xgboost as xgb
from sklearn.cross_validation import KFold

from sklearn.metrics import roc_auc_score
from scipy.io import loadmat
from operator import itemgetter
import random
import os
import time
import glob
import re
from multiprocessing import Process
import copy
from scipy.fftpack import fft

import xgboost as xgb
from xgboost.sklearn import XGBClassifier
from sklearn import cross_validation, metrics   #Additional scklearn functions
from sklearn.grid_search import GridSearchCV   #Perforing grid search

import matplotlib.pylab as plt
#%matplotlib inline
from matplotlib.pylab import rcParams

from pandas.tools.plotting import scatter_matrix

from sklearn.preprocessing import scale

from sklearn.decomposition import PCA




rcParams['figure.figsize'] = 12, 4


random.seed(2016)
np.random.seed(2016)


def natural_key(string_):
    return [int(s) if s.isdigit() else s for s in re.split(r'(\d+)', string_)]


def create_feature_map(features):
    outfile = open('xgb.fmap', 'w')
    for i, feat in enumerate(features):
        outfile.write('{0}\t{1}\tq\n'.format(i, feat))
    outfile.close()


def get_importance(gbm, features):
    create_feature_map(features)
    importance = gbm.get_fscore(fmap='xgb.fmap')
    importance = sorted(importance.items(), key=itemgetter(1), reverse=True)
    return importance


def intersect(a, b):
    return list(set(a) & set(b))


def print_features_importance(imp):
    for i in range(len(imp)):
        print("# " + str(imp[i][1]))
        print('output.remove(\'' + imp[i][0] + '\')')


def mat_to_pandas(path):
    mat = loadmat(path)
    names = mat['dataStruct'].dtype.names
    ndata = {n: mat['dataStruct'][n][0, 0] for n in names}
    sequence = -1
    if 'sequence' in names:
        sequence = mat['dataStruct']['sequence']
    return pd.DataFrame(ndata['data'], columns=ndata['channelIndices'][0]), sequence
    



def create_simple_csv_train(patient_id):

    out = open("simple_train_" + str(patient_id) + ".csv", "w")
    out.write("Id,sequence_id,patient_id")
    for i in range(16):
        out.write(",avg_" + str(i) + ",peak1_" + str(i) + ",peak2_" + str(i) + ",peak3_" + str(i) +",peak4_" + str(i))
    out.write(",file_size,result\n")

    # TRAIN (0)
    out_str = ''
    files = sorted(glob.glob("./data/train_" + str(patient_id) + "/*.mat"), key=natural_key)
    print ('train files'+ str(patient_id), len(files))    
    pos1=0
    neg1=0
    sequence_id = 0
    total = 0
    seq1=0
    for fl in files:
        total += 1
        # print('Go for ' + fl)
        id_str = os.path.basename(fl)[:-4]
        arr = id_str.split("_")
        patient = int(arr[0])
        id = int(arr[1])
        result = int(arr[2])
        new_id = patient*100000 + id
        try:
            tables, sequence_from_mat = mat_to_pandas(fl)
        except:
            print('Some error here {}...'.format(fl))
            continue
        out_str += str(new_id) + "," + str(sequence_id) + "," + str(patient)

        sizesignal=int(tables.shape[0])       
        
        for f in sorted(list(tables.columns.values)):
            mean = tables[f].mean()
            
            yf1 = fft(tables[f])
            fftpeak=2.0/sizesignal * np.abs(yf1[0:sizesignal/2])
 
            numberofbands=4

            sizeband=20/numberofbands

#           for i in range(numberofbands)
          
            peak1=fftpeak[0:5].mean()            
            peak2=fftpeak[5:10].mean()          
            peak3=fftpeak[10:15].mean()
            peak4=fftpeak[15:20].mean()
            
            out_str += "," + str(mean)+ "," + str(peak1) + "," + str(peak2) + "," + str(peak3) +"," + str(peak4)
        out_str += "," + str(os.path.getsize(fl)) + "," + str(result) + "\n"
        #print(sequence_from_mat)
        #print(type(sequence_from_mat))
        seq1=int(sequence_from_mat[0][0][0][0])
        print(total, seq1)
        if (total % 6 == 0) and (seq1==6):
            if result != 0:
                pos1 += 1
                print('Positive ocurrence sequence finished', pos1)
            else:
                neg1 += 1
                print('Negative ocurrence sequence finished', neg1)
                
            sequence_id += 1
            print ('sequence',sequence_id)

    out.write(out_str)
    
    out.close()
    print('Train CSV for patient {} has been completed...'.format(patient_id))


def create_simple_csv_test(patient_id):

    # TEST
    out_str = ''
    files = sorted(glob.glob("./data/test_" + str(patient_id) + "/*.mat"), key=natural_key)
    print ('test files'+ str(patient_id), len(files))    
    out = open("simple_test_" + str(patient_id) + ".csv", "w")
    out.write("Id,patient_id")
    for i in range(16):
        out.write(",avg_" + str(i) + ",peak1_" + str(i) + ",peak2_" + str(i) + ",peak3_" + str(i) +",peak4_" + str(i))
    out.write(",file_size\n")
    for fl in files:
        # print('Go for ' + fl)
        id_str = os.path.basename(fl)[:-4]
        arr = id_str.split("_")
        patient = int(arr[0])
        id = int(arr[1])
        new_id = patient*100000 + id
        try:
            tables, sequence_from_mat = mat_to_pandas(fl)
        except:
            print('Some error here {}...'.format(fl))
            continue
        out_str += str(new_id) + "," + str(patient)

        sizesignal=int(tables.shape[0])           
        
        for f in sorted(list(tables.columns.values)):
            mean = tables[f].mean()
            
            yf1 = fft(tables[f])
            fftpeak=2.0/sizesignal * np.abs(yf1[0:sizesignal/2])

            numberofbands=4

            sizeband=20/numberofbands

#           for i in range(numberofbands)
          
            peak1=fftpeak[0:5].mean()            
            peak2=fftpeak[5:10].mean()          
            peak3=fftpeak[10:15].mean()
            peak4=fftpeak[15:20].mean()
            
            out_str += "," + str(mean)+ "," + str(peak1) + "," + str(peak2) + "," + str(peak3) +"," + str(peak4)
                        
        out_str += "," + str(os.path.getsize(fl)) + "\n"
        # break

    out.write(out_str)
    out.close()
    print('Test CSV for patient {} has been completed...'.format(patient_id))


def run_kfold(nfolds, train, test, features, target, random_state=2016):
    eta = 0.2
    max_depth = 3
    subsample = 0.9
    colsample_bytree = 0.9
    start_time = time.time()

    print('XGBoost params. ETA: {}, MAX_DEPTH: {}, SUBSAMPLE: {}, COLSAMPLE_BY_TREE: {}'.format(eta, max_depth, subsample, colsample_bytree))
    params = {
        "objective": "binary:logistic",
        "booster" : "gbtree",
        "eval_metric": "auc",
        "eta": eta,
        "tree_method": 'exact',
        "max_depth": max_depth,
        "subsample": subsample,
        "colsample_bytree": colsample_bytree,
        "silent": 1,
        "seed": random_state,
    }
    num_boost_round = 1000
    early_stopping_rounds = 50

    yfull_train = dict()
    yfull_test = copy.deepcopy(test[['Id']].astype(object))

    unique_sequences = np.array(train['sequence_id'].unique())
    
    
    kf = KFold(len(unique_sequences), n_folds=nfolds, shuffle=True, random_state=random_state)
    num_fold = 0
    for train_seq_index, test_seq_index in kf:
        num_fold += 1
        print('Start fold {} from {}'.format(num_fold, nfolds))
        train_seq = unique_sequences[train_seq_index]
        valid_seq = unique_sequences[test_seq_index]
        print('Length of train people: {}'.format(len(train_seq)))
        print('Length of valid people: {}'.format(len(valid_seq)))

        X_train, X_valid = train[train['sequence_id'].isin(train_seq)][features], train[train['sequence_id'].isin(valid_seq)][features]
        y_train, y_valid = train[train['sequence_id'].isin(train_seq)][target], train[train['sequence_id'].isin(valid_seq)][target]
        X_test = test[features]

        print('Length train:', len(X_train))
        print('Length valid:', len(X_valid))

        dtrain = xgb.DMatrix(X_train, y_train)
        dvalid = xgb.DMatrix(X_valid, y_valid)

        watchlist = [(dtrain, 'train'), (dvalid, 'eval')]
        gbm = xgb.train(params, dtrain, num_boost_round, evals=watchlist, early_stopping_rounds=early_stopping_rounds, verbose_eval=1000)

        yhat = gbm.predict(xgb.DMatrix(X_valid), ntree_limit=gbm.best_iteration+1)

        # Each time store portion of precicted data in train predicted values
        for i in range(len(X_valid.index)):
            yfull_train[X_valid.index[i]] = yhat[i]

        print("Validating...")
        check = gbm.predict(xgb.DMatrix(X_valid), ntree_limit=gbm.best_iteration+1)
        score = roc_auc_score(y_valid.tolist(), check)
        print('Check error value: {:.6f}'.format(score))

        imp = get_importance(gbm, features)
        print('Importance array: ', imp)

        print("Predict test set...")
        test_prediction1 = gbm.predict(xgb.DMatrix(X_test), ntree_limit=gbm.best_iteration+1)
        yfull_test['kfold_' + str(num_fold)] = test_prediction1
        
        print(test_prediction1)
               

    # Copy dict to list
    train_res = []
    for i in range(len(train.index)):
        train_res.append(yfull_train[i])

    score = roc_auc_score(train[target], np.array(train_res))
    print('Check error value: {:.6f}'.format(score))

    # Find mean for KFolds on test
    merge = []
    for i in range(1, nfolds+1):
        merge.append('kfold_' + str(i))
    yfull_test['mean'] = yfull_test[merge].mean(axis=1)
    
    print(yfull_test)

    print('Training time: {} minutes'.format(round((time.time() - start_time)/60, 2)))
    return yfull_test['mean'].values, score




def create_submission(score, test, prediction):
    # Make Submission
    now = datetime.datetime.now()
    sub_file = 'submission_' + str(score) + '_' + str(now.strftime("%Y-%m-%d-%H-%M")) + '.csv'
    print('Writing submission: ', sub_file)
    f = open(sub_file, 'w')
    f.write('File,Class\n')
    total = 0
    for id in test['Id']:
        patient = id // 100000
        fid = id % 100000
        str1 = str(patient) + '_' + str(fid) + '.mat' + ',' + str(prediction[total])
        str1 += '\n'
        total += 1
        f.write(str1)
    f.close()


def get_features(train, test):
    trainval = list(train.columns.values)
    testval = list(test.columns.values)
    output = intersect(trainval, testval)
    output.remove('Id')
    # output.remove('file_size')
    return sorted(output)


def read_test_train():
    print("Load train.csv...")
    train1 = pd.read_csv("simple_train_1.csv")
    train2 = pd.read_csv("simple_train_2.csv")
    train3 = pd.read_csv("simple_train_3.csv")
    train = pd.concat([train1, train2, train3])
    # Remove all zeroes files
    train = train[train['file_size'] > 55000].copy()
    # Shuffle rows since they are ordered
    train = train.iloc[np.random.permutation(len(train))]
    # Reset broken index
    train = train.reset_index()
    print("Load test.csv...")
    test1 = pd.read_csv("simple_test_1.csv")
    test2 = pd.read_csv("simple_test_2.csv")
    test3 = pd.read_csv("simple_test_3.csv")
    test = pd.concat([test1, test2, test3])
    print("Process tables...")
    features = get_features(train, test)
    return train, test, features

# %%
#Creating files and reading them, ready for prediction.


if __name__ == '__main__':
    print('XGBoost: {}'.format(xgb.__version__))
    if 1:
        # Do reading and processing of MAT files in parallel
        p = dict()
        p[1] = Process(target=create_simple_csv_train, args=(1,))
        p[1].start()
        p[2] = Process(target=create_simple_csv_train, args=(2,))
        p[2].start()
        p[3] = Process(target=create_simple_csv_train, args=(3,))
        p[3].start()
        p[4] = Process(target=create_simple_csv_test, args=(1,))
        p[4].start()
        p[5] = Process(target=create_simple_csv_test, args=(2,))
        p[5].start()
        p[6] = Process(target=create_simple_csv_test, args=(3,))
        p[6].start()
        p[1].join()
        p[2].join()
        p[3].join()
        p[4].join()
        p[5].join()
        p[6].join()
    train, test, features = read_test_train()
    print('Length of train: ', len(train))
    print('Length of test: ', len(test))
    print('Features [{}]: {}'.format(len(features), sorted(features)))
# Out:
# XGBoost: 0.6
# test files3 2286
# test files2 2256
# test files1 1584
# train files1 1302
# train files2 2346
# train files3 2394
# /home/rodolfoxps/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:221: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
# /home/rodolfoxps/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:221: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
# /home/rodolfoxps/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:123: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
# 1 1
# /home/rodolfoxps/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:221: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
# /home/rodolfoxps/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:123: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
# 1 1
# /home/rodolfoxps/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:123: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
# 1 1
# 2 1
# 2 1
# 2 1
# 3 2
# 3 2
# 4 2
# 4 2
# 5 3
# 3 2
# 6 3
# 5 3
# 7 4
# 4 2
# 6 3
# 5 3
# 8 4
# 6 3
# 7 4
# 8 4
# 9 5
# 7 4
# 9 5
# 10 5
# 8 4
# 10 5
# 11 6
# 9 5
# 11 6
# 12 6
# Positive ocurrence sequence finished 1
# sequence 1
# 13 1
# 14 1
# 12 6
# Positive ocurrence sequence finished 1
# sequence 1
# 10 5
# 15 2
# 13 1
# 16 2
# 11 6
# 14 1
# 17 3
# 18 3
# 15 2
# 12 6
# Positive ocurrence sequence finished 1
# sequence 1
# 19 4
# 16 2
# 20 4
# 13 1
# 17 3
# 21 5
# 22 5
# 23 6
# 14 1
# 18 3
# 24 6
# Positive ocurrence sequence finished 2
# sequence 2
# 25 1
# 19 4
# 26 1
# 15 2
# 20 4
# 27 2
# 28 2
# 16 2
# 21 5
# 29 3
# 30 3
# 22 5
# 17 3
# 31 4
# 23 6
# 18 3
# 32 4
# 24 6
# Positive ocurrence sequence finished 2
# sequence 2
# 25 1
# 19 4
# 33 5
# 26 1
# 34 5
# 20 4
# 27 2
# 35 6
# 36 6
# Positive ocurrence sequence finished 3
# sequence 3
# 28 2
# 21 5
# 29 3
# 22 5
# 37 1
# 30 3
# 38 1
# 23 6
# 31 4
# 39 2
# 32 4
# 40 2
# 24 6
# Positive ocurrence sequence finished 2
# sequence 2
# 33 5
# 41 3
# 34 5
# 25 1
# 26 1
# 35 6
# 42 3
# 36 6
# Positive ocurrence sequence finished 3
# sequence 3
# 27 2
# 37 1
# 43 4
# 38 1
# 44 4
# 28 2
# 39 2
# 45 5
# 46 5
# 40 2
# 29 3
# 47 6
# 41 3
# 30 3
# 42 3
# 48 6
# Positive ocurrence sequence finished 4
# sequence 4
# 43 4
# 49 1
# 50 1
# 31 4
# 44 4
# 51 2
# 32 4
# 52 2
# 45 5
# 46 5
# 47 6
# 53 3
# 33 5
# 48 6
# Positive ocurrence sequence finished 4
# sequence 4
# 49 1
# 54 3
# 34 5
# 50 1
# 55 4
# 51 2
# 56 4
# 35 6
# 52 2
# 57 5
# 53 3
# 54 3
# 55 4
# 36 6
# Positive ocurrence sequence finished 3
# sequence 3
# 58 5
# 56 4
# 59 6
# 57 5
# 37 1
# 58 5
# 60 6
# Positive ocurrence sequence finished 5
# sequence 5
# 59 6
# 61 1
# 38 1
# 60 6
# Positive ocurrence sequence finished 5
# sequence 5
# 62 1
# 39 2
# 63 2
# 61 1
# 64 2
# 62 1
# 40 2
# 65 3
# 63 2
# 66 3
# 64 2
# 41 3
# 65 3
# 67 4
# 68 4
# 69 5
# 66 3
# 70 5
# 42 3
# 67 4
# 68 4
# 71 6
# 72 6
# Positive ocurrence sequence finished 6
# sequence 6
# 43 4
# 69 5
# 73 1
# 70 5
# 71 6
# 44 4
# 74 1
# 72 6
# Positive ocurrence sequence finished 6
# sequence 6
# 45 5
# 46 5
# 75 2
# 73 1
# 74 1
# 76 2
# 47 6
# 75 2
# 48 6
# Positive ocurrence sequence finished 4
# sequence 4
# 76 2
# 77 3
# 77 3
# 78 3
# 49 1
# 78 3
# 79 4
# 80 4
# 50 1
# 79 4
# 80 4
# 81 5
# 82 5
# 51 2
# 83 6
# 81 5
# 84 6
# Positive ocurrence sequence finished 7
# sequence 7
# 52 2
# 85 1
# 86 1
# 53 3
# 87 2
# 82 5
# 54 3
# 88 2
# 89 3
# 83 6
# Some error here /home/rodolfoxps/Documents/Kaggle//train_1/1_45_1.mat...
# 55 4
# 91 4
# 56 4
# 92 4
# 84 6
# Positive ocurrence sequence finished 7
# sequence 7
# 93 5
# 94 5
# 57 5
# 58 5
# 95 6
# 85 1
# 59 6
# 96 6
# Positive ocurrence sequence finished 8
# sequence 8
# 97 1
# 86 1
# 60 6
# Positive ocurrence sequence finished 5
# sequence 5
# 98 1
# 61 1
# 99 2
# 87 2
# 88 2
# 100 2
# 62 1
# 101 3
# 89 3
# 63 2
# 102 3
# 90 3
# 103 4
# 64 2
# 104 4
# 65 3
# 91 4
# 92 4
# 105 5
# 66 3
# 106 5
# 93 5
# 67 4
# 94 5
# 107 6
# 68 4
# 108 6
# Positive ocurrence sequence finished 9
# sequence 9
# 69 5
# 95 6
# 96 6
# Positive ocurrence sequence finished 8
# sequence 8
# 109 1
# 70 5
# 110 1
# 71 6
# 111 2
# 97 1
# 112 2
# 72 6
# Positive ocurrence sequence finished 6
# sequence 6
# 113 3
# 114 3
# 73 1
# 98 1
# 115 4
# 116 4
# 74 1
# 75 2
# 76 2
# 117 5
# 99 2
# 118 5
# 100 2
# 77 3
# 119 6
# 78 3
# 120 6
# Positive ocurrence sequence finished 10
# sequence 10
# 101 3
# 121 1
# 79 4
# 122 1
# 102 3
# 80 4
# 123 2
# 124 2
# 103 4
# 125 3
# 81 5
# 126 3
# 104 4
# 82 5
# 127 4
# 128 4
# 105 5
# 83 6
# 106 5
# 129 5
# 130 5
# 131 6
# 84 6
# Positive ocurrence sequence finished 7
# sequence 7
# 107 6
# 85 1
# 132 6
# Positive ocurrence sequence finished 11
# sequence 11
# 86 1
# 133 1
# 108 6
# Positive ocurrence sequence finished 9
# sequence 9
# 134 1
# 135 2
# 87 2
# 136 2
# 88 2
# 109 1
# 137 3
# 89 3
# 138 3
# 110 1
# 139 4
# 90 3
# 140 4
# 91 4
# 141 5
# 111 2
# 142 5
# 92 4
# 143 6
# 112 2
# 144 6
# Positive ocurrence sequence finished 12
# sequence 12
# 93 5
# 145 1
# 94 5
# 113 3
# 146 1
# 95 6
# 147 2
# 114 3
# 148 2
# 96 6
# Positive ocurrence sequence finished 8
# sequence 8
# 149 3
# 115 4
# 150 3
# 97 1
# 98 1
# 151 4
# 116 4
# 152 4
# 99 2
# 153 5
# 100 2
# 117 5
# 154 5
# 101 3
# 155 6
# 118 5
# 102 3
# 156 6
# Positive ocurrence sequence finished 13
# sequence 13
# 157 1
# 103 4
# 119 6
# 158 1
# 104 4
# 159 2
# 120 6
# Positive ocurrence sequence finished 10
# sequence 10
# 160 2
# 105 5
# 161 3
# 121 1
# 106 5
# 162 3
# 107 6
# 122 1
# 163 4
# 108 6
# Positive ocurrence sequence finished 9
# sequence 9
# 164 4
# 123 2
# 109 1
# 165 5
# 110 1
# 124 2
# 166 5
# 111 2
# 112 2
# 125 3
# 113 3
# 167 6
# 168 6
# Positive ocurrence sequence finished 14
# sequence 14
# 114 3
# 169 1
# 115 4
# 170 1
# 126 3
# 116 4
# 171 2
# 117 5
# 172 2
# 127 4
# 173 3
# 118 5
# 174 3
# 119 6
# 175 4
# 128 4
# 120 6
# Positive ocurrence sequence finished 10
# sequence 10
# 176 4
# 121 1
# 129 5
# 177 5
# 178 5
# 130 5
# 122 1
# 179 6
# 123 2
# 180 6
# Positive ocurrence sequence finished 15
# sequence 15
# 131 6
# 181 1
# 124 2
# 132 6
# Positive ocurrence sequence finished 11
# sequence 11
# 182 1
# 125 3
# 183 2
# 133 1
# 134 1
# 126 3
# 184 2
# 185 3
# 127 4
# 186 3
# 135 2
# 128 4
# 187 4
# 188 4
# 189 5
# 129 5
# 136 2
# 190 5
# 191 6
# 130 5
# 192 6
# Positive ocurrence sequence finished 16
# sequence 16
# 137 3
# 193 1
# 194 1
# 195 2
# 196 2
# 131 6
# 138 3
# 197 3
# 198 3
# 132 6
# Positive ocurrence sequence finished 11
# sequence 11
# 199 4
# 139 4
# 200 4
# 133 1
# 201 5
# 140 4
# 202 5
# 134 1
# 203 6
# 141 5
# 142 5
# 135 2
# 204 6
# Positive ocurrence sequence finished 17
# sequence 17
# 143 6
# 205 1
# 136 2
# 206 1
# 144 6
# Positive ocurrence sequence finished 12
# sequence 12
# 207 2
# 137 3
# 208 2
# 145 1
# 138 3
# 209 3
# 210 3
# 211 4
# 139 4
# 212 4
# 146 1
# 213 5
# 214 5
# 140 4
# 147 2
# 215 6
# 141 5
# 216 6
# Positive ocurrence sequence finished 18
# sequence 18
# 148 2
# 142 5
# 217 1
# 218 1
# 149 3
# 143 6
# 219 2
# 220 2
# 221 3
# 144 6
# Positive ocurrence sequence finished 12
# sequence 12
# 150 3
# 222 3
# 145 1
# 223 4
# 151 4
# 224 4
# 225 5
# 146 1
# 152 4
# 226 5
# 227 6
# 228 6
# Positive ocurrence sequence finished 19
# sequence 19
# 147 2
# 153 5
# 229 1
# 230 1
# 148 2
# 231 2
# 232 2
# 154 5
# 233 3
# 149 3
# 234 3
# 155 6
# 150 3
# 235 4
# 236 4
# 151 4
# 237 5
# 156 6
# Positive ocurrence sequence finished 13
# sequence 13
# 238 5
# 152 4
# 157 1
# 239 6
# 240 6
# Positive ocurrence sequence finished 20
# sequence 20
# 153 5
# 241 1
# 242 1
# 158 1
# 243 2
# 244 2
# 154 5
# 245 3
# 246 3
# 159 2
# 155 6
# 247 4
# 248 4
# 156 6
# Positive ocurrence sequence finished 13
# sequence 13
# 249 5
# 160 2
# 250 5
# 157 1
# 251 6
# 252 6
# Positive ocurrence sequence finished 21
# sequence 21
# 158 1
# 253 1
# 161 3
# 159 2
# 162 3
# 254 1
# 160 2
# 255 2
# 256 2
# 163 4
# 161 3
# 257 3
# 258 3
# 164 4
# 259 4
# 162 3
# 260 4
# 261 5
# 262 5
# 163 4
# 165 5
# 263 6
# 264 6
# Positive ocurrence sequence finished 22
# sequence 22
# 164 4
# 166 5
# 265 1
# 266 1
# 167 6
# 165 5
# 267 2
# 268 2
# 269 3
# 270 3
# 271 4
# 166 5
# 168 6
# Positive ocurrence sequence finished 14
# sequence 14
# 272 4
# 167 6
# 273 5
# 169 1
# 274 5
# 168 6
# Positive ocurrence sequence finished 14
# sequence 14
# 170 1
# 275 6
# 169 1
# 171 2
# 276 6
# Positive ocurrence sequence finished 23
# sequence 23
# 170 1
# 277 1
# 172 2
# 278 1
# 279 2
# 171 2
# 173 3
# 280 2
# 172 2
# 174 3
# 281 3
# 175 4
# 173 3
# 282 3
# 283 4
# 284 4
# 174 3
# 176 4
# 285 5
# 175 4
# 286 5
# 177 5
# 287 6
# 176 4
# 288 6
# Positive ocurrence sequence finished 24
# sequence 24
# 289 1
# 177 5
# 290 1
# 178 5
# 291 2
# 178 5
# 292 2
# 179 6
# 293 3
# 294 3
# 179 6
# 295 4
# 180 6
# Positive ocurrence sequence finished 15
# sequence 15
# 296 4
# 180 6
# Positive ocurrence sequence finished 15
# sequence 15
# 297 5
# 298 5
# 181 1
# 181 1
# 299 6
# 182 1
# 300 6
# Positive ocurrence sequence finished 25
# sequence 25
# 182 1
# 301 1
# 183 2
# 183 2
# 302 2
# 184 2
# 303 3
# 304 4
# 184 2
# 185 3
# 305 5
# 185 3
# 186 3
# 306 6
# Negative ocurrence sequence finished 1
# sequence 26
# 186 3
# 187 4
# 307 1
# 188 4
# 189 5
# 308 2
# 187 4
# 309 3
# 190 5
# 310 4
# 311 5
# 188 4
# 312 6
# Negative ocurrence sequence finished 2
# sequence 27
# 191 6
# 313 1
# 189 5
# 314 2
# 192 6
# Positive ocurrence sequence finished 16
# sequence 16
# 315 3
# 190 5
# 316 4
# 193 1
# 317 5
# 191 6
# 318 6
# Negative ocurrence sequence finished 3
# sequence 28
# 192 6
# Positive ocurrence sequence finished 16
# sequence 16
# 319 1
# 193 1
# 194 1
# 195 2
# 194 1
# 320 2
# 195 2
# 196 2
# 321 3
# 196 2
# 322 4
# 197 3
# 323 5
# 197 3
# 324 6
# Negative ocurrence sequence finished 4
# sequence 29
# 198 3
# 198 3
# 325 1
# 199 4
# 326 2
# 199 4
# 327 3
# 200 4
# 200 4
# 328 4
# 201 5
# 329 5
# 201 5
# 330 6
# Negative ocurrence sequence finished 5
# sequence 30
# 202 5
# 202 5
# 331 1
# 203 6
# 332 2
# 204 6
# Positive ocurrence sequence finished 17
# sequence 17
# 203 6
# 333 3
# 205 1
# 334 4
# 204 6
# Positive ocurrence sequence finished 17
# sequence 17
# 205 1
# 206 1
# 335 5
# 336 6
# Negative ocurrence sequence finished 6
# sequence 31
# 337 1
# 206 1
# 207 2
# 207 2
# 338 2
# 208 2
# 208 2
# 339 3
# 209 3
# 340 4
# 209 3
# 210 3
# 341 5
# 210 3
# 211 4
# 211 4
# 342 6
# Negative ocurrence sequence finished 7
# sequence 32
# 212 4
# 343 1
# 212 4
# 213 5
# 344 2
# 345 3
# 213 5
# 214 5
# 215 6
# 346 4
# 216 6
# Positive ocurrence sequence finished 18
# sequence 18
# 214 5
# 347 5
# 348 6
# Negative ocurrence sequence finished 8
# sequence 33
# 217 1
# 215 6
# 349 1
# 350 2
# 216 6
# Positive ocurrence sequence finished 18
# sequence 18
# 218 1
# 351 3
# 219 2
# 352 4
# 217 1
# 220 2
# 353 5
# 221 3
# 218 1
# 354 6
# Negative ocurrence sequence finished 9
# sequence 34
# 222 3
# 355 1
# 223 4
# 219 2
# 224 4
# 356 2
# 357 3
# 220 2
# 358 4
# 225 5
# 226 5
# 221 3
# 359 5
# 227 6
# 360 6
# Negative ocurrence sequence finished 10
# sequence 35
# 222 3
# 228 6
# Positive ocurrence sequence finished 19
# sequence 19
# 361 1
# 223 4
# 362 2
# 229 1
# 230 1
# 363 3
# 224 4
# 364 4
# 231 2
# 225 5
# 365 5
# 232 2
# 366 6
# Negative ocurrence sequence finished 11
# sequence 36
# 233 3
# 226 5
# 367 1
# 368 2
# 227 6
# 234 3
# 369 3
# 370 4
# 228 6
# Positive ocurrence sequence finished 19
# 371 5
# sequence 19
# 235 4
# 229 1
# 372 6
# Negative ocurrence sequence finished 12
# sequence 37
# 230 1
# 373 1
# 374 2
# 231 2
# 236 4
# 375 3
# 232 2
# 237 5
# 376 4
# 238 5
# 233 3
# 377 5
# 239 6
# 234 3
# 378 6
# Negative ocurrence sequence finished 13
# sequence 38
# 379 1
# 235 4
# 240 6
# Positive ocurrence sequence finished 20
# sequence 20
# 380 2
# 241 1
# 242 1
# 236 4
# 381 3
# 243 2
# 244 2
# 382 4
# 245 3
# 246 3
# 237 5
# 383 5
# 247 4
# 248 4
# 384 6
# Negative ocurrence sequence finished 14
# sequence 39
# 238 5
# 249 5
# 385 1
# 239 6
# 386 2
# 250 5
# 240 6
# Positive ocurrence sequence finished 20
# sequence 20
# 251 6
# 387 3
# 241 1
# 242 1
# 388 4
# 252 6
# Positive ocurrence sequence finished 21
# sequence 21
# 243 2
# 389 5
# 253 1
# 244 2
# 245 3
# 254 1
# 246 3
# 390 6
# Negative ocurrence sequence finished 15
# sequence 40
# 255 2
# 391 1
# 247 4
# 248 4
# 392 2
# 249 5
# 393 3
# 256 2
# 250 5
# 257 3
# 394 4
# 258 3
# 259 4
# 251 6
# 395 5
# 260 4
# 396 6
# Negative ocurrence sequence finished 16
# sequence 41
# 252 6
# Positive ocurrence sequence finished 21
# sequence 21
# 397 1
# 261 5
# 253 1
# 262 5
# 398 2
# 399 3
# 263 6
# 254 1
# 264 6
# Positive ocurrence sequence finished 22
# sequence 22
# 265 1
# 400 4
# 255 2
# 266 1
# 401 5
# 256 2
# 402 6
# Negative ocurrence sequence finished 17
# sequence 42
# 403 1
# 267 2
# 268 2
# 257 3
# 269 3
# 270 3
# 404 2
# 258 3
# 271 4
# 405 3
# 259 4
# 406 4
# 272 4
# 273 5
# 407 5
# 260 4
# 274 5
# 408 6
# Negative ocurrence sequence finished 18
# sequence 43
# 275 6
# 276 6
# Positive ocurrence sequence finished 23
# sequence 23
# 261 5
# 409 1
# 277 1
# 278 1
# 410 2
# 411 3
# 279 2
# 280 2
# 262 5
# 412 4
# 281 3
# 282 3
# 263 6
# 283 4
# 413 5
# 284 4
# 414 6
# Negative ocurrence sequence finished 19
# sequence 44
# 285 5
# 264 6
# Positive ocurrence sequence finished 22
# sequence 22
# 415 1
# 286 5
# 287 6
# 265 1
# 288 6
# Positive ocurrence sequence finished 24
# sequence 24
# 416 2
# 266 1
# 417 3
# 289 1
# 290 1
# 418 4
# 267 2
# 291 2
# 419 5
# 268 2
# 292 2
# 420 6
# Negative ocurrence sequence finished 20
# sequence 45
# 293 3
# 269 3
# 421 1
# 422 2
# 294 3
# 270 3
# 295 4
# 423 3
# 271 4
# 272 4
# 296 4
# 424 4
# 425 5
# 273 5
# 297 5
# 426 6
# Negative ocurrence sequence finished 21
# sequence 46
# 274 5
# 298 5
# 299 6
# 427 1
# 275 6
# 300 6
# Positive ocurrence sequence finished 25
# sequence 25
# 276 6
# Positive ocurrence sequence finished 23
# sequence 23
# 428 2
# 301 1
# 429 3
# 277 1
# 302 2
# 303 3
# 430 4
# 304 4
# 278 1
# 305 5
# 431 5
# 306 6
# Negative ocurrence sequence finished 1
# sequence 26
# 279 2
# 432 6
# Negative ocurrence sequence finished 22
# sequence 47
# 307 1
# 433 1
# 280 2
# 308 2
# 434 2
# 309 3
# 281 3
# 435 3
# 310 4
# 436 4
# 282 3
# 311 5
# 437 5
# 312 6
# Negative ocurrence sequence finished 2
# sequence 27
# 313 1
# 283 4
# 438 6
# Negative ocurrence sequence finished 23
# sequence 48
# 284 4
# 314 2
# 315 3
# 439 1
# 285 5
# 316 4
# 440 2
# 286 5
# 441 3
# 317 5
# 442 4
# 318 6
# Negative ocurrence sequence finished 3
# sequence 28
# 287 6
# 443 5
# 444 6
# Negative ocurrence sequence finished 24
# sequence 49
# 319 1
# 445 1
# 288 6
# Positive ocurrence sequence finished 24
# sequence 24
# 320 2
# 446 2
# 289 1
# 321 3
# 447 3
# 322 4
# 448 4
# 290 1
# 323 5
# 324 6
# Negative ocurrence sequence finished 4
# sequence 29
# 449 5
# 450 6
# Negative ocurrence sequence finished 25
# sequence 50
# 325 1
# 291 2
# 451 1
# 452 2
# 292 2
# 326 2
# 293 3
# 453 3
# 327 3
# 454 4
# 294 3
# 328 4
# 295 4
# 455 5
# 329 5
# 296 4
# 330 6
# Negative ocurrence sequence finished 5
# sequence 30
# 456 6
# Negative ocurrence sequence finished 26
# sequence 51
# 297 5
# 331 1
# 457 1
# 458 2
# 298 5
# 332 2
# 459 3
# 333 3
# 299 6
# 460 4
# 334 4
# 300 6
# Positive ocurrence sequence finished 25
# sequence 25
# 335 5
# 461 5
# 462 6
# Negative ocurrence sequence finished 27
# sequence 52
# 336 6
# Negative ocurrence sequence finished 6
# sequence 31
# 463 1
# 337 1
# 301 1
# 338 2
# 464 2
# 302 2
# 465 3
# 466 4
# 339 3
# 303 3
# 467 5
# 340 4
# 468 6
# Negative ocurrence sequence finished 28
# sequence 53
# 304 4
# 341 5
# 469 1
# 305 5
# 470 2
# 342 6
# Negative ocurrence sequence finished 7
# sequence 32
# 471 3
# 306 6
# Negative ocurrence sequence finished 1
# sequence 26
# 472 4
# 343 1
# 307 1
# 473 5
# 308 2
# 474 6
# Negative ocurrence sequence finished 29
# sequence 54
# 344 2
# 475 1
# 345 3
# 309 3
# 476 2
# 346 4
# 310 4
# 477 3
# 347 5
# 348 6
# Negative ocurrence sequence finished 8
# sequence 33
# 311 5
# 478 4
# 479 5
# 312 6
# Negative ocurrence sequence finished 2
# sequence 27
# 480 6
# Negative ocurrence sequence finished 30
# sequence 55
# 349 1
# 481 1
# 482 2
# 313 1
# 483 3
# 350 2
# 484 4
# 314 2
# 351 3
# 485 5
# 352 4
# 315 3
# 486 6
# Negative ocurrence sequence finished 31
# sequence 56
# 316 4
# 353 5
# 487 1
# 488 2
# 317 5
# 354 6
# Negative ocurrence sequence finished 9
# sequence 34
# 489 3
# 355 1
# 490 4
# 318 6
# Negative ocurrence sequence finished 3
# sequence 28
# 491 5
# 356 2
# 492 6
# Negative ocurrence sequence finished 32
# sequence 57
# 319 1
# 493 1
# 357 3
# 494 2
# 320 2
# 358 4
# 495 3
# 359 5
# 496 4
# 321 3
# 360 6
# Negative ocurrence sequence finished 10
# sequence 35
# 497 5
# 498 6
# Negative ocurrence sequence finished 33
# sequence 58
# 499 1
# 322 4
# 500 2
# 361 1
# 501 3
# 323 5
# 362 2
# 502 4
# 503 5
# 363 3
# 504 6
# Negative ocurrence sequence finished 34
# sequence 59
# 364 4
# 324 6
# Negative ocurrence sequence finished 4
# sequence 29
# 505 1
# 506 2
# 325 1
# 365 5
# 507 3
# 508 4
# 366 6
# Negative ocurrence sequence finished 11
# sequence 36
# 367 1
# 509 5
# 326 2
# 510 6
# Negative ocurrence sequence finished 35
# sequence 60
# 511 1
# 512 2
# 327 3
# 368 2
# 513 3
# 514 4
# 328 4
# 515 5
# 369 3
# 516 6
# Negative ocurrence sequence finished 36
# sequence 61
# 329 5
# 517 1
# 370 4
# 518 2
# 330 6
# Negative ocurrence sequence finished 5
# sequence 30
# 519 3
# 371 5
# 331 1
# 520 4
# 521 5
# 372 6
# Negative ocurrence sequence finished 12
# sequence 37
# 332 2
# 522 6
# Negative ocurrence sequence finished 37
# sequence 62
# 373 1
# 333 3
# 523 1
# 524 2
# 374 2
# 334 4
# 525 3
# 526 4
# 375 3
# 335 5
# 527 5
# 528 6
# Negative ocurrence sequence finished 38
# sequence 63
# 376 4
# 336 6
# Negative ocurrence sequence finished 6
# sequence 31
# 529 1
# 377 5
# 337 1
# 530 2
# 378 6
# Negative ocurrence sequence finished 13
# sequence 38
# 531 3
# 338 2
# 532 4
# 379 1
# 339 3
# 533 5
# 534 6
# Negative ocurrence sequence finished 39
# sequence 64
# 535 1
# 380 2
# 381 3
# 382 4
# 340 4
# 383 5
# 536 2
# 341 5
# 537 3
# 384 6
# Negative ocurrence sequence finished 14
# sequence 39
# 538 4
# 342 6
# Negative ocurrence sequence finished 7
# sequence 32
# 385 1
# 539 5
# 540 6
# Negative ocurrence sequence finished 40
# sequence 65
# 343 1
# 541 1
# 542 2
# 344 2
# 386 2
# 543 3
# 345 3
# 544 4
# 387 3
# 545 5
# 346 4
# 546 6
# Negative ocurrence sequence finished 41
# sequence 66
# 388 4
# 547 1
# 347 5
# 389 5
# 548 2
# 549 3
# 348 6
# Negative ocurrence sequence finished 8
# sequence 33
# 390 6
# Negative ocurrence sequence finished 15
# sequence 40
# 550 4
# 349 1
# 551 5
# 552 6
# Negative ocurrence sequence finished 42
# sequence 67
# 391 1
# 350 2
# 553 1
# 392 2
# 554 2
# 351 3
# 393 3
# 555 3
# 352 4
# 394 4
# 556 4
# 557 5
# 395 5
# 558 6
# Negative ocurrence sequence finished 43
# sequence 68
# 353 5
# 559 1
# 396 6
# Negative ocurrence sequence finished 16
# sequence 41
# 560 2
# 354 6
# Negative ocurrence sequence finished 9
# sequence 34
# 561 3
# 397 1
# 562 4
# 355 1
# 563 5
# 398 2
# 564 6
# Negative ocurrence sequence finished 44
# sequence 69
# 356 2
# 565 1
# 399 3
# 566 2
# 567 3
# 357 3
# 400 4
# 568 4
# 401 5
# 569 5
# 358 4
# 570 6
# Negative ocurrence sequence finished 45
# sequence 70
# 402 6
# Negative ocurrence sequence finished 17
# sequence 42
# 571 1
# 359 5
# 403 1
# 572 2
# 404 2
# 360 6
# Negative ocurrence sequence finished 10
# sequence 35
# 573 3
# 405 3
# 574 4
# 361 1
# 406 4
# 575 5
# 362 2
# 576 6
# Negative ocurrence sequence finished 46
# sequence 71
# 363 3
# 577 1
# 407 5
# 364 4
# 578 2
# 365 5
# 408 6
# Negative ocurrence sequence finished 18
# sequence 43
# 579 3
# 409 1
# 580 4
# 366 6
# Negative ocurrence sequence finished 11
# sequence 36
# 410 2
# 581 5
# 411 3
# 367 1
# 582 6
# Negative ocurrence sequence finished 47
# sequence 72
# 583 1
# 368 2
# 412 4
# 584 2
# 369 3
# 585 3
# 413 5
# 586 4
# 587 5
# 370 4
# 414 6
# Negative ocurrence sequence finished 19
# sequence 44
# 415 1
# 588 6
# Negative ocurrence sequence finished 48
# sequence 73
# 589 1
# 371 5
# 416 2
# 372 6
# Negative ocurrence sequence finished 12
# sequence 37
# 590 2
# 417 3
# 591 3
# 592 4
# 418 4
# 373 1
# 593 5
# 594 6
# Negative ocurrence sequence finished 49
# sequence 74
# 595 1
# 596 2
# 419 5
# 374 2
# 597 3
# 420 6
# Negative ocurrence sequence finished 20
# sequence 45
# 375 3
# 598 4
# 421 1
# 376 4
# 599 5
# 422 2
# 600 6
# Negative ocurrence sequence finished 50
# sequence 75
# 601 1
# 377 5
# 423 3
# 602 2
# 603 3
# 424 4
# 378 6
# Negative ocurrence sequence finished 13
# sequence 38
# 379 1
# 425 5
# 604 4
# 605 5
# 426 6
# Negative ocurrence sequence finished 21
# sequence 46
# 380 2
# 606 6
# Negative ocurrence sequence finished 51
# sequence 76
# 607 1
# 608 2
# 381 3
# 427 1
# 609 3
# 428 2
# 610 4
# 382 4
# 429 3
# 611 5
# 612 6
# Negative ocurrence sequence finished 52
# sequence 77
# 383 5
# 430 4
# 613 1
# 614 2
# 615 3
# 384 6
# Negative ocurrence sequence finished 14
# sequence 39
# 431 5
# 616 4
# 617 5
# 432 6
# Negative ocurrence sequence finished 22
# sequence 47
# 385 1
# 386 2
# 618 6
# Negative ocurrence sequence finished 53
# sequence 78
# 433 1
# 619 1
# 387 3
# 620 2
# 434 2
# 621 3
# 388 4
# 435 3
# 622 4
# 389 5
# 623 5
# 436 4
# 437 5
# 624 6
# Negative ocurrence sequence finished 54
# sequence 79
# 390 6
# Negative ocurrence sequence finished 15
# sequence 40
# 625 1
# 438 6
# Negative ocurrence sequence finished 23
# sequence 48
# 626 2
# 627 3
# 391 1
# 628 4
# 439 1
# 629 5
# 440 2
# 392 2
# 441 3
# 630 6
# Negative ocurrence sequence finished 55
# sequence 80
# 393 3
# 442 4
# 631 1
# 443 5
# 394 4
# 632 2
# 395 5
# 444 6
# Negative ocurrence sequence finished 24
# sequence 49
# 633 3
# 634 4
# 635 5
# 636 6
# Negative ocurrence sequence finished 56
# sequence 81
# 637 1
# 638 2
# 396 6
# Negative ocurrence sequence finished 16
# sequence 41
# 445 1
# 397 1
# 398 2
# 639 3
# 640 4
# 446 2
# 399 3
# 641 5
# 642 6
# Negative ocurrence sequence finished 57
# sequence 82
# 400 4
# 447 3
# 401 5
# 643 1
# 448 4
# 402 6
# Negative ocurrence sequence finished 17
# sequence 42
# 644 2
# 403 1
# 404 2
# 645 3
# 405 3
# 449 5
# 646 4
# 450 6
# Negative ocurrence sequence finished 25
# sequence 50
# 406 4
# 451 1
# 647 5
# 452 2
# 648 6
# Negative ocurrence sequence finished 58
# sequence 83
# 407 5
# 649 1
# 650 2
# 453 3
# 408 6
# Negative ocurrence sequence finished 18
# sequence 43
# 454 4
# 651 3
# 652 4
# 409 1
# 653 5
# 455 5
# 654 6
# Negative ocurrence sequence finished 59
# sequence 84
# 410 2
# 411 3
# 655 1
# 456 6
# Negative ocurrence sequence finished 26
# sequence 51
# 656 2
# 412 4
# 457 1
# 657 3
# 413 5
# 458 2
# 658 4
# 659 5
# 414 6
# Negative ocurrence sequence finished 19
# sequence 44
# 459 3
# 660 6
# Negative ocurrence sequence finished 60
# sequence 85
# 661 1
# 415 1
# 662 2
# 460 4
# 416 2
# 663 3
# 461 5
# 664 4
# 417 3
# 665 5
# 666 6
# Negative ocurrence sequence finished 61
# sequence 86
# 418 4
# 462 6
# Negative ocurrence sequence finished 27
# sequence 52
# 667 1
# 668 2
# 419 5
# 463 1
# 669 3
# 464 2
# 420 6
# Negative ocurrence sequence finished 20
# sequence 45
# 670 4
# 465 3
# 421 1
# 671 5
# 672 6
# Negative ocurrence sequence finished 62
# sequence 87
# 466 4
# 673 1
# 422 2
# 674 2
# 467 5
# 468 6
# Negative ocurrence sequence finished 28
# sequence 53
# 675 3
# 423 3
# 676 4
# 424 4
# 677 5
# 469 1
# 678 6
# Negative ocurrence sequence finished 63
# sequence 88
# 425 5
# 470 2
# 679 1
# 426 6
# Negative ocurrence sequence finished 21
# sequence 46
# 680 2
# 427 1
# 471 3
# 681 3
# 472 4
# 428 2
# 682 4
# 683 5
# 473 5
# 429 3
# 474 6
# Negative ocurrence sequence finished 29
# sequence 54
# 684 6
# Negative ocurrence sequence finished 64
# sequence 89
# 685 1
# 430 4
# 475 1
# 686 2
# 431 5
# 687 3
# 476 2
# 477 3
# 688 4
# 432 6
# Negative ocurrence sequence finished 22
# sequence 47
# 689 5
# 478 4
# 690 6
# Negative ocurrence sequence finished 65
# sequence 90
# 433 1
# 479 5
# 691 1
# 480 6
# Negative ocurrence sequence finished 30
# sequence 55
# 692 2
# 434 2
# 693 3
# 694 4
# 435 3
# 481 1
# 695 5
# 482 2
# 436 4
# 696 6
# Negative ocurrence sequence finished 66
# sequence 91
# 483 3
# 697 1
# 437 5
# 698 2
# 484 4
# 699 3
# 700 4
# 438 6
# Negative ocurrence sequence finished 23
# sequence 48
# 701 5
# 485 5
# 439 1
# 702 6
# Negative ocurrence sequence finished 67
# sequence 92
# 703 1
# 440 2
# 486 6
# Negative ocurrence sequence finished 31
# sequence 56
# 704 2
# 487 1
# 705 3
# 441 3
# 488 2
# 706 4
# 707 5
# 489 3
# 442 4
# 490 4
# 708 6
# Negative ocurrence sequence finished 68
# sequence 93
# 709 1
# 710 2
# 443 5
# 711 3
# 491 5
# 444 6
# Negative ocurrence sequence finished 24
# sequence 49
# 712 4
# 445 1
# 492 6
# Negative ocurrence sequence finished 32
# sequence 57
# 713 5
# 493 1
# 714 6
# Negative ocurrence sequence finished 69
# sequence 94
# 715 1
# 716 2
# 446 2
# 717 3
# 447 3
# 494 2
# 718 4
# 719 5
# 495 3
# 448 4
# 720 6
# Negative ocurrence sequence finished 70
# sequence 95
# 496 4
# 721 1
# 449 5
# 722 2
# 497 5
# 450 6
# Negative ocurrence sequence finished 25
# sequence 50
# 723 3
# 724 4
# 498 6
# Negative ocurrence sequence finished 33
# sequence 58
# 451 1
# 499 1
# 725 5
# 452 2
# 726 6
# Negative ocurrence sequence finished 71
# sequence 96
# 453 3
# 500 2
# 501 3
# 454 4
# 727 1
# 728 2
# 729 3
# 502 4
# 455 5
# 730 4
# 503 5
# 731 5
# 456 6
# Negative ocurrence sequence finished 26
# sequence 51
# 504 6
# Negative ocurrence sequence finished 34
# sequence 59
# 732 6
# Negative ocurrence sequence finished 72
# sequence 97
# 733 1
# 457 1
# 505 1
# 734 2
# 506 2
# 507 3
# 458 2
# 735 3
# 508 4
# 736 4
# 459 3
# 509 5
# 737 5
# 460 4
# 738 6
# Negative ocurrence sequence finished 73
# sequence 98
# 510 6
# Negative ocurrence sequence finished 35
# sequence 60
# 461 5
# 511 1
# 739 1
# 512 2
# 740 2
# 462 6
# Negative ocurrence sequence finished 27
# sequence 52
# 741 3
# 513 3
# 463 1
# 742 4
# 514 4
# 515 5
# 743 5
# 464 2
# 516 6
# Negative ocurrence sequence finished 36
# sequence 61
# 744 6
# Negative ocurrence sequence finished 74
# sequence 99
# 517 1
# 465 3
# 745 1
# 746 2
# 518 2
# 466 4
# 519 3
# 747 3
# 748 4
# 467 5
# 749 5
# 750 6
# Negative ocurrence sequence finished 75
# sequence 100
# 468 6
# Negative ocurrence sequence finished 28
# sequence 53
# 520 4
# 751 1
# 752 2
# 469 1
# 753 3
# 521 5
# 754 4
# 470 2
# 522 6
# Negative ocurrence sequence finished 37
# sequence 62
# 755 5
# 756 6
# Negative ocurrence sequence finished 76
# sequence 101
# 471 3
# 523 1
# 757 1
# 758 2
# 472 4
# 524 2
# 759 3
# 473 5
# 525 3
# 474 6
# Negative ocurrence sequence finished 29
# sequence 54
# 760 4
# 761 5
# 475 1
# 762 6
# Negative ocurrence sequence finished 77
# sequence 102
# 526 4
# 763 1
# 476 2
# 764 2
# 765 3
# 527 5
# 477 3
# 766 4
# 478 4
# 767 5
# 528 6
# Negative ocurrence sequence finished 38
# sequence 63
# 768 6
# Negative ocurrence sequence finished 78
# sequence 103
# 479 5
# 529 1
# 769 1
# 770 2
# 480 6
# Negative ocurrence sequence finished 30
# sequence 55
# 530 2
# 771 3
# 481 1
# 772 4
# 531 3
# 773 5
# 482 2
# 774 6
# Negative ocurrence sequence finished 79
# sequence 104
# 775 1
# 483 3
# 776 2
# 532 4
# 777 3
# 484 4
# 533 5
# 778 4
# 779 5
# 485 5
# 486 6
# 780 6
# Negative ocurrence sequence finished 31
# Negative ocurrence sequence finished 80
# sequence 56
# sequence 105
# 534 6
# Negative ocurrence sequence finished 39
# sequence 64
# 781 1
# 782 2
# 487 1
# 535 1
# 783 3
# 488 2
# 536 2
# 784 4
# 785 5
# 786 6
# Negative ocurrence sequence finished 81
# sequence 106
# 489 3
# 537 3
# 787 1
# 788 2
# 490 4
# 789 3
# 538 4
# 790 4
# 491 5
# 791 5
# 539 5
# 792 6
# Negative ocurrence sequence finished 82
# sequence 107
# 492 6
# Negative ocurrence sequence finished 32
# sequence 57
# 793 1
# 493 1
# 794 2
# 540 6
# Negative ocurrence sequence finished 40
# sequence 65
# 795 3
# 541 1
# 494 2
# 796 4
# 495 3
# 797 5
# 542 2
# 798 6
# Negative ocurrence sequence finished 83
# sequence 108
# 496 4
# 799 1
# 543 3
# 497 5
# 800 2
# 801 3
# 498 6
# Negative ocurrence sequence finished 33
# sequence 58
# 544 4
# 802 4
# 803 5
# 499 1
# 545 5
# 804 6
# Negative ocurrence sequence finished 84
# sequence 109
# 805 1
# 500 2
# 806 2
# 807 3
# 546 6
# Negative ocurrence sequence finished 41
# sequence 66
# 501 3
# 808 4
# 809 5
# 502 4
# 547 1
# 810 6
# Negative ocurrence sequence finished 85
# sequence 110
# 811 1
# 548 2
# 503 5
# 812 2
# 504 6
# Negative ocurrence sequence finished 34
# sequence 59
# 813 3
# 549 3
# 814 4
# 505 1
# 815 5
# 550 4
# 506 2
# 816 6
# Negative ocurrence sequence finished 86
# sequence 111
# 817 1
# 551 5
# 818 2
# 507 3
# 819 3
# 820 4
# 821 5
# 552 6
# Negative ocurrence sequence finished 42
# sequence 67
# 508 4
# 553 1
# 822 6
# Negative ocurrence sequence finished 87
# sequence 112
# 554 2
# 823 1
# 509 5
# 824 2
# 555 3
# 825 3
# 510 6
# Negative ocurrence sequence finished 35
# sequence 60
# 826 4
# 511 1
# 556 4
# 827 5
# 512 2
# 557 5
# 828 6
# Negative ocurrence sequence finished 88
# sequence 113
# 829 1
# 513 3
# 830 2
# 514 4
# 831 3
# 515 5
# 558 6
# Negative ocurrence sequence finished 43
# sequence 68
# 832 4
# 516 6
# Negative ocurrence sequence finished 36
# sequence 61
# 833 5
# 559 1
# 517 1
# 834 6
# Negative ocurrence sequence finished 89
# sequence 114
# 835 1
# 518 2
# 836 2
# 519 3
# 560 2
# 837 3
# 561 3
# 838 4
# 520 4
# 521 5
# 839 5
# 562 4
# 563 5
# 840 6
# Negative ocurrence sequence finished 90
# sequence 115
# 522 6
# Negative ocurrence sequence finished 37
# sequence 62
# 841 1
# 523 1
# 842 2
# 524 2
# 564 6
# Negative ocurrence sequence finished 44
# sequence 69
# 843 3
# 844 4
# 525 3
# 845 5
# 526 4
# 846 6
# Negative ocurrence sequence finished 91
# sequence 116
# 565 1
# 847 1
# 527 5
# 848 2
# 528 6
# Negative ocurrence sequence finished 38
# sequence 63
# 849 3
# 566 2
# 850 4
# 529 1
# 851 5
# 567 3
# 568 4
# 852 6
# Negative ocurrence sequence finished 92
# sequence 117
# 530 2
# 853 1
# 531 3
# 854 2
# 569 5
# 855 3
# 532 4
# 856 4
# 533 5
# 570 6
# Negative ocurrence sequence finished 45
# sequence 70
# 571 1
# 857 5
# 534 6
# Negative ocurrence sequence finished 39
# sequence 64
# 572 2
# 858 6
# Negative ocurrence sequence finished 93
# sequence 118
# 535 1
# 573 3
# 859 1
# 574 4
# 536 2
# 860 2
# 537 3
# 538 4
# 575 5
# 861 3
# 539 5
# 862 4
# 540 6
# Negative ocurrence sequence finished 40
# sequence 65
# 863 5
# 576 6
# Negative ocurrence sequence finished 46
# sequence 71
# 541 1
# 864 6
# Negative ocurrence sequence finished 94
# sequence 119
# 577 1
# 865 1
# 578 2
# 542 2
# 579 3
# 866 2
# 543 3
# 580 4
# 867 3
# 544 4
# 868 4
# 545 5
# 581 5
# 582 6
# Negative ocurrence sequence finished 47
# sequence 72
# 869 5
# 870 6
# Negative ocurrence sequence finished 95
# sequence 120
# 546 6
# Negative ocurrence sequence finished 41
# sequence 66
# 583 1
# 871 1
# 547 1
# 584 2
# 872 2
# 548 2
# 873 3
# 585 3
# 549 3
# 874 4
# 875 5
# 876 6
# Negative ocurrence sequence finished 96
# sequence 121
# 586 4
# 587 5
# 550 4
# 877 1
# 551 5
# 878 2
# 588 6
# Negative ocurrence sequence finished 48
# sequence 73
# 879 3
# 589 1
# 552 6
# Negative ocurrence sequence finished 42
# sequence 67
# 880 4
# 553 1
# 881 5
# 590 2
# 882 6
# Negative ocurrence sequence finished 97
# sequence 122
# 554 2
# 883 1
# 591 3
# 555 3
# 884 2
# 592 4
# 593 5
# 556 4
# 885 3
# 557 5
# 886 4
# 558 6
# Negative ocurrence sequence finished 43
# sequence 68
# 887 5
# 594 6
# Negative ocurrence sequence finished 49
# sequence 74
# 888 6
# Negative ocurrence sequence finished 98
# sequence 123
# 559 1
# 889 1
# 560 2
# 595 1
# 890 2
# 596 2
# 561 3
# 597 3
# 891 3
# 598 4
# 562 4
# 892 4
# 563 5
# 599 5
# 893 5
# 894 6
# Negative ocurrence sequence finished 99
# sequence 124
# 564 6
# Negative ocurrence sequence finished 44
# sequence 69
# 600 6
# Negative ocurrence sequence finished 50
# sequence 75
# 565 1
# 895 1
# 601 1
# 896 2
# 566 2
# 897 3
# 602 2
# 567 3
# 603 3
# 898 4
# 568 4
# 569 5
# 899 5
# 604 4
# 570 6
# Negative ocurrence sequence finished 45
# sequence 70
# 900 6
# Negative ocurrence sequence finished 100
# sequence 125
# 605 5
# 901 1
# 571 1
# 606 6
# Negative ocurrence sequence finished 51
# sequence 76
# 902 2
# 572 2
# 903 3
# 573 3
# 904 4
# 607 1
# 574 4
# 905 5
# 608 2
# 906 6
# Negative ocurrence sequence finished 101
# sequence 126
# 575 5
# 907 1
# 908 2
# 609 3
# 909 3
# 576 6
# Negative ocurrence sequence finished 46
# sequence 71
# 577 1
# 910 4
# 610 4
# 578 2
# 911 5
# 579 3
# 611 5
# 912 6
# Negative ocurrence sequence finished 102
# sequence 127
# 580 4
# 913 1
# 581 5
# 914 2
# 612 6
# Negative ocurrence sequence finished 52
# sequence 77
# 582 6
# Negative ocurrence sequence finished 47
# sequence 72
# 915 3
# 916 4
# 583 1
# 613 1
# 917 5
# 614 2
# 584 2
# 918 6
# Negative ocurrence sequence finished 103
# sequence 128
# 585 3
# 919 1
# 920 2
# 586 4
# 615 3
# 921 3
# 922 4
# 587 5
# 616 4
# 923 5
# 588 6
# Negative ocurrence sequence finished 48
# sequence 73
# 924 6
# Negative ocurrence sequence finished 104
# sequence 129
# 589 1
# 925 1
# 617 5
# 590 2
# 926 2
# 618 6
# Negative ocurrence sequence finished 53
# sequence 78
# 591 3
# 927 3
# 928 4
# 592 4
# 619 1
# 593 5
# 929 5
# 594 6
# Negative ocurrence sequence finished 49
# sequence 74
# 930 6
# Negative ocurrence sequence finished 105
# sequence 130
# 595 1
# 620 2
# 931 1
# 596 2
# 932 2
# 933 3
# 597 3
# 621 3
# 934 4
# 598 4
# 935 5
# 599 5
# 622 4
# 936 6
# Negative ocurrence sequence finished 106
# sequence 131
# 600 6
# Negative ocurrence sequence finished 50
# sequence 75
# 937 1
# 601 1
# 938 2
# 623 5
# 602 2
# 603 3
# 939 3
# 624 6
# Negative ocurrence sequence finished 54
# sequence 79
# 940 4
# 604 4
# 625 1
# 941 5
# 942 6
# Negative ocurrence sequence finished 107
# sequence 132
# 605 5
# 943 1
# 606 6
# Negative ocurrence sequence finished 51
# sequence 76
# 607 1
# 626 2
# 944 2
# 945 3
# 627 3
# 608 2
# 946 4
# 628 4
# 609 3
# 629 5
# 947 5
# 948 6
# Negative ocurrence sequence finished 108
# sequence 133
# 610 4
# 630 6
# Negative ocurrence sequence finished 55
# sequence 80
# 949 1
# 611 5
# 950 2
# 612 6
# Negative ocurrence sequence finished 52
# sequence 77
# 631 1
# 951 3
# 632 2
# 613 1
# 952 4
# 614 2
# 953 5
# 633 3
# 954 6
# Negative ocurrence sequence finished 109
# sequence 134
# 615 3
# 955 1
# 634 4
# 616 4
# 956 2
# 617 5
# 635 5
# 618 6
# Negative ocurrence sequence finished 53
# sequence 78
# 957 3
# 636 6
# Negative ocurrence sequence finished 56
# sequence 81
# 619 1
# 958 4
# 620 2
# 637 1
# 959 5
# 621 3
# 960 6
# Negative ocurrence sequence finished 110
# sequence 135
# 622 4
# 961 1
# 638 2
# 623 5
# 962 2
# 624 6
# Negative ocurrence sequence finished 54
# sequence 79
# 963 3
# 639 3
# 625 1
# 964 4
# 626 2
# 640 4
# 965 5
# 966 6
# Negative ocurrence sequence finished 111
# sequence 136
# 967 1
# 968 2
# 627 3
# 628 4
# 969 3
# 641 5
# 629 5
# 630 6
# Negative ocurrence sequence finished 55
# sequence 80
# 970 4
# 631 1
# 971 5
# 632 2
# 642 6
# Negative ocurrence sequence finished 57
# sequence 82
# 972 6
# Negative ocurrence sequence finished 112
# sequence 137
# 973 1
# 974 2
# 975 3
# 643 1
# 633 3
# 976 4
# 644 2
# 634 4
# 635 5
# 977 5
# 636 6
# Negative ocurrence sequence finished 56
# sequence 81
# 978 6
# Negative ocurrence sequence finished 113
# sequence 138
# 645 3
# 637 1
# 979 1
# 646 4
# 638 2
# 980 2
# 981 3
# 639 3
# 647 5
# 640 4
# 648 6
# Negative ocurrence sequence finished 58
# sequence 83
# 982 4
# 641 5
# 983 5
# 649 1
# 984 6
# Negative ocurrence sequence finished 114
# sequence 139
# 642 6
# Negative ocurrence sequence finished 57
# sequence 82
# 985 1
# 643 1
# 650 2
# 986 2
# 987 3
# 644 2
# 651 3
# 988 4
# 645 3
# 652 4
# 989 5
# 646 4
# 990 6
# Negative ocurrence sequence finished 115
# sequence 140
# 647 5
# 991 1
# 648 6
# Negative ocurrence sequence finished 58
# sequence 83
# 653 5
# 992 2
# 993 3
# 654 6
# Negative ocurrence sequence finished 59
# sequence 84
# 649 1
# 994 4
# 655 1
# 650 2
# 995 5
# 651 3
# 996 6
# Negative ocurrence sequence finished 116
# sequence 141
# 656 2
# 652 4
# 997 1
# 998 2
# 653 5
# 999 3
# 657 3
# 654 6
# Negative ocurrence sequence finished 59
# sequence 84
# 658 4
# 655 1
# 1000 4
# 656 2
# 659 5
# 657 3
# 660 6
# Negative ocurrence sequence finished 60
# sequence 85
# 1001 5
# 661 1
# 1002 6
# Negative ocurrence sequence finished 117
# sequence 142
# 658 4
# 1003 1
# 659 5
# 1004 2
# 662 2
# 660 6
# Negative ocurrence sequence finished 60
# sequence 85
# 663 3
# 1005 3
# 661 1
# 1006 4
# 664 4
# 662 2
# 1007 5
# 665 5
# 663 3
# 1008 6
# Negative ocurrence sequence finished 118
# sequence 143
# 666 6
# Negative ocurrence sequence finished 61
# sequence 86
# 1009 1
# 664 4
# 1010 2
# 665 5
# 667 1
# 1011 3
# 668 2
# 666 6
# Negative ocurrence sequence finished 61
# sequence 86
# 1012 4
# 667 1
# 1013 5
# 669 3
# 668 2
# 1014 6
# Negative ocurrence sequence finished 119
# sequence 144
# 670 4
# 669 3
# 1015 1
# 1016 2
# 670 4
# 671 5
# 671 5
# 1017 3
# 672 6
# Negative ocurrence sequence finished 62
# sequence 87
# 672 6
# Negative ocurrence sequence finished 62
# sequence 87
# 1018 4
# 673 1
# 1019 5
# 673 1
# 674 2
# 1020 6
# Negative ocurrence sequence finished 120
# sequence 145
# 675 3
# 1021 1
# 674 2
# 676 4
# 1022 2
# 675 3
# 1023 3
# 1024 4
# 677 5
# 1025 5
# 678 6
# Negative ocurrence sequence finished 63
# sequence 88
# 676 4
# 679 1
# 1026 6
# Negative ocurrence sequence finished 121
# sequence 146
# 677 5
# 680 2
# 1027 1
# 681 3
# 1028 2
# 1029 3
# 678 6
# Negative ocurrence sequence finished 63
# sequence 88
# 682 4
# 679 1
# 1030 4
# 680 2
# 683 5
# 1031 5
# 681 3
# 684 6
# Negative ocurrence sequence finished 64
# sequence 89
# 1032 6
# Negative ocurrence sequence finished 122
# sequence 147
# 1033 1
# 682 4
# 685 1
# 686 2
# 1034 2
# 683 5
# 1035 3
# 687 3
# 1036 4
# 688 4
# 684 6
# Negative ocurrence sequence finished 64
# sequence 89
# 1037 5
# 685 1
# 689 5
# 1038 6
# Negative ocurrence sequence finished 123
# sequence 148
# 690 6
# Negative ocurrence sequence finished 65
# sequence 90
# 686 2
# 1039 1
# 691 1
# 687 3
# 1040 2
# 688 4
# 692 2
# 693 3
# 1041 3
# 689 5
# 694 4
# 1042 4
# 695 5
# 690 6
# Negative ocurrence sequence finished 65
# sequence 90
# 1043 5
# 696 6
# Negative ocurrence sequence finished 66
# sequence 91
# 1044 6
# Negative ocurrence sequence finished 124
# sequence 149
# 697 1
# 691 1
# 1045 1
# 698 2
# 692 2
# 1046 2
# 699 3
# 1047 3
# 693 3
# 1048 4
# 694 4
# 700 4
# 1049 5
# 695 5
# 701 5
# 1050 6
# Negative ocurrence sequence finished 125
# sequence 150
# 696 6
# Negative ocurrence sequence finished 66
# sequence 91
# 697 1
# 702 6
# Negative ocurrence sequence finished 67
# sequence 92
# 698 2
# 1051 1
# 703 1
# 699 3
# 1052 2
# 1053 3
# 704 2
# 1054 4
# 700 4
# 705 3
# 1055 5
# 1056 6
# Negative ocurrence sequence finished 126
# sequence 151
# 706 4
# 701 5
# 1057 1
# 702 6
# Negative ocurrence sequence finished 67
# sequence 92
# 707 5
# 1058 2
# 708 6
# Negative ocurrence sequence finished 68
# sequence 93
# 709 1
# 703 1
# 1059 3
# 710 2
# 704 2
# 711 3
# 1060 4
# 705 3
# 706 4
# 712 4
# 1061 5
# 707 5
# 1062 6
# Negative ocurrence sequence finished 127
# sequence 152
# 713 5
# 708 6
# Negative ocurrence sequence finished 68
# sequence 93
# 1063 1
# 709 1
# 714 6
# Negative ocurrence sequence finished 69
# sequence 94
# 715 1
# 1064 2
# 716 2
# 710 2
# 1065 3
# 1066 4
# 1067 5
# 711 3
# 717 3
# 1068 6
# Negative ocurrence sequence finished 128
# sequence 153
# 718 4
# 712 4
# 713 5
# 719 5
# 714 6
# Negative ocurrence sequence finished 69
# sequence 94
# 1069 1
# 720 6
# Negative ocurrence sequence finished 70
# sequence 95
# 1070 2
# 715 1
# 721 1
# 1071 3
# 716 2
# 722 2
# 1072 4
# 717 3
# 723 3
# 1073 5
# 724 4
# 1074 6
# Negative ocurrence sequence finished 129
# sequence 154
# 718 4
# 725 5
# 726 6
# Negative ocurrence sequence finished 71
# sequence 96
# 1075 1
# 719 5
# 1076 2
# 1077 3
# 727 1
# 1078 4
# 728 2
# 720 6
# Negative ocurrence sequence finished 70
# sequence 95
# 1079 5
# 729 3
# 730 4
# 1080 6
# Negative ocurrence sequence finished 130
# sequence 155
# 731 5
# 721 1
# 1081 1
# 732 6
# Negative ocurrence sequence finished 72
# sequence 97
# 1082 2
# 722 2
# 1083 3
# 733 1
# 1084 4
# 734 2
# 723 3
# 1085 5
# 1086 6
# Negative ocurrence sequence finished 131
# sequence 156
# 1087 1
# 724 4
# 735 3
# 725 5
# 1088 2
# 736 4
# 1089 3
# 726 6
# Negative ocurrence sequence finished 71
# sequence 96
# 737 5
# 727 1
# 1090 4
# 738 6
# Negative ocurrence sequence finished 73
# sequence 98
# 1091 5
# 728 2
# 739 1
# 1092 6
# Negative ocurrence sequence finished 132
# sequence 157
# 740 2
# 729 3
# 1093 1
# 741 3
# 1094 2
# 742 4
# 730 4
# 731 5
# 1095 3
# 1096 4
# 743 5
# 744 6
# Negative ocurrence sequence finished 74
# sequence 99
# 732 6
# Negative ocurrence sequence finished 72
# sequence 97
# 1097 5
# 1098 6
# Negative ocurrence sequence finished 133
# sequence 158
# 745 1
# 733 1
# 1099 1
# 746 2
# 734 2
# 1100 2
# 735 3
# 1101 3
# 747 3
# 1102 4
# 736 4
# 748 4
# 737 5
# 749 5
# 1103 5
# 750 6
# Negative ocurrence sequence finished 75
# sequence 100
# 1104 6
# Negative ocurrence sequence finished 134
# sequence 159
# 738 6
# Negative ocurrence sequence finished 73
# sequence 98
# 739 1
# 1105 1
# 751 1
# 1106 2
# 740 2
# 752 2
# 1107 3
# 1108 4
# 753 3
# 741 3
# 1109 5
# 1110 6
# Negative ocurrence sequence finished 135
# sequence 160
# 754 4
# 1111 1
# 742 4
# 1112 2
# 1113 3
# 755 5
# 743 5
# 1114 4
# 1115 5
# 756 6
# Negative ocurrence sequence finished 76
# sequence 101
# 1116 6
# 744 6
# Negative ocurrence sequence finished 74
# Negative ocurrence sequence finished 136
# sequence 161
# sequence 99
# 745 1
# 757 1
# 746 2
# 1117 1
# 758 2
# 1118 2
# 1119 3
# 747 3
# 759 3
# 1120 4
# 760 4
# 1121 5
# 748 4
# 761 5
# 749 5
# 1122 6
# Negative ocurrence sequence finished 137
# sequence 162
# 762 6
# Negative ocurrence sequence finished 77
# sequence 102
# 1123 1
# 1124 2
# 750 6
# Negative ocurrence sequence finished 75
# sequence 100
# 1125 3
# 763 1
# 751 1
# 1126 4
# 764 2
# 752 2
# 765 3
# 1127 5
# 766 4
# 753 3
# 1128 6
# Negative ocurrence sequence finished 138
# sequence 163
# 767 5
# 1129 1
# 754 4
# 768 6
# Negative ocurrence sequence finished 78
# sequence 103
# 1130 2
# 755 5
# 1131 3
# 769 1
# 1132 4
# 770 2
# 1133 5
# 756 6
# Negative ocurrence sequence finished 76
# sequence 101
# 757 1
# 771 3
# 1134 6
# Negative ocurrence sequence finished 139
# sequence 164
# 758 2
# 1135 1
# 772 4
# 759 3
# 1136 2
# 760 4
# 773 5
# 1137 3
# 774 6
# Negative ocurrence sequence finished 79
# sequence 104
# 1138 4
# 761 5
# 1139 5
# 775 1
# 1140 6
# Negative ocurrence sequence finished 140
# sequence 165
# 762 6
# Negative ocurrence sequence finished 77
# sequence 102
# 763 1
# 776 2
# 1141 1
# 764 2
# 777 3
# 1142 2
# 778 4
# 765 3
# 1143 3
# 779 5
# 1144 4
# 780 6
# Negative ocurrence sequence finished 80
# sequence 105
# 781 1
# 766 4
# 1145 5
# 782 2
# 767 5
# 1146 6
# Negative ocurrence sequence finished 141
# sequence 166
# 1147 1
# 783 3
# 1148 2
# 784 4
# 768 6
# Negative ocurrence sequence finished 78
# sequence 103
# 1149 3
# 785 5
# 769 1
# 1150 4
# 770 2
# 786 6
# Negative ocurrence sequence finished 81
# sequence 106
# 1151 5
# 771 3
# 787 1
# 772 4
# 1152 6
# Negative ocurrence sequence finished 142
# sequence 167
# 1153 1
# 788 2
# 1154 2
# 773 5
# 1155 3
# 789 3
# 774 6
# Negative ocurrence sequence finished 79
# sequence 104
# 1156 4
# 790 4
# 775 1
# 776 2
# 1157 5
# 777 3
# 778 4
# 1158 6
# Negative ocurrence sequence finished 143
# sequence 168
# 791 5
# 1159 1
# 779 5
# 792 6
# Negative ocurrence sequence finished 82
# sequence 107
# 793 1
# 780 6
# Negative ocurrence sequence finished 80
# sequence 105
# 1160 2
# 794 2
# 781 1
# 782 2
# 795 3
# 1161 3
# 796 4
# 783 3
# 797 5
# 1162 4
# 1163 5
# 1164 6
# Negative ocurrence sequence finished 144
# sequence 169
# 798 6
# Negative ocurrence sequence finished 83
# sequence 108
# 784 4
# 1165 1
# 785 5
# 799 1
# 1166 2
# 786 6
# Negative ocurrence sequence finished 81
# sequence 106
# 1167 3
# 800 2
# 1168 4
# 1169 5
# 787 1
# 801 3
# 802 4
# 1170 6
# Negative ocurrence sequence finished 145
# sequence 170
# 803 5
# 804 6
# Negative ocurrence sequence finished 84
# sequence 109
# 1171 1
# 788 2
# 789 3
# 805 1
# 1172 2
# 806 2
# 1173 3
# 807 3
# 790 4
# 1174 4
# 808 4
# 791 5
# 1175 5
# 809 5
# 1176 6
# Negative ocurrence sequence finished 146
# sequence 171
# 1177 1
# 792 6
# Negative ocurrence sequence finished 82
# sequence 107
# 810 6
# Negative ocurrence sequence finished 85
# sequence 110
# 1178 2
# 793 1
# 1179 3
# 811 1
# 794 2
# 1180 4
# 812 2
# 795 3
# 1181 5
# 796 4
# 813 3
# 797 5
# 1182 6
# Negative ocurrence sequence finished 147
# sequence 172
# 1183 1
# 814 4
# 798 6
# Negative ocurrence sequence finished 83
# sequence 108
# 1184 2
# 815 5
# 799 1
# 1185 3
# 800 2
# 816 6
# Negative ocurrence sequence finished 86
# sequence 111
# 1186 4
# 817 1
# 1187 5
# 801 3
# 1188 6
# Negative ocurrence sequence finished 148
# sequence 173
# 802 4
# 818 2
# 1189 1
# 1190 2
# 803 5
# 819 3
# 1191 3
# 804 6
# Negative ocurrence sequence finished 84
# sequence 109
# 820 4
# 1192 4
# 805 1
# 821 5
# 1193 5
# 806 2
# 1194 6
# Negative ocurrence sequence finished 149
# sequence 174
# 822 6
# Negative ocurrence sequence finished 87
# sequence 112
# 807 3
# 823 1
# 824 2
# 1195 1
# 825 3
# 808 4
# 809 5
# 1196 2
# 826 4
# 1197 3
# 810 6
# Negative ocurrence sequence finished 85
# sequence 110
# 1198 4
# 827 5
# 828 6
# Negative ocurrence sequence finished 88
# sequence 113
# 1199 5
# 811 1
# 829 1
# 1200 6
# Negative ocurrence sequence finished 150
# sequence 175
# 812 2
# 830 2
# 1201 1
# 813 3
# 831 3
# 814 4
# 1202 2
# 832 4
# 1203 3
# 815 5
# 833 5
# 1204 4
# 816 6
# Negative ocurrence sequence finished 86
# sequence 111
# 834 6
# Negative ocurrence sequence finished 89
# sequence 114
# 835 1
# 1205 5
# 836 2
# 1206 6
# Negative ocurrence sequence finished 151
# sequence 176
# 817 1
# 818 2
# 837 3
# 1207 1
# 819 3
# 838 4
# 1208 2
# 820 4
# 821 5
# 1209 3
# 822 6
# Negative ocurrence sequence finished 87
# sequence 112
# 839 5
# 823 1
# 824 2
# 1210 4
# 825 3
# 840 6
# Negative ocurrence sequence finished 90
# sequence 115
# 1211 5
# 841 1
# 826 4
# 1212 6
# Negative ocurrence sequence finished 152
# sequence 177
# 827 5
# 842 2
# 828 6
# Negative ocurrence sequence finished 88
# sequence 113
# 1213 1
# 843 3
# 1214 2
# 829 1
# 844 4
# 1215 3
# 1216 4
# 845 5
# 830 2
# 1217 5
# 846 6
# Negative ocurrence sequence finished 91
# sequence 116
# 1218 6
# Negative ocurrence sequence finished 153
# sequence 178
# 831 3
# 1219 1
# 847 1
# 848 2
# 1220 2
# 1221 3
# 832 4
# 1222 4
# 849 3
# 1223 5
# 1224 6
# Negative ocurrence sequence finished 154
# sequence 179
# 850 4
# 1225 1
# 833 5
# 834 6
# Negative ocurrence sequence finished 89
# sequence 114
# 1226 2
# 851 5
# 1227 3
# 835 1
# 1228 4
# 852 6
# Negative ocurrence sequence finished 92
# sequence 117
# 1229 5
# 836 2
# 853 1
# 837 3
# 1230 6
# Negative ocurrence sequence finished 155
# sequence 180
# 1231 1
# 854 2
# 855 3
# 1232 2
# 838 4
# 1233 3
# 856 4
# 839 5
# 1234 4
# 840 6
# Negative ocurrence sequence finished 90
# sequence 115
# 1235 5
# 1236 6
# Negative ocurrence sequence finished 156
# sequence 181
# 1237 1
# 1238 2
# 857 5
# 841 1
# 1239 3
# 858 6
# Negative ocurrence sequence finished 93
# sequence 118
# 1240 4
# 842 2
# 1241 5
# 859 1
# 843 3
# 1242 6
# Negative ocurrence sequence finished 157
# sequence 182
# 1243 1
# 860 2
# 1244 2
# 844 4
# 861 3
# 1245 3
# 845 5
# 1246 4
# 862 4
# 846 6
# Negative ocurrence sequence finished 91
# sequence 116
# 863 5
# 1247 5
# 1248 6
# Negative ocurrence sequence finished 158
# sequence 183
# 864 6
# Negative ocurrence sequence finished 94
# sequence 119
# 847 1
# 1249 1
# 848 2
# 865 1
# 1250 2
# 849 3
# 1251 3
# 866 2
# 1252 4
# 867 3
# 1253 5
# 850 4
# 1254 6
# Negative ocurrence sequence finished 159
# sequence 184
# 1255 1
# 868 4
# 851 5
# 1256 2
# 869 5
# 1257 3
# 1258 4
# 852 6
# Negative ocurrence sequence finished 92
# sequence 117
# 870 6
# Negative ocurrence sequence finished 95
# sequence 120
# 1259 5
# 853 1
# 1260 6
# Negative ocurrence sequence finished 160
# sequence 185
# 871 1
# 1261 1
# 854 2
# 872 2
# 1262 2
# 1263 3
# 873 3
# 855 3
# 1264 4
# 874 4
# 856 4
# 1265 5
# 1266 6
# Negative ocurrence sequence finished 161
# sequence 186
# 857 5
# 875 5
# 1267 1
# 858 6
# Negative ocurrence sequence finished 93
# sequence 118
# 1268 2
# 876 6
# Negative ocurrence sequence finished 96
# sequence 121
# 1269 3
# 859 1
# 877 1
# 1270 4
# 1271 5
# 860 2
# 861 3
# 878 2
# 862 4
# 1272 6
# Negative ocurrence sequence finished 162
# sequence 187
# 879 3
# 1273 1
# 863 5
# 864 6
# Negative ocurrence sequence finished 94
# sequence 119
# 1274 2
# 880 4
# 1275 3
# 865 1
# 1276 4
# 881 5
# 1277 5
# 1278 6
# Negative ocurrence sequence finished 163
# sequence 188
# 866 2
# 1279 1
# 882 6
# Negative ocurrence sequence finished 97
# sequence 122
# 867 3
# 883 1
# 868 4
# 884 2
# 1280 2
# 1281 3
# 1282 4
# 885 3
# 1283 5
# 869 5
# 1284 6
# Negative ocurrence sequence finished 164
# sequence 189
# 886 4
# 870 6
# Negative ocurrence sequence finished 95
# sequence 120
# 1285 1
# 871 1
# 1286 2
# 887 5
# 1287 3
# 872 2
# 888 6
# Negative ocurrence sequence finished 98
# sequence 123
# 889 1
# 1288 4
# 873 3
# 1289 5
# 890 2
# 1290 6
# Negative ocurrence sequence finished 165
# sequence 190
# 874 4
# 875 5
# 1291 1
# 1292 2
# 891 3
# 1293 3
# 876 6
# Negative ocurrence sequence finished 96
# sequence 121
# 1294 4
# 892 4
# 877 1
# 893 5
# 1295 5
# 878 2
# 1296 6
# Negative ocurrence sequence finished 166
# sequence 191
# 1297 1
# 894 6
# Negative ocurrence sequence finished 99
# sequence 124
# 895 1
# 1298 2
# 879 3
# 896 2
# 880 4
# 1299 3
# 881 5
# 897 3
# 1300 4
# 882 6
# Negative ocurrence sequence finished 97
# sequence 122
# 898 4
# 1301 5
# 883 1
# 1302 6
# Negative ocurrence sequence finished 167
# sequence 192
# Train CSV for patient 1 has been completed...
# 899 5
# 884 2
# 900 6
# Negative ocurrence sequence finished 100
# sequence 125
# 885 3
# 886 4
# 901 1
# 887 5
# 902 2
# 888 6
# Negative ocurrence sequence finished 98
# sequence 123
# 903 3
# 889 1
# 904 4
# 890 2
# 891 3
# 905 5
# 892 4
# 906 6
# Negative ocurrence sequence finished 101
# sequence 126
# 893 5
# 907 1
# 894 6
# Negative ocurrence sequence finished 99
# sequence 124
# 895 1
# 896 2
# 908 2
# 897 3
# 898 4
# 909 3
# 899 5
# 910 4
# 900 6
# Negative ocurrence sequence finished 100
# sequence 125
# 901 1
# 911 5
# 902 2
# 903 3
# 912 6
# Negative ocurrence sequence finished 102
# sequence 127
# 904 4
# 905 5
# 913 1
# 906 6
# Negative ocurrence sequence finished 101
# sequence 126
# 907 1
# 914 2
# 908 2
# 915 3
# 909 3
# 916 4
# 910 4
# 911 5
# 917 5
# 912 6
# Negative ocurrence sequence finished 102
# sequence 127
# 913 1
# 918 6
# Negative ocurrence sequence finished 103
# sequence 128
# 914 2
# 915 3
# 919 1
# 920 2
# 916 4
# 917 5
# 918 6
# Negative ocurrence sequence finished 103
# sequence 128
# 921 3
# 919 1
# 922 4
# 920 2
# 923 5
# 921 3
# 922 4
# 924 6
# Negative ocurrence sequence finished 104
# sequence 129
# 923 5
# 924 6
# Negative ocurrence sequence finished 104
# sequence 129
# 925 1
# 925 1
# 926 2
# 926 2
# 927 3
# 927 3
# 928 4
# 928 4
# 929 5
# 929 5
# 930 6
# Negative ocurrence sequence finished 105
# sequence 130
# 930 6
# Negative ocurrence sequence finished 105
# sequence 130
# 931 1
# 931 1
# 932 2
# 932 2
# 933 3
# 934 4
# 933 3
# 935 5
# 934 4
# 936 6
# Negative ocurrence sequence finished 106
# sequence 131
# 935 5
# 937 1
# 936 6
# Negative ocurrence sequence finished 106
# sequence 131
# 938 2
# 937 1
# 938 2
# 939 3
# 940 4
# 939 3
# 941 5
# 940 4
# 942 6
# Negative ocurrence sequence finished 107
# sequence 132
# 943 1
# 941 5
# 944 2
# 945 3
# 942 6
# Negative ocurrence sequence finished 107
# sequence 132
# 946 4
# 947 5
# 943 1
# 948 6
# Negative ocurrence sequence finished 108
# sequence 133
# 949 1
# 944 2
# 950 2
# 951 3
# 952 4
# 945 3
# 953 5
# 954 6
# Negative ocurrence sequence finished 109
# sequence 134
# 946 4
# 955 1
# 947 5
# 956 2
# 957 3
# 948 6
# Negative ocurrence sequence finished 108
# sequence 133
# 949 1
# 958 4
# 959 5
# 950 2
# 960 6
# Negative ocurrence sequence finished 110
# sequence 135
# 951 3
# 961 1
# 952 4
# 962 2
# 953 5
# 963 3
# 964 4
# 954 6
# Negative ocurrence sequence finished 109
# sequence 134
# 965 5
# 966 6
# Negative ocurrence sequence finished 111
# sequence 136
# 955 1
# 967 1
# 956 2
# 968 2
# 969 3
# 957 3
# 970 4
# 971 5
# 958 4
# 972 6
# Negative ocurrence sequence finished 112
# sequence 137
# 959 5
# 973 1
# 974 2
# 960 6
# Negative ocurrence sequence finished 110
# sequence 135
# 975 3
# 961 1
# 976 4
# 962 2
# 977 5
# 963 3
# 978 6
# Negative ocurrence sequence finished 113
# sequence 138
# 979 1
# 964 4
# 980 2
# 965 5
# 981 3
# 966 6
# Negative ocurrence sequence finished 111
# sequence 136
# 982 4
# 983 5
# 984 6
# Negative ocurrence sequence finished 114
# sequence 139
# 967 1
# 985 1
# 968 2
# 986 2
# 969 3
# 987 3
# 970 4
# 988 4
# 971 5
# 989 5
# 972 6
# Negative ocurrence sequence finished 112
# sequence 137
# 973 1
# 990 6
# Negative ocurrence sequence finished 115
# sequence 140
# 974 2
# 991 1
# 992 2
# 975 3
# 993 3
# 976 4
# 994 4
# 977 5
# 995 5
# 978 6
# Negative ocurrence sequence finished 113
# sequence 138
# 996 6
# Negative ocurrence sequence finished 116
# sequence 141
# 979 1
# 997 1
# 980 2
# 998 2
# 981 3
# 999 3
# 982 4
# 1000 4
# 1001 5
# 983 5
# 1002 6
# Negative ocurrence sequence finished 117
# sequence 142
# 1003 1
# 984 6
# Negative ocurrence sequence finished 114
# sequence 139
# 1004 2
# 1005 3
# 985 1
# 1006 4
# 986 2
# 987 3
# 1007 5
# 988 4
# 1008 6
# Negative ocurrence sequence finished 118
# sequence 143
# 1009 1
# 989 5
# 990 6
# Negative ocurrence sequence finished 115
# sequence 140
# 1010 2
# 991 1
# 992 2
# 1011 3
# 1012 4
# 1013 5
# 993 3
# 1014 6
# Negative ocurrence sequence finished 119
# sequence 144
# 994 4
# 1015 1
# 995 5
# 996 6
# Negative ocurrence sequence finished 116
# sequence 141
# 1016 2
# 1017 3
# 997 1
# 998 2
# 1018 4
# 999 3
# 1019 5
# 1000 4
# 1001 5
# 1020 6
# Negative ocurrence sequence finished 120
# sequence 145
# 1002 6
# Negative ocurrence sequence finished 117
# sequence 142
# 1021 1
# 1003 1
# 1022 2
# 1004 2
# 1023 3
# 1005 3
# 1006 4
# 1024 4
# 1007 5
# 1008 6
# Negative ocurrence sequence finished 118
# sequence 143
# 1025 5
# 1009 1
# 1026 6
# Negative ocurrence sequence finished 121
# sequence 146
# 1010 2
# 1027 1
# 1028 2
# 1011 3
# 1029 3
# 1012 4
# 1013 5
# 1030 4
# 1031 5
# 1014 6
# Negative ocurrence sequence finished 119
# sequence 144
# 1032 6
# Negative ocurrence sequence finished 122
# sequence 147
# 1015 1
# 1016 2
# 1033 1
# 1034 2
# Test CSV for patient 2 has been completed...
# 1035 3
# 1017 3
# 1036 4
# 1018 4
# 1019 5
# 1037 5
# 1038 6
# Negative ocurrence sequence finished 123
# sequence 148
# 1020 6
# Negative ocurrence sequence finished 120
# sequence 145
# 1021 1
# 1039 1
# 1022 2
# 1040 2
# 1023 3
# 1041 3
# 1042 4
# 1024 4
# 1043 5
# 1025 5
# 1044 6
# Negative ocurrence sequence finished 124
# sequence 149
# Test CSV for patient 1 has been completed...
# 1026 6
# Negative ocurrence sequence finished 121
# sequence 146
# 1045 1
# 1027 1
# 1028 2
# 1046 2
# 1029 3
# 1047 3
# Test CSV for patient 3 has been completed...
# 1048 4
# 1030 4
# 1049 5
# 1031 5
# 1050 6
# Negative ocurrence sequence finished 125
# sequence 150
# 1032 6
# Negative ocurrence sequence finished 122
# sequence 147
# 1051 1
# 1033 1
# 1052 2
# 1034 2
# 1053 3
# 1035 3
# 1054 4
# 1036 4
# 1055 5
# 1037 5
# 1038 6
# 1056 6
# Negative ocurrence sequence finished 126
# sequence 151
# Negative ocurrence sequence finished 123
# sequence 148
# 1057 1
# 1039 1
# 1058 2
# 1040 2
# 1059 3
# 1041 3
# 1060 4
# 1042 4
# 1061 5
# 1043 5
# 1062 6
# Negative ocurrence sequence finished 127
# sequence 152
# 1044 6
# Negative ocurrence sequence finished 124
# sequence 149
# 1063 1
# 1045 1
# 1064 2
# 1046 2
# 1065 3
# 1047 3
# 1066 4
# ...
# sequence 293
# 1904 2
# 1909 1
# 1905 3
# 1910 2
# 1906 4
# 1911 3
# 1912 4
# 1907 5
# 1913 5
# 1908 6
# Negative ocurrence sequence finished 268
# sequence 293
# 1914 6
# Negative ocurrence sequence finished 269
# sequence 294
# 1909 1
# 1915 1
# 1910 2
# 1916 2
# 1911 3
# 1917 3
# 1912 4
# 1918 4
# 1913 5
# 1919 5
# 1914 6
# Negative ocurrence sequence finished 269
# sequence 294
# 1920 6
# Negative ocurrence sequence finished 270
# sequence 295
# 1915 1
# 1921 1
# 1916 2
# 1922 2
# 1917 3
# 1923 3
# 1918 4
# 1924 4
# 1919 5
# 1925 5
# 1920 6
# Negative ocurrence sequence finished 270
# sequence 295
# 1926 6
# Negative ocurrence sequence finished 271
# sequence 296
# 1921 1
# 1927 1
# 1922 2
# 1928 2
# 1923 3
# 1929 3
# 1924 4
# 1930 4
# 1925 5
# 1931 5
# 1926 6
# Negative ocurrence sequence finished 271
# sequence 296
# 1932 6
# Negative ocurrence sequence finished 272
# sequence 297
# 1927 1
# 1933 1
# 1928 2
# 1934 2
# 1929 3
# 1935 3
# 1930 4
# 1936 4
# 1931 5
# 1937 5
# 1932 6
# Negative ocurrence sequence finished 272
# sequence 297
# 1938 6
# Negative ocurrence sequence finished 273
# sequence 298
# 1933 1
# 1939 1
# 1934 2
# 1940 2
# 1935 3
# 1941 3
# 1936 4
# 1942 4
# 1937 5
# 1943 5
# 1938 6
# Negative ocurrence sequence finished 273
# sequence 298
# 1944 6
# Negative ocurrence sequence finished 274
# sequence 299
# 1939 1
# 1945 1
# 1940 2
# 1946 2
# 1941 3
# 1947 3
# 1942 4
# 1943 5
# 1948 4
# 1944 6
# Negative ocurrence sequence finished 274
# sequence 299
# 1949 5
# 1945 1
# 1950 6
# Negative ocurrence sequence finished 275
# sequence 300
# 1946 2
# 1951 1
# 1947 3
# 1952 2
# 1948 4
# 1953 3
# 1949 5
# 1954 4
# 1950 6
# Negative ocurrence sequence finished 275
# sequence 300
# 1955 5
# 1951 1
# 1956 6
# Negative ocurrence sequence finished 276
# sequence 301
# 1957 1
# 1952 2
# 1958 2
# 1953 3
# 1959 3
# 1954 4
# 1960 4
# 1955 5
# 1961 5
# 1956 6
# Negative ocurrence sequence finished 276
# sequence 301
# 1962 6
# Negative ocurrence sequence finished 277
# sequence 302
# 1957 1
# 1963 1
# 1958 2
# 1964 2
# 1959 3
# 1965 3
# 1960 4
# 1966 4
# 1961 5
# 1967 5
# 1962 6
# Negative ocurrence sequence finished 277
# sequence 302
# 1963 1
# 1968 6
# Negative ocurrence sequence finished 278
# sequence 303
# 1964 2
# 1969 1
# 1965 3
# 1970 2
# 1971 3
# 1966 4
# 1972 4
# 1967 5
# 1973 5
# 1968 6
# Negative ocurrence sequence finished 278
# sequence 303
# 1974 6
# Negative ocurrence sequence finished 279
# sequence 304
# 1969 1
# 1975 1
# 1970 2
# 1976 2
# 1971 3
# 1977 3
# 1972 4
# 1978 4
# 1973 5
# 1979 5
# 1974 6
# Negative ocurrence sequence finished 279
# sequence 304
# 1980 6
# Negative ocurrence sequence finished 280
# sequence 305
# 1975 1
# 1981 1
# 1976 2
# 1982 2
# 1977 3
# 1983 3
# 1978 4
# 1984 4
# 1979 5
# 1980 6
# Negative ocurrence sequence finished 280
# sequence 305
# 1985 5
# 1981 1
# 1986 6
# Negative ocurrence sequence finished 281
# sequence 306
# 1982 2
# 1987 1
# 1983 3
# 1988 2
# 1984 4
# 1989 3
# 1985 5
# 1990 4
# 1986 6
# Negative ocurrence sequence finished 281
# sequence 306
# 1991 5
# 1987 1
# 1992 6
# Negative ocurrence sequence finished 282
# sequence 307
# 1988 2
# 1993 1
# 1989 3
# 1990 4
# 1994 2
# 1991 5
# 1995 3
# 1992 6
# Negative ocurrence sequence finished 282
# sequence 307
# 1996 4
# 1993 1
# 1997 5
# 1994 2
# 1998 6
# Negative ocurrence sequence finished 283
# sequence 308
# 1995 3
# 1999 1
# 1996 4
# 2000 2
# 1997 5
# 2001 3
# 1998 6
# Negative ocurrence sequence finished 283
# sequence 308
# 2002 4
# 1999 1
# 2003 5
# 2000 2
# 2004 6
# Negative ocurrence sequence finished 284
# sequence 309
# 2001 3
# 2005 1
# 2002 4
# 2006 2
# 2003 5
# 2007 3
# 2004 6
# Negative ocurrence sequence finished 284
# sequence 309
# 2008 4
# 2005 1
# 2009 5
# 2006 2
# 2010 6
# Negative ocurrence sequence finished 285
# sequence 310
# 2007 3
# 2011 1
# 2008 4
# 2012 2
# 2009 5
# 2013 3
# 2010 6
# Negative ocurrence sequence finished 285
# 2014 4
# sequence 310
# 2011 1
# 2015 5
# 2012 2
# 2016 6
# Negative ocurrence sequence finished 286
# sequence 311
# 2013 3
# 2017 1
# 2014 4
# 2018 2
# 2015 5
# 2019 3
# 2016 6
# Negative ocurrence sequence finished 286
# sequence 311
# 2020 4
# 2017 1
# 2021 5
# 2018 2
# 2022 6
# Negative ocurrence sequence finished 287
# sequence 312
# 2019 3
# 2023 1
# 2020 4
# 2024 2
# 2021 5
# 2025 3
# 2022 6
# Negative ocurrence sequence finished 287
# sequence 312
# 2026 4
# 2023 1
# 2027 5
# 2024 2
# 2028 6
# Negative ocurrence sequence finished 288
# sequence 313
# 2025 3
# 2029 1
# 2026 4
# 2030 2
# 2027 5
# 2031 3
# 2028 6
# Negative ocurrence sequence finished 288
# sequence 313
# 2032 4
# 2029 1
# 2033 5
# 2030 2
# 2034 6
# Negative ocurrence sequence finished 289
# sequence 314
# 2031 3
# 2035 1
# 2036 2
# 2032 4
# 2033 5
# 2037 3
# 2034 6
# Negative ocurrence sequence finished 289
# sequence 314
# 2038 4
# 2039 5
# 2035 1
# 2040 6
# 2036 2
# Negative ocurrence sequence finished 290
# sequence 315
# 2037 3
# 2041 1
# 2038 4
# 2042 2
# 2039 5
# 2043 3
# 2040 6
# Negative ocurrence sequence finished 290
# sequence 315
# 2044 4
# 2041 1
# 2045 5
# 2042 2
# 2046 6
# Negative ocurrence sequence finished 291
# sequence 316
# 2043 3
# 2047 1
# 2044 4
# 2048 2
# 2045 5
# 2049 3
# 2046 6
# Negative ocurrence sequence finished 291
# sequence 316
# 2050 4
# 2047 1
# 2051 5
# 2048 2
# 2052 6
# Negative ocurrence sequence finished 292
# sequence 317
# 2049 3
# 2053 1
# 2050 4
# 2054 2
# 2051 5
# 2055 3
# 2052 6
# Negative ocurrence sequence finished 292
# sequence 317
# 2056 4
# 2053 1
# 2057 5
# 2054 2
# 2058 6
# Negative ocurrence sequence finished 293
# sequence 318
# 2055 3
# 2059 1
# 2056 4
# 2060 2
# 2057 5
# 2061 3
# 2058 6
# Negative ocurrence sequence finished 293
# sequence 318
# 2062 4
# 2059 1
# 2063 5
# 2060 2
# 2064 6
# Negative ocurrence sequence finished 294
# sequence 319
# 2061 3
# 2065 1
# 2062 4
# 2066 2
# 2063 5
# 2067 3
# 2064 6
# Negative ocurrence sequence finished 294
# sequence 319
# 2065 1
# 2068 4
# 2069 5
# 2066 2
# 2067 3
# 2070 6
# Negative ocurrence sequence finished 295
# sequence 320
# 2071 1
# 2068 4
# 2072 2
# 2069 5
# 2073 3
# 2070 6
# Negative ocurrence sequence finished 295
# sequence 320
# 2074 4
# 2071 1
# 2075 5
# 2072 2
# 2076 6
# Negative ocurrence sequence finished 296
# sequence 321
# 2073 3
# 2077 1
# 2074 4
# 2078 2
# 2075 5
# 2079 3
# 2076 6
# Negative ocurrence sequence finished 296
# sequence 321
# 2080 4
# 2077 1
# 2081 5
# 2078 2
# 2082 6
# Negative ocurrence sequence finished 297
# sequence 322
# 2079 3
# 2083 1
# 2080 4
# 2084 2
# 2081 5
# 2082 6
# Negative ocurrence sequence finished 297
# sequence 322
# 2085 3
# 2083 1
# 2086 4
# 2084 2
# 2087 5
# 2088 6
# 2085 3
# Negative ocurrence sequence finished 298
# sequence 323
# 2086 4
# 2089 1
# 2087 5
# 2090 2
# 2088 6
# Negative ocurrence sequence finished 298
# sequence 323
# 2091 3
# 2089 1
# 2092 4
# 2090 2
# 2093 5
# 2091 3
# 2094 6
# Negative ocurrence sequence finished 299
# sequence 324
# 2092 4
# 2095 1
# 2093 5
# 2096 2
# 2097 3
# 2094 6
# Negative ocurrence sequence finished 299
# sequence 324
# 2095 1
# 2098 4
# 2099 5
# 2096 2
# 2100 6
# Negative ocurrence sequence finished 300
# sequence 325
# 2097 3
# 2101 1
# 2098 4
# 2102 2
# 2099 5
# 2103 3
# 2104 4
# 2100 6
# Negative ocurrence sequence finished 300
# sequence 325
# 2105 5
# 2101 1
# 2106 6
# Negative ocurrence sequence finished 301
# sequence 326
# 2102 2
# 2103 3
# 2107 1
# 2108 2
# 2104 4
# 2105 5
# 2109 3
# 2110 4
# 2106 6
# Negative ocurrence sequence finished 301
# sequence 326
# 2111 5
# 2107 1
# 2112 6
# Negative ocurrence sequence finished 302
# sequence 327
# 2108 2
# 2113 1
# 2109 3
# 2114 2
# 2110 4
# 2115 3
# 2111 5
# 2116 4
# 2112 6
# Negative ocurrence sequence finished 302
# sequence 327
# 2117 5
# 2113 1
# 2118 6
# Negative ocurrence sequence finished 303
# sequence 328
# 2114 2
# 2119 1
# 2115 3
# 2120 2
# 2116 4
# 2121 3
# 2117 5
# 2122 4
# 2118 6
# Negative ocurrence sequence finished 303
# sequence 328
# 2123 5
# 2119 1
# 2124 6
# Negative ocurrence sequence finished 304
# sequence 329
# 2120 2
# 2125 1
# 2121 3
# 2126 2
# 2122 4
# 2127 3
# 2123 5
# 2128 4
# 2124 6
# Negative ocurrence sequence finished 304
# sequence 329
# 2129 5
# 2125 1
# 2130 6
# Negative ocurrence sequence finished 305
# sequence 330
# 2126 2
# 2131 1
# 2127 3
# 2132 2
# 2128 4
# 2133 3
# 2129 5
# 2134 4
# 2130 6
# Negative ocurrence sequence finished 305
# sequence 330
# 2135 5
# 2131 1
# 2136 6
# Negative ocurrence sequence finished 306
# sequence 331
# 2132 2
# 2137 1
# 2133 3
# 2138 2
# 2134 4
# 2139 3
# 2135 5
# 2140 4
# 2136 6
# Negative ocurrence sequence finished 306
# sequence 331
# 2141 5
# 2137 1
# 2142 6
# Negative ocurrence sequence finished 307
# sequence 332
# 2143 1
# 2138 2
# 2144 2
# 2139 3
# 2145 3
# 2140 4
# 2146 4
# 2141 5
# 2147 5
# 2142 6
# Negative ocurrence sequence finished 307
# sequence 332
# 2148 6
# Negative ocurrence sequence finished 308
# sequence 333
# 2143 1
# 2149 1
# 2144 2
# 2150 2
# 2145 3
# 2151 3
# 2146 4
# 2152 4
# 2147 5
# 2153 5
# 2148 6
# Negative ocurrence sequence finished 308
# sequence 333
# 2154 6
# Negative ocurrence sequence finished 309
# sequence 334
# 2149 1
# 2155 1
# 2150 2
# 2156 2
# 2151 3
# 2157 3
# 2152 4
# 2158 4
# 2153 5
# 2159 5
# 2154 6
# Negative ocurrence sequence finished 309
# sequence 334
# 2160 6
# Negative ocurrence sequence finished 310
# sequence 335
# 2155 1
# 2161 1
# 2162 2
# 2156 2
# 2163 3
# 2157 3
# 2164 4
# 2158 4
# 2165 5
# 2159 5
# 2166 6
# Negative ocurrence sequence finished 311
# sequence 336
# 2160 6
# Negative ocurrence sequence finished 310
# sequence 335
# 2167 1
# 2161 1
# 2168 2
# 2162 2
# 2169 3
# 2163 3
# 2170 4
# 2164 4
# 2171 5
# 2165 5
# 2172 6
# Negative ocurrence sequence finished 312
# sequence 337
# 2166 6
# Negative ocurrence sequence finished 311
# sequence 336
# 2173 1
# 2167 1
# 2174 2
# 2168 2
# 2169 3
# 2175 3
# 2170 4
# 2176 4
# 2171 5
# 2177 5
# 2172 6
# Negative ocurrence sequence finished 312
# sequence 337
# 2178 6
# Negative ocurrence sequence finished 313
# sequence 338
# 2173 1
# 2179 1
# 2174 2
# 2180 2
# 2175 3
# 2181 3
# 2176 4
# 2177 5
# 2182 4
# 2183 5
# 2178 6
# Negative ocurrence sequence finished 313
# sequence 338
# 2179 1
# 2184 6
# Negative ocurrence sequence finished 314
# sequence 339
# 2180 2
# 2185 1
# 2181 3
# 2186 2
# 2182 4
# 2187 3
# 2183 5
# 2188 4
# 2184 6
# Negative ocurrence sequence finished 314
# sequence 339
# 2189 5
# 2185 1
# 2190 6
# 2186 2
# Negative ocurrence sequence finished 315
# sequence 340
# 2187 3
# 2191 1
# 2188 4
# 2192 2
# 2189 5
# 2193 3
# 2190 6
# Negative ocurrence sequence finished 315
# sequence 340
# 2194 4
# 2191 1
# 2195 5
# 2192 2
# 2196 6
# Negative ocurrence sequence finished 316
# sequence 341
# 2193 3
# 2197 1
# 2194 4
# 2198 2
# 2195 5
# 2199 3
# 2196 6
# Negative ocurrence sequence finished 316
# sequence 341
# 2200 4
# 2197 1
# 2201 5
# 2198 2
# 2202 6
# Negative ocurrence sequence finished 317
# sequence 342
# 2199 3
# 2203 1
# 2200 4
# 2204 2
# 2201 5
# 2205 3
# 2202 6
# Negative ocurrence sequence finished 317
# sequence 342
# 2206 4
# 2203 1
# 2207 5
# 2204 2
# 2208 6
# Negative ocurrence sequence finished 318
# sequence 343
# 2205 3
# 2209 1
# 2206 4
# 2210 2
# 2207 5
# 2211 3
# 2208 6
# Negative ocurrence sequence finished 318
# sequence 343
# 2212 4
# 2209 1
# 2210 2
# 2213 5
# 2211 3
# 2214 6
# Negative ocurrence sequence finished 319
# sequence 344
# 2212 4
# 2215 1
# 2213 5
# 2216 2
# 2214 6
# Negative ocurrence sequence finished 319
# sequence 344
# 2217 3
# 2215 1
# 2218 4
# 2216 2
# 2219 5
# 2217 3
# 2220 6
# Negative ocurrence sequence finished 320
# sequence 345
# 2218 4
# 2221 1
# 2219 5
# 2222 2
# 2220 6
# Negative ocurrence sequence finished 320
# sequence 345
# 2223 3
# 2224 4
# 2221 1
# 2222 2
# 2225 5
# 2226 6
# Negative ocurrence sequence finished 321
# sequence 346
# 2223 3
# 2227 1
# 2224 4
# 2228 2
# 2225 5
# 2229 3
# 2226 6
# Negative ocurrence sequence finished 321
# sequence 346
# 2227 1
# 2230 4
# 2228 2
# 2231 5
# 2229 3
# 2232 6
# Negative ocurrence sequence finished 322
# sequence 347
# 2230 4
# 2233 1
# 2231 5
# 2234 2
# 2232 6
# Negative ocurrence sequence finished 322
# sequence 347
# 2235 3
# 2233 1
# 2236 4
# 2234 2
# 2237 5
# 2235 3
# 2238 6
# Negative ocurrence sequence finished 323
# sequence 348
# 2236 4
# 2239 1
# 2237 5
# 2240 2
# 2238 6
# Negative ocurrence sequence finished 323
# sequence 348
# 2241 3
# 2239 1
# 2242 4
# 2240 2
# 2243 5
# 2241 3
# 2244 6
# Negative ocurrence sequence finished 324
# sequence 349
# 2242 4
# 2245 1
# 2243 5
# 2246 2
# 2244 6
# Negative ocurrence sequence finished 324
# sequence 349
# 2247 3
# 2245 1
# 2248 4
# 2246 2
# 2249 5
# 2247 3
# 2250 6
# Negative ocurrence sequence finished 325
# sequence 350
# 2248 4
# 2251 1
# 2249 5
# 2252 2
# 2250 6
# Negative ocurrence sequence finished 325
# sequence 350
# 2253 3
# 2251 1
# 2254 4
# 2252 2
# 2255 5
# 2253 3
# 2256 6
# Negative ocurrence sequence finished 326
# sequence 351
# 2254 4
# 2257 1
# 2255 5
# 2258 2
# 2256 6
# Negative ocurrence sequence finished 326
# sequence 351
# 2259 3
# 2257 1
# 2260 4
# 2258 2
# 2261 5
# 2259 3
# 2262 6
# Negative ocurrence sequence finished 327
# sequence 352
# 2260 4
# 2263 1
# 2261 5
# 2264 2
# 2262 6
# Negative ocurrence sequence finished 327
# sequence 352
# 2265 3
# 2266 4
# 2263 1
# 2267 5
# 2264 2
# 2268 6
# Negative ocurrence sequence finished 328
# sequence 353
# 2269 1
# 2265 3
# 2270 2
# 2266 4
# 2271 3
# 2267 5
# 2272 4
# 2268 6
# Negative ocurrence sequence finished 328
# sequence 353
# 2269 1
# 2273 5
# 2270 2
# 2274 6
# Negative ocurrence sequence finished 329
# sequence 354
# 2271 3
# 2275 1
# 2272 4
# 2276 2
# 2277 3
# 2273 5
# 2278 4
# 2274 6
# Negative ocurrence sequence finished 329
# sequence 354
# 2279 5
# 2275 1
# 2280 6
# Negative ocurrence sequence finished 330
# sequence 355
# 2276 2
# 2281 1
# 2277 3
# 2282 2
# 2278 4
# 2283 3
# 2279 5
# 2284 4
# 2280 6
# Negative ocurrence sequence finished 330
# sequence 355
# 2285 5
# 2281 1
# 2286 6
# Negative ocurrence sequence finished 331
# sequence 356
# 2282 2
# 2287 1
# 2283 3
# 2288 2
# 2284 4
# 2289 3
# 2285 5
# 2290 4
# 2286 6
# Negative ocurrence sequence finished 331
# sequence 356
# 2291 5
# 2287 1
# 2292 6
# Negative ocurrence sequence finished 332
# sequence 357
# 2288 2
# 2293 1
# 2289 3
# 2294 2
# 2290 4
# 2295 3
# 2291 5
# 2296 4
# 2292 6
# Negative ocurrence sequence finished 332
# sequence 357
# 2297 5
# 2293 1
# 2298 6
# Negative ocurrence sequence finished 333
# sequence 358
# 2299 1
# 2294 2
# 2300 2
# 2295 3
# 2301 3
# 2296 4
# 2302 4
# 2297 5
# 2298 6
# Negative ocurrence sequence finished 333
# sequence 358
# 2303 5
# 2299 1
# 2304 6
# Negative ocurrence sequence finished 334
# sequence 359
# 2300 2
# 2305 1
# 2301 3
# 2306 2
# 2302 4
# 2307 3
# 2303 5
# 2308 4
# 2304 6
# Negative ocurrence sequence finished 334
# sequence 359
# 2309 5
# 2305 1
# 2310 6
# Negative ocurrence sequence finished 335
# sequence 360
# 2306 2
# 2311 1
# 2307 3
# 2312 2
# 2308 4
# 2313 3
# 2309 5
# 2314 4
# 2310 6
# Negative ocurrence sequence finished 335
# sequence 360
# 2315 5
# 2311 1
# 2316 6
# 2312 2
# Negative ocurrence sequence finished 336
# sequence 361
# 2313 3
# 2317 1
# 2314 4
# 2318 2
# 2315 5
# 2319 3
# 2320 4
# 2316 6
# Negative ocurrence sequence finished 336
# sequence 361
# 2321 5
# 2317 1
# 2322 6
# Negative ocurrence sequence finished 337
# sequence 362
# 2318 2
# 2323 1
# 2319 3
# 2320 4
# 2324 2
# 2325 3
# 2321 5
# 2326 4
# 2322 6
# Negative ocurrence sequence finished 337
# sequence 362
# 2323 1
# 2327 5
# 2328 6
# Negative ocurrence sequence finished 338
# sequence 363
# 2324 2
# 2325 3
# 2329 1
# 2326 4
# 2330 2
# 2327 5
# 2331 3
# 2328 6
# 2332 4
# Negative ocurrence sequence finished 338
# sequence 363
# 2333 5
# 2329 1
# 2334 6
# Negative ocurrence sequence finished 339
# sequence 364
# 2330 2
# 2335 1
# 2331 3
# 2336 2
# 2332 4
# 2337 3
# 2333 5
# 2338 4
# 2334 6
# Negative ocurrence sequence finished 339
# sequence 364
# 2339 5
# 2335 1
# 2340 6
# Negative ocurrence sequence finished 340
# sequence 365
# 2336 2
# 2341 1
# 2337 3
# 2342 2
# 2338 4
# 2339 5
# 2343 3
# 2340 6
# Negative ocurrence sequence finished 340
# sequence 365
# 2344 4
# 2345 5
# 2341 1
# 2342 2
# 2346 6
# Negative ocurrence sequence finished 341
# sequence 366
# Train CSV for patient 2 has been completed...
# 2343 3
# 2344 4
# 2345 5
# 2346 6
# Negative ocurrence sequence finished 341
# sequence 366
# 2347 1
# 2348 2
# 2349 3
# 2350 4
# 2351 5
# 2352 6
# Negative ocurrence sequence finished 342
# sequence 367
# 2353 1
# 2354 2
# 2355 3
# 2356 4
# 2357 5
# 2358 6
# Negative ocurrence sequence finished 343
# sequence 368
# 2359 1
# 2360 2
# 2361 3
# 2362 4
# 2363 5
# 2364 6
# Negative ocurrence sequence finished 344
# sequence 369
# 2365 1
# 2366 2
# 2367 3
# 2368 4
# 2369 5
# 2370 6
# Negative ocurrence sequence finished 345
# sequence 370
# 2371 1
# 2372 2
# 2373 3
# 2374 4
# 2375 5
# 2376 6
# Negative ocurrence sequence finished 346
# sequence 371
# 2377 1
# 2378 2
# 2379 3
# 2380 4
# 2381 5
# 2382 6
# Negative ocurrence sequence finished 347
# sequence 372
# 2383 1
# 2384 2
# 2385 3
# 2386 4
# 2387 5
# 2388 6
# Negative ocurrence sequence finished 348
# sequence 373
# 2389 1
# 2390 2
# 2391 3
# 2392 4
# 2393 5
# 2394 6
# Negative ocurrence sequence finished 349
# sequence 374
# Train CSV for patient 3 has been completed...
# Load train.csv...
# Load test.csv...
# Process tables...
# Length of train:  5970
# Length of test:  6126
# Features [82]: ['avg_0', 'avg_1', 'avg_10', 'avg_11', 'avg_12', 'avg_13', 'avg_14', 'avg_15', 'avg_2', 'avg_3', 'avg_4', 'avg_5', 'avg_6', 'avg_7', 'avg_8', 'avg_9', 'file_size', 'patient_id', 'peak1_0', 'peak1_1', 'peak1_10', 'peak1_11', 'peak1_12', 'peak1_13', 'peak1_14', 'peak1_15', 'peak1_2', 'peak1_3', 'peak1_4', 'peak1_5', 'peak1_6', 'peak1_7', 'peak1_8', 'peak1_9', 'peak2_0', 'peak2_1', 'peak2_10', 'peak2_11', 'peak2_12', 'peak2_13', 'peak2_14', 'peak2_15', 'peak2_2', 'peak2_3', 'peak2_4', 'peak2_5', 'peak2_6', 'peak2_7', 'peak2_8', 'peak2_9', 'peak3_0', 'peak3_1', 'peak3_10', 'peak3_11', 'peak3_12', 'peak3_13', 'peak3_14', 'peak3_15', 'peak3_2', 'peak3_3', 'peak3_4', 'peak3_5', 'peak3_6', 'peak3_7', 'peak3_8', 'peak3_9', 'peak4_0', 'peak4_1', 'peak4_10', 'peak4_11', 'peak4_12', 'peak4_13', 'peak4_14', 'peak4_15', 'peak4_2', 'peak4_3', 'peak4_4', 'peak4_5', 'peak4_6', 'peak4_7', 'peak4_8', 'peak4_9']

# %%
#prediction, score= modelfit(xgb1, newtrain, newtest, train, predictors,'result',test, useTrainCV=True)

prediction, score = run_kfold(6, train, test, features, 'result')

create_submission(score, test, prediction)
print('version 3acb')
# Out:
# XGBoost params. ETA: 0.2, MAX_DEPTH: 3, SUBSAMPLE: 0.9, COLSAMPLE_BY_TREE: 0.9
# Start fold 1 from 6
# Length of train people: 311
# Length of valid people: 63
# Length train: 4984
# Length valid: 986
# [0]	train-auc:0.586464	eval-auc:0.511574
# Multiple eval metrics have been passed: 'eval-auc' will be used for early stopping.
#
# Will train until eval-auc hasn't improved in 50 rounds.
# Stopping. Best iteration:
# [1]	train-auc:0.682976	eval-auc:0.592603
#
# Validating...
# Check error value: 0.592603
# Importance array:  [('avg_3', 16), ('avg_4', 15), ('peak4_15', 12), ('peak1_12', 10), ('peak4_2', 9), ('peak1_0', 8), ('peak3_0', 8), ('peak1_13', 8), ('peak2_7', 8), ('peak1_15', 8), ('peak1_5', 8), ('avg_12', 8), ('peak1_10', 6), ('avg_1', 6), ('peak2_11', 6), ('peak3_2', 6), ('peak2_8', 6), ('peak4_7', 6), ('avg_8', 6), ('peak4_4', 6), ('peak3_4', 5), ('avg_11', 5), ('peak4_3', 5), ('peak2_3', 5), ('peak2_4', 5), ('peak3_6', 5), ('peak3_15', 5), ('avg_2', 5), ('avg_14', 5), ('peak4_14', 5), ('peak1_9', 5), ('avg_15', 5), ('avg_5', 4), ('peak3_12', 4), ('avg_7', 4), ('peak4_1', 4), ('peak1_8', 4), ('peak4_8', 4), ('peak3_5', 4), ('peak1_4', 4), ('avg_13', 4), ('peak2_9', 4), ('avg_0', 4), ('peak4_5', 4), ('peak2_10', 4), ('peak2_14', 4), ('file_size', 4), ('peak2_6', 4), ('peak3_7', 4), ('peak4_12', 3), ('peak3_8', 3), ('peak2_2', 3), ('peak1_2', 3), ('peak3_10', 3), ('peak2_1', 3), ('peak1_11', 3), ('peak1_1', 3), ('peak2_12', 2), ('peak1_3', 2), ('avg_9', 2), ('peak2_15', 2), ('peak2_13', 2), ('peak4_11', 2), ('peak4_13', 2), ('peak3_3', 2), ('peak1_6', 2), ('peak3_13', 2), ('peak1_7', 2), ('avg_6', 2), ('peak4_10', 2), ('peak4_0', 1), ('peak3_11', 1), ('peak2_0', 1), ('peak3_1', 1), ('peak1_14', 1), ('peak2_5', 1), ('peak3_9', 1)]
# Predict test set...
# [ 0.35143554  0.35143554  0.35143554 ...,  0.33986965  0.33986965
#   0.35143554]
# Start fold 2 from 6
# Length of train people: 311
# Length of valid people: 63
# Length train: 4878
# Length valid: 1092
# [0]	train-auc:0.685555	eval-auc:0.557353
# Multiple eval metrics have been passed: 'eval-auc' will be used for early stopping.
#
# Will train until eval-auc hasn't improved in 50 rounds.
# Stopping. Best iteration:
# [15]	train-auc:0.882011	eval-auc:0.652893
#
# Validating...
# Check error value: 0.652893
# Importance array:  [('peak3_2', 15), ('peak1_2', 14), ('avg_3', 14), ('avg_4', 11), ('peak4_3', 11), ('peak3_0', 11), ('peak1_0', 10), ('avg_11', 10), ('peak2_8', 10), ('peak1_11', 10), ('avg_8', 9), ('peak4_11', 9), ('peak1_8', 9), ('peak3_9', 9), ('peak4_15', 8), ('peak2_11', 8), ('peak2_13', 8), ('avg_0', 8), ('peak1_15', 8), ('avg_6', 7), ('peak4_7', 7), ('peak3_3', 7), ('peak4_2', 7), ('avg_7', 7), ('peak4_4', 7), ('avg_12', 7), ('avg_5', 6), ('peak3_6', 6), ('peak4_13', 6), ('peak2_7', 6), ('avg_15', 6), ('peak2_5', 6), ('peak4_14', 6), ('peak3_12', 5), ('peak1_3', 5), ('peak3_8', 5), ('peak1_12', 5), ('peak2_0', 5), ('peak3_1', 5), ('avg_13', 5), ('peak2_9', 5), ('peak2_14', 5), ('file_size', 5), ('peak3_11', 5), ('peak4_0', 4), ('peak3_13', 4), ('peak3_15', 4), ('peak2_3', 4), ('peak1_4', 4), ('peak2_4', 4), ('peak1_9', 4), ('peak2_10', 4), ('peak3_7', 4), ('peak1_13', 4), ('peak1_10', 3), ('peak4_9', 3), ('peak1_14', 3), ('peak4_8', 3), ('peak3_5', 3), ('peak4_10', 3), ('peak4_5', 3), ('peak4_6', 3), ('peak2_6', 3), ('peak1_6', 3), ('avg_2', 3), ('avg_9', 3), ('peak1_5', 3), ('avg_14', 3), ('peak1_1', 3), ('peak2_12', 2), ('peak3_4', 2), ('peak2_2', 2), ('peak1_7', 2), ('peak4_12', 1), ('peak2_15', 1), ('avg_1', 1), ('peak2_1', 1), ('peak4_1', 1), ('peak3_14', 1)]
# Predict test set...
# [ 0.09378085  0.08492644  0.09378085 ...,  0.05263187  0.02760983
#   0.15357487]
# Start fold 3 from 6
# Length of train people: 312
# Length of valid people: 62
# Length train: 5006
# Length valid: 964
# [0]	train-auc:0.64253	eval-auc:0.550163
# Multiple eval metrics have been passed: 'eval-auc' will be used for early stopping.
#
# Will train until eval-auc hasn't improved in 50 rounds.
# Stopping. Best iteration:
# [36]	train-auc:0.932794	eval-auc:0.641718
#
# Validating...
# Check error value: 0.641718
# Importance array:  [('avg_3', 18), ('peak1_0', 15), ('peak4_3', 14), ('peak1_2', 13), ('avg_2', 13), ('peak1_11', 13), ('peak3_6', 12), ('peak2_13', 12), ('avg_12', 12), ('avg_4', 11), ('peak2_8', 11), ('peak2_4', 11), ('peak2_14', 11), ('peak4_4', 11), ('peak1_8', 11), ('avg_6', 9), ('peak2_7', 9), ('peak4_2', 9), ('avg_11', 9), ('avg_13', 9), ('peak1_9', 9), ('peak3_9', 9), ('peak4_15', 8), ('peak1_3', 8), ('peak1_12', 8), ('peak1_13', 8), ('peak3_3', 8), ('peak4_7', 8), ('avg_0', 8), ('peak1_5', 8), ('avg_15', 8), ('peak1_1', 8), ('avg_1', 7), ('peak1_7', 7), ('peak3_2', 7), ('peak3_13', 7), ('peak2_3', 7), ('peak3_0', 7), ('peak1_6', 7), ('avg_8', 7), ('peak3_7', 7), ('peak4_14', 7), ('peak2_15', 6), ('peak4_8', 6), ('file_size', 6), ('peak3_1', 6), ('peak3_11', 6), ('peak1_14', 6), ('peak2_9', 6), ('peak1_15', 6), ('peak3_10', 6), ('avg_14', 6), ('peak1_4', 6), ('avg_7', 5), ('peak4_1', 5), ('peak3_14', 5), ('peak4_9', 5), ('peak3_15', 5), ('peak2_5', 5), ('avg_9', 5), ('peak4_10', 5), ('avg_10', 4), ('peak2_0', 4), ('peak3_12', 4), ('peak4_0', 4), ('peak2_11', 4), ('peak4_6', 4), ('peak4_13', 4), ('peak2_6', 4), ('peak3_4', 4), ('avg_5', 3), ('peak1_10', 3), ('peak4_12', 3), ('peak3_8', 3), ('peak2_1', 3), ('peak2_10', 2), ('peak3_5', 2), ('peak4_11', 2), ('peak2_2', 1), ('peak2_12', 1), ('peak4_5', 1)]
# Predict test set...
# [ 0.04584377  0.07500868  0.06028491 ...,  0.01559023  0.00599722
#   0.04876999]
# Start fold 4 from 6
# Length of train people: 312
# Length of valid people: 62
# Length train: 5057
# Length valid: 913
# [0]	train-auc:0.639038	eval-auc:0.631671
# Multiple eval metrics have been passed: 'eval-auc' will be used for early stopping.
#
# Will train until eval-auc hasn't improved in 50 rounds.
# Stopping. Best iteration:
# [22]	train-auc:0.879667	eval-auc:0.640724
#
# Validating...
# Check error value: 0.640724
# Importance array:  [('file_size', 13), ('avg_3', 12), ('avg_11', 11), ('peak2_4', 11), ('peak1_11', 11), ('peak1_4', 11), ('peak3_3', 10), ('peak1_1', 10), ('peak1_2', 9), ('peak3_8', 9), ('peak3_2', 9), ('peak4_2', 9), ('avg_12', 9), ('peak4_15', 8), ('peak1_12', 8), ('peak4_1', 8), ('avg_5', 8), ('peak2_2', 8), ('avg_13', 8), ('peak2_9', 8), ('peak3_13', 8), ('peak1_9', 8), ('avg_4', 7), ('avg_8', 7), ('peak4_12', 7), ('avg_6', 7), ('peak2_6', 7), ('peak2_7', 7), ('peak4_8', 7), ('peak2_8', 7), ('avg_0', 7), ('peak2_1', 7), ('peak3_4', 7), ('peak2_10', 7), ('peak3_9', 7), ('peak1_3', 6), ('peak1_0', 6), ('peak4_3', 6), ('peak3_0', 6), ('peak3_6', 6), ('peak3_1', 6), ('peak3_10', 6), ('avg_2', 6), ('peak2_14', 6), ('peak1_5', 6), ('avg_1', 6), ('peak4_4', 6), ('peak1_8', 6), ('peak1_7', 5), ('peak2_3', 5), ('peak4_7', 5), ('peak1_15', 5), ('avg_15', 5), ('avg_9', 4), ('peak2_13', 4), ('peak4_10', 4), ('peak2_11', 4), ('peak4_5', 4), ('avg_7', 4), ('peak2_15', 4), ('avg_10', 3), ('peak1_10', 3), ('peak2_0', 3), ('peak3_12', 3), ('peak3_5', 3), ('peak3_14', 3), ('peak3_11', 3), ('peak1_6', 3), ('peak4_6', 3), ('peak4_0', 3), ('peak1_13', 3), ('peak4_9', 2), ('peak4_11', 2), ('peak3_15', 2), ('peak1_14', 2), ('peak3_7', 2), ('avg_14', 2), ('peak2_12', 1), ('peak4_13', 1), ('peak4_14', 1)]
# Predict test set...
# [ 0.07275829  0.047749    0.08161805 ...,  0.02475556  0.02317007
#   0.05737086]
# Start fold 5 from 6
# Length of train people: 312
# Length of valid people: 62
# Length train: 4976
# Length valid: 994
# [0]	train-auc:0.575956	eval-auc:0.544855
# Multiple eval metrics have been passed: 'eval-auc' will be used for early stopping.
#
# Will train until eval-auc hasn't improved in 50 rounds.
# Stopping. Best iteration:
# [11]	train-auc:0.811558	eval-auc:0.661605
#
# Validating...
# Check error value: 0.661605
# Importance array:  [('avg_3', 13), ('peak2_11', 12), ('avg_0', 11), ('avg_4', 10), ('peak1_0', 9), ('avg_12', 9), ('peak3_13', 8), ('peak3_2', 8), ('avg_5', 8), ('peak3_6', 8), ('peak1_11', 8), ('peak3_3', 8), ('peak2_1', 8), ('avg_2', 8), ('peak4_4', 8), ('avg_1', 7), ('peak2_0', 7), ('avg_11', 7), ('peak4_2', 7), ('peak4_13', 7), ('file_size', 7), ('peak4_14', 7), ('peak1_8', 7), ('peak4_3', 6), ('avg_9', 6), ('peak2_4', 6), ('peak4_7', 6), ('peak2_8', 6), ('peak3_9', 6), ('peak4_11', 5), ('peak1_3', 5), ('avg_8', 5), ('peak3_11', 5), ('peak3_5', 5), ('peak2_3', 5), ('peak4_1', 5), ('peak4_10', 5), ('peak2_9', 5), ('peak1_5', 5), ('peak2_6', 5), ('peak1_9', 5), ('avg_15', 5), ('peak1_1', 5), ('peak1_12', 4), ('peak3_12', 4), ('peak4_8', 4), ('peak3_1', 4), ('peak2_2', 4), ('avg_13', 4), ('peak1_2', 4), ('peak3_15', 4), ('peak1_6', 4), ('peak2_14', 4), ('avg_14', 4), ('peak2_10', 4), ('peak3_7', 4), ('peak4_15', 3), ('peak2_12', 3), ('peak3_4', 3), ('avg_6', 3), ('peak1_14', 3), ('peak4_6', 3), ('peak1_4', 3), ('peak2_13', 3), ('peak1_15', 3), ('peak2_5', 3), ('avg_7', 3), ('avg_10', 2), ('peak4_9', 2), ('peak4_12', 2), ('peak3_8', 2), ('peak2_15', 2), ('peak3_0', 2), ('peak3_14', 2), ('peak2_7', 2), ('peak4_5', 2), ('peak4_0', 2), ('peak1_7', 2), ('peak1_13', 2), ('peak1_10', 1), ('peak3_10', 1)]
# Predict test set...
# [ 0.0987044   0.09373711  0.09525578 ...,  0.07313121  0.06845895
#   0.12893605]
# Start fold 6 from 6
# Length of train people: 312
# Length of valid people: 62
# Length train: 4949
# Length valid: 1021
# [0]	train-auc:0.711081	eval-auc:0.60121
# Multiple eval metrics have been passed: 'eval-auc' will be used for early stopping.
#
# Will train until eval-auc hasn't improved in 50 rounds.
# Stopping. Best iteration:
# [3]	train-auc:0.773815	eval-auc:0.619614
#
# Validating...
# Check error value: 0.619614
# Importance array:  [('avg_3', 14), ('avg_12', 12), ('avg_11', 11), ('peak4_15', 8), ('peak4_2', 8), ('peak4_14', 8), ('avg_4', 7), ('peak1_2', 7), ('peak1_12', 7), ('peak4_3', 7), ('peak1_4', 7), ('avg_1', 7), ('avg_5', 6), ('peak1_0', 6), ('peak1_3', 6), ('peak2_7', 6), ('peak3_6', 6), ('avg_15', 6), ('avg_2', 6), ('avg_6', 6), ('avg_8', 5), ('peak4_8', 5), ('peak2_0', 5), ('peak3_2', 5), ('peak2_8', 5), ('avg_13', 5), ('peak2_11', 5), ('peak4_13', 5), ('peak3_11', 5), ('peak2_5', 5), ('peak1_1', 5), ('peak3_12', 4), ('peak3_13', 4), ('peak4_9', 4), ('peak4_1', 4), ('peak1_8', 4), ('peak3_5', 4), ('peak3_4', 4), ('peak2_3', 4), ('peak3_0', 4), ('peak2_4', 4), ('peak1_13', 4), ('peak4_4', 4), ('peak4_7', 4), ('peak4_11', 4), ('peak1_11', 4), ('file_size', 4), ('peak3_9', 4), ('avg_10', 3), ('peak4_10', 3), ('peak2_12', 3), ('peak3_15', 3), ('peak2_9', 3), ('avg_0', 3), ('peak1_15', 3), ('peak3_7', 3), ('peak1_6', 3), ('avg_7', 3), ('peak2_14', 3), ('peak1_9', 3), ('peak1_7', 3), ('peak2_13', 2), ('peak2_15', 2), ('peak2_6', 2), ('peak2_2', 2), ('peak1_14', 2), ('peak2_1', 2), ('peak3_1', 2), ('peak3_3', 2), ('peak3_14', 2), ('avg_9', 2), ('peak1_5', 2), ('avg_14', 2), ('peak4_0', 1), ('peak4_12', 1), ('peak3_8', 1), ('peak4_5', 1), ('peak1_10', 1)]
# Predict test set...
# [ 0.26074502  0.25614133  0.26074502 ...,  0.22802839  0.22802839
#   0.23861222]
# Check error value: 0.532168
#           Id   kfold_1   kfold_2   kfold_3   kfold_4   kfold_5   kfold_6  \
# 0     100001  0.351436  0.093781  0.045844  0.072758  0.098704  0.260745
# 1     100002  0.351436  0.084926  0.075009  0.047749  0.093737  0.256141
# 2     100003  0.351436  0.093781  0.060285  0.081618  0.095256  0.260745
# 3     100004  0.351436  0.084817  0.067772  0.089997  0.142166  0.260745
# 4     100006  0.360241  0.161824  0.232607  0.100251  0.183920  0.302306
# 5     100008  0.351436  0.118068  0.092872  0.098297  0.109717  0.285488
# 6     100009  0.351436  0.068419  0.114315  0.035043  0.085624  0.245401
# 7     100010  0.351436  0.076795  0.088151  0.091894  0.095256  0.274690
# 8     100011  0.390545  0.118763  0.160532  0.288673  0.345794  0.300220
# 9     100012  0.351436  0.092311  0.064659  0.097719  0.091964  0.285488
# 10    100013  0.390545  0.223523  0.216940  0.202683  0.214097  0.302306
# 11    100014  0.390545  0.134055  0.299356  0.127572  0.229644  0.300220
# 12    100015  0.351436  0.072193  0.174903  0.059849  0.090204  0.243433
# 13    100016  0.351436  0.074907  0.092569  0.048816  0.082590  0.233873
# 14    100017  0.339870  0.068419  0.031229  0.044387  0.085624  0.233873
# 15    100018  0.351436  0.114125  0.057731  0.084400  0.134347  0.285488
# 16    100019  0.360241  0.200787  0.347239  0.167858  0.230379  0.302306
# 17    100020  0.360241  0.183647  0.336219  0.131094  0.252232  0.300220
# 18    100021  0.351436  0.142996  0.089743  0.081792  0.109717  0.300220
# 19    100022  0.360241  0.081090  0.056932  0.065573  0.100428  0.258195
# 20    100023  0.390545  0.137513  0.237382  0.133276  0.341521  0.302306
# 21    100024  0.339870  0.062480  0.052620  0.032417  0.085624  0.233873
# 22    100025  0.360241  0.074664  0.058476  0.063623  0.119064  0.272054
# 23    100026  0.360241  0.211812  0.302238  0.103730  0.230379  0.284452
# 24    100027  0.351436  0.067514  0.065961  0.040528  0.087023  0.256774
# 25    100028  0.351436  0.068841  0.041555  0.039134  0.087023  0.256774
# 26    100029  0.351436  0.125769  0.191921  0.167038  0.133381  0.302306
# 27    100030  0.351436  0.125719  0.200185  0.092388  0.126070  0.300220
# 28    100031  0.351436  0.088873  0.090592  0.109097  0.095256  0.274690
# 29    100032  0.390545  0.160434  0.330538  0.135508  0.200059  0.284452
# ...      ...       ...       ...       ...       ...       ...       ...
# 2256  302257  0.339870  0.043286  0.020461  0.041432  0.084524  0.228028
# 2257  302258  0.351436  0.129960  0.132362  0.211494  0.114653  0.317520
# 2258  302259  0.339870  0.036239  0.012505  0.020383  0.065478  0.228028
# 2259  302260  0.352524  0.095604  0.023651  0.042791  0.076536  0.273547
# 2260  302261  0.339870  0.036831  0.023679  0.036797  0.081933  0.248709
# 2261  302262  0.339870  0.030513  0.024714  0.028686  0.065478  0.228028
# 2262  302263  0.352524  0.137105  0.045617  0.050913  0.094580  0.279111
# 2263  302264  0.339870  0.034439  0.016889  0.021736  0.076522  0.228028
# 2264  302265  0.339870  0.034439  0.055252  0.029798  0.079352  0.228028
# 2265  302266  0.339870  0.091192  0.056905  0.086909  0.093737  0.248709
# 2266  302267  0.390545  0.121320  0.111335  0.220549  0.124165  0.299152
# 2267  302268  0.352524  0.144258  0.157780  0.125926  0.128668  0.296769
# 2268  302269  0.352524  0.062987  0.018998  0.041492  0.085669  0.233594
# 2269  302270  0.339870  0.040454  0.019255  0.026426  0.079352  0.228028
# 2270  302271  0.352524  0.069205  0.060705  0.058799  0.088439  0.273547
# 2271  302272  0.352524  0.142721  0.077091  0.061082  0.107283  0.254613
# 2272  302273  0.339870  0.030730  0.006938  0.025198  0.072097  0.228028
# 2273  302274  0.352524  0.063774  0.072755  0.049591  0.082275  0.273547
# 2274  302275  0.339870  0.071893  0.062074  0.044578  0.094178  0.228028
# 2275  302276  0.339870  0.040937  0.066626  0.033362  0.087622  0.228028
# 2276  302277  0.339870  0.033113  0.015834  0.019731  0.068566  0.228028
# 2277  302278  0.352524  0.095650  0.059277  0.059147  0.098007  0.276282
# 2278  302279  0.352524  0.039730  0.044981  0.057735  0.079350  0.233594
# 2279  302280  0.339870  0.037285  0.006086  0.017451  0.066106  0.228028
# 2280  302281  0.339870  0.028722  0.009178  0.017659  0.102865  0.228028
# 2281  302282  0.351436  0.136870  0.043930  0.052591  0.094580  0.238612
# 2282  302283  0.339870  0.147605  0.050861  0.134093  0.090477  0.232963
# 2283  302284  0.339870  0.052632  0.015590  0.024756  0.073131  0.228028
# 2284  302285  0.339870  0.027610  0.005997  0.023170  0.068459  0.228028
# 2285  302286  0.351436  0.153575  0.048770  0.057371  0.128936  0.238612
#
#           mean
# 0     0.153878
# 1     0.151500
# 2     0.157187
# 3     0.166155
# 4     0.223525
# 5     0.175980
# 6     0.150040
# 7     0.163037
# 8     0.267421
# 9     0.163929
# 10    0.258349
# 11    0.246898
# 12    0.165336
# 13    0.147365
# 14    0.133900
# 15    0.171255
# 16    0.268135
# 17    0.260609
# 18    0.179317
# 19    0.153743
# 20    0.257090
# 21    0.134480
# 22    0.158020
# 23    0.248809
# 24    0.144873
# 25    0.140794
# 26    0.211975
# 27    0.199336
# 28    0.168324
# 29    0.250256
# ...        ...
# 2256  0.126267
# 2257  0.209571
# 2258  0.117084
# 2259  0.144109
# 2260  0.127970
# 2261  0.119548
# 2262  0.159975
# 2263  0.119581
# 2264  0.127790
# 2265  0.152887
# 2266  0.211177
# 2267  0.200987
# 2268  0.132544
# 2269  0.122231
# 2270  0.150537
# 2271  0.165886
# 2272  0.117144
# 2273  0.149078
# 2274  0.140104
# 2275  0.132741
# 2276  0.117524
# 2277  0.156814
# 2278  0.134652
# 2279  0.115804
# 2280  0.121054
# 2281  0.153003
# 2282  0.165978
# 2283  0.122334
# 2284  0.115522
# 2285  0.163117
#
# [6126 rows x 8 columns]
# Training time: 0.18 minutes
# Writing submission:  submission_0.532167954703_2016-10-23-15-23.csv
# version 3acb
